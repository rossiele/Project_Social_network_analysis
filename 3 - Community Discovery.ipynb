# %% [markdown]
# # COMMUNITY DISCOVERY
# Nella seguente sezione si individueranno le comunità applicando i seguenti tre **algoritmi di Community Discovery** utilizzando la libreria [**CDlib**](https://cdlib.readthedocs.io/en/latest/index.html)
#
# Algoritmi:
# - [**Louvain**](#Louvain) (Internal Density Algorithm)
# - [**Label Propagation**](#labelprop) (Percolazione)
# - [**K-Clique**](#kclique) (Structure Definition)
#
# Su questi tre algoritmi verranno fatte sia valutazioni interne (in termini di conductance, AND, IED ecc.) e [esterne](#exval) (in termini di **Normalized Mutual Information** e **Normalized F1**)

# %%
#installo cdlib
# !pip install cdlib
# Out:
# Requirement already satisfied: cdlib in c:\users\aliis\anaconda3\lib\site-packages (0.2.6)
# Requirement already satisfied: nf1 in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.0.4)
# Requirement already satisfied: demon in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (2.0.6)
# Requirement already satisfied: scipy in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (1.7.1)
# Requirement already satisfied: pulp in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (2.6.0)
# Requirement already satisfied: bimlpa in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.1.2)
# Requirement already satisfied: python-Levenshtein in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.12.2)
# Requirement already satisfied: networkx>=2.4 in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (2.6.3)
# Requirement already satisfied: pandas in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (1.3.4)
# Requirement already satisfied: python-igraph in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.9.10)
# Requirement already satisfied: angel-cd in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (1.0.3)
# Requirement already satisfied: dynetx in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.3.1)
# Requirement already satisfied: eva-lcd in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.1.1)
# Requirement already satisfied: pooch in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (1.6.0)
# Requirement already satisfied: markov-clustering in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.0.6.dev0)
# Requirement already satisfied: tqdm in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (4.62.3)
# Requirement already satisfied: numpy in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (1.20.3)
# Requirement already satisfied: cython in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.29.28)
# Requirement already satisfied: thresholdclustering in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (1.1)
# Requirement already satisfied: pyclustering in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.10.1.2)
# Requirement already satisfied: python-louvain>=0.16 in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.16)
# Requirement already satisfied: seaborn in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.11.2)
# Requirement already satisfied: scikit-learn in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (1.1.1)
# Requirement already satisfied: matplotlib in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (3.4.3)
# Requirement already satisfied: chinese-whispers in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.8.0)
# Requirement already satisfied: future in c:\users\aliis\anaconda3\lib\site-packages (from cdlib) (0.18.2)
# Requirement already satisfied: decorator in c:\users\aliis\anaconda3\lib\site-packages (from dynetx->cdlib) (5.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aliis\anaconda3\lib\site-packages (from matplotlib->cdlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aliis\anaconda3\lib\site-packages (from matplotlib->cdlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aliis\anaconda3\lib\site-packages (from matplotlib->cdlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aliis\anaconda3\lib\site-packages (from matplotlib->cdlib) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\aliis\anaconda3\lib\site-packages (from matplotlib->cdlib) (0.10.0)
# Requirement already satisfied: six in c:\users\aliis\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->cdlib) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\aliis\anaconda3\lib\site-packages (from pandas->cdlib) (2021.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\aliis\anaconda3\lib\site-packages (from pooch->cdlib) (21.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\aliis\anaconda3\lib\site-packages (from pooch->cdlib) (2.26.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\aliis\anaconda3\lib\site-packages (from pooch->cdlib) (1.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aliis\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->cdlib) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aliis\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->cdlib) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aliis\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->cdlib) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aliis\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->cdlib) (2.0.4)
# Requirement already satisfied: igraph==0.9.10 in c:\users\aliis\anaconda3\lib\site-packages (from python-igraph->cdlib) (0.9.10)
# Requirement already satisfied: texttable>=1.6.2 in c:\users\aliis\anaconda3\lib\site-packages (from igraph==0.9.10->python-igraph->cdlib) (1.6.4)
# Requirement already satisfied: setuptools in c:\users\aliis\anaconda3\lib\site-packages (from python-Levenshtein->cdlib) (58.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aliis\anaconda3\lib\site-packages (from scikit-learn->cdlib) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\aliis\anaconda3\lib\site-packages (from scikit-learn->cdlib) (1.1.0)
# Requirement already satisfied: colorama in c:\users\aliis\anaconda3\lib\site-packages (from tqdm->cdlib) (0.4.4)

# %%
import cdlib
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import powerlaw
import seaborn as sns

from cdlib import algorithms, evaluation, ensemble, viz, readwrite

# %%
def read_net(filename):
    g = nx.Graph()
    with open(filename) as f:
        f.readline()
        for l in f:
            l = l.split(",")
            g.add_edge(l[1], l[3]) #, weight=int(float(l[5].rstrip('\n'))))
    return g

lista = []

def coms_evaluation(algoritmo, nome_algoritmo):
    print ('--------------------------------------------------------------\n Valutazione comunità ottenute con algoritmo', nome_algoritmo, '\n-------------------------------------------------------------\n')
    print('- Copertura nodi:', algoritmo.node_coverage)
    print('- Modularity:',  algoritmo.newman_girvan_modularity())
    print('- Numero Nodi:', algoritmo.size())
    print('- Avg Distance:', algoritmo.avg_distance())
    print('- Conductance:', algoritmo.conductance())
    print('- Avarage Node Degree:', algoritmo.average_internal_degree())
    print('- Internal Edge Density:', algoritmo.internal_edge_density())
    
    lista.append((nome_algoritmo, algoritmo.size(summary = False)))
    

def stampa_nodi_coms (algoritmo, nome_algoritmo):
    n_nodi = []
    for i in algoritmo.communities:
        n_nodi += i
    n_nodi = list(set(n_nodi))
    print("Nodi nelle communities identificate con l'algoritmo", nome_algoritmo,':', len(n_nodi))

# %% [markdown]
# Creazione del grafo

# %%
df = pd.read_csv("data/df_grafo_pesato.csv", skipinitialspace=True, na_values='?', keep_default_na=True)
del[df['Unnamed: 0']]
g = read_net("data/df_grafo_pesato.csv")

# %% [markdown]
# Per individuare le comunità utilizzerò un grafo diretto e non pesato

# %%
g = g.to_undirected()
nx.info(g)
# Out:
# 'Graph with 18266 nodes and 21697 edges'

# %%
df
# Out:
#              source            id_source           target  \
# 0            jwl2nd           4563241355   chanleycourttv
# 1         simplyslj  1518917881119059968   theemilydbaker
# 2            jwl2nd           4563241355          courttv
# 3         simplyslj  1518917881119059968  legalbytesmedia
# 4           adrferg  1074757149748854792          courttv
# ...             ...                  ...              ...
# 21708     intheone9            208950166     ThatUmbrella
# 21709     intheone9            208950166      dailymailuk
# 21710     intheone9            208950166      elainebhoft
# 21711     intheone9            208950166  girlsreallyrule
# 21712  zzziiinnnggg             54606627     winonasrider
#
#                  id_target   weights
# 0               4730732546  1.000000
# 1                 22594853  0.952055
# 2      1031946753510203392  0.924658
# 3      1262475778631106560  0.914384
# 4      1031946753510203392  0.633562
# ...                    ...       ...
# 21708   901030183213445125  0.000000
# 21709            111556423  0.000000
# 21710  1380604861486665730  0.000000
# 21711            580312540  0.000000
# 21712           1088984209  0.000000
#
# [21713 rows x 5 columns]

# %% [markdown]
# -----

# %% [markdown]
# ## LOUVAIN <a id = 'Louvain'> </a>

# %% [markdown]
# ### Parameter Tuning
# - *resolution*
# - *randomize*

# %%
resolution_louvain = ensemble.Parameter(name="resolution", start=0.1, end=1, step=0.1)
randomize_louvain = ensemble.BoolParameter(name="randomize")

communities_louvain, scoring_louvain = ensemble.random_search(graph=g, method=algorithms.louvain,
                                              parameters=[resolution_louvain, randomize_louvain],
                                              quality_score = evaluation.erdos_renyi_modularity,
                                              instances = 3, aggregate=max)

print("Configuration: %s \nScoring: %s" %(communities_louvain.method_parameters, scoring_louvain))
# Out:
# Configuration: {'weight': 'weight', 'resolution': 0.5, 'randomize': False}
# Scoring: FitnessResult(min=None, max=None, score=0.7820624696434636, std=None)

# %%
louvain_coms =  algorithms.louvain(g, resolution=0.9, randomize=False)

# %%
louvain_coms

# %% [markdown]
# ### Valutazione interna

# %%
print('Sovrapposizione communities identificate con algoritmo Louvain (con pesi): ', louvain_coms.overlap)
# Out:
# Sovrapposizione communities identificate con algoritmo Louvain (con pesi):  False

# %%
coms_evaluation(louvain_coms, "Louvain")
# Out:
# --------------------------------------------------------------
#  Valutazione comunità ottenute con algoritmo Louvain
# -------------------------------------------------------------
#
# - Copertura nodi: 1.0
# - Modularity: FitnessResult(min=None, max=None, score=0.7941856342711396, std=None)
# - Numero Nodi: FitnessResult(min=1, max=1468, score=7.419171405361495, std=52.4595833562343)
# - Avg Distance: FitnessResult(min=0, max=8.633618090452261, score=1.19140051681419, std=0.5840647245306968)
# - Conductance: FitnessResult(min=0.0, max=0.2872727272727273, score=0.003087559167734226, std=0.024490192471284908)
# - Avarage Node Degree: FitnessResult(min=1.0, max=3.5, score=1.1585003575925221, std=0.2885668501979991)
# - Internal Edge Density: FitnessResult(min=0, max=3.0, score=0.8538837272021891, std=0.2585624708673986)

# %%
louvain_coms.communities
# Out:
# [['simplyslj',
#   'theemilydbaker',
#   'legalbytesmedia',
#   'tobiastheginger',
#   'thatumbrella',
#   'rekietalaw',
#   'esneet4113',
#   'yellowflashguy',
#   'aburkhartlaw',
#   'IanRunkle',
#   'inspectorstocks',
#   'kyduiguy',
#   'houseinhabit',
#   'ianrunkle',
#   'colleenbaker4',
#   'bronk34',
#   'thelawkoala',
#   'leannen04',
#   'jamesfromcourt',
#   'popcornedplanet',
#   'gellertdepp',
#   'joshthepunished',
#   'emmaleekelly5',
#   'comegeeksome1',
#   'junktruth',
#   'andysignore',
#   'lawselfdefense',
#   'spirituallyemp1',
#   'lonestarmomcom',
#   'steviejraw',
#   'lumberlaw',
#   'niermanjoe',
#   'RekietaLaw',
#   'MelancholyDolli',
#   'unabashedgator',
#   'brooklynburning',
#   'wakeyourvintage',
#   'lakeside17',
#   'teresalolvera',
#   'johnnydepp__ll',
#   'dobedobedolala',
#   'rhomany',
#   'brelana88',
#   'nancyomarin',
#   'tartanbulletz',
#   'r_telari',
#   'ffxcircuitcourt',
#   'rohitkulk29',
#   'govchad',
#   'lil_skyscraper_',
#   'epicesquire',
#   'faranbalanced',
#   'LumberLaw',
#   'novatempest_',
#   'lafamlaw',
#   'foxla',
#   'ca_divorce',
#   'XcuseMyFro',
#   'thelegalvices',
#   'lawschoolgrit',
#   'hnnbnn88',
#   'hoeglaw',
#   'thelegalmindset',
#   'sandraarchangel',
#   'rosiepilsbury',
#   'asadorasummers',
#   '_mzfreddie',
#   'urshy74',
#   'ampllama',
#   'DR_Man_hattan',
#   'uncivillaw',
#   'thesunshinekey',
#   'nickixdestiny',
#   'assimp333',
#   'deppjchris',
#   'natethelawyer',
#   'msninja13',
#   'camillemvasquez',
#   'bartonbella1',
#   'thatbrianfella',
#   'kimberlyconroy',
#   'davidterrace',
#   'mdapparel',
#   'QueenBee_73',
#   'trollets_fru',
#   'lifesapprentice',
#   'ephramstcloud',
#   'nashtastic2022',
#   'resistimpulse',
#   'leap_inwood',
#   'crazymomma007',
#   'gma',
#   'redzesty11',
#   'tragoslaw',
#   'NRWE23',
#   'UHurr',
#   'acm11106',
#   'cathrynbe',
#   'sosofiefatale',
#   'jane_k',
#   'Laine175',
#   'ssolorio77',
#   'Kwatts7304',
#   'saifed99',
#   'planetmonkie',
#   'ashleykristen64',
#   'ashton68756450',
#   'morgensmuede',
#   'LilienStastna',
#   'majaseif',
#   'vipvirtualsols',
#   'fadedbarnes',
#   'serpens1984',
#   'charisse_cantu',
#   'helenroberta19',
#   'amberrosee422',
#   'ree06114033',
#   'solequeen2020',
#   'laurabockov',
#   'LinKrenicki',
#   'steph6_xox',
#   'Karley7963',
#   'renegade98',
#   'mimiloveee71',
#   'colonelkurtz99',
#   'nlwisco',
#   'meganfoxwriter',
#   'greenmonkeysoup',
#   'spankiev',
#   'asmrparadiseyt',
#   'gninjuh',
#   'rekietamedia',
#   'ella83706561',
#   'red_velvet_ari',
#   'naomiwarne',
#   'keeleytalks',
#   'muzikmaker77',
#   'ajasmine0715',
#   'sweetieshortie2',
#   'kimberlykurz2',
#   'kdubsmiles',
#   'docbunny2020',
#   'jamiediann003',
#   'a_amanda_gomes',
#   'aanah82',
#   '911lapd',
#   'lapdhollywood',
#   'agirlofthenorth',
#   'lapdwestla',
#   'qab5znyd5ym81',
#   'daniisacs',
#   'mrssosbourne',
#   'skkyyyyyyyyyyy',
#   '007londongirl',
#   '0iivie',
#   'longinus357',
#   'daughterseveral',
#   'SmartTroll2021',
#   'toreparker',
#   'journaldelux',
#   'neverland_ecila',
#   'fairfaxcountypd',
#   'teamyoutube',
#   'nikki_vj_',
#   'davis_mistica',
#   'fgirlofjustice',
#   'dawncatherine',
#   'Alyssa_Milano',
#   'thisliberty',
#   'buchieri1',
#   'heardseyfried',
#   'jrl82929144',
#   'bettkink',
#   'tybeard10',
#   'tractordrivnsob',
#   'mplatypus82',
#   'thevampirerose',
#   'sunflower_boho',
#   'mousears7',
#   'danceinline',
#   'lorenasalter1',
#   'kitkatdani',
#   'sparky027',
#   'debsfennell',
#   'NiermanJoe',
#   'loislovesmusic',
#   'moralecompass',
#   'squidlord',
#   'lizbethne30',
#   'MeekMill',
#   'snowhitedriftd',
#   'theumbrellaguy',
#   'Traceonbase10',
#   'jujube1431',
#   'bootstinker',
#   'PopcornedPlanet',
#   'texas__nana',
#   'larrycr96853478',
#   'kamtot1138',
#   'sysco7t',
#   'cmerkl1',
#   'tanikasimply',
#   'katiekay0216',
#   'tallgirl0979',
#   'nadinebaden',
#   'SeaDBoat',
#   'GaryMar37705162',
#   'secretsquizzer',
#   'nosoyayamagucci',
#   'chammabrandon',
#   'theleadattorney',
#   'karrieat',
#   'chrysaliscreate',
#   'rottentomatoes',
#   'xxjusttessxx',
#   'clarissakay10',
#   'n2it8',
#   'almasy87',
#   'tatey61',
#   'TragosLaw',
#   'FionaCh01958269',
#   'nectarpeppervt',
#   'camjphillips',
#   'theonlyju1',
#   'kumar_b1',
#   'mr_bouche',
#   'Mimm_ina',
#   'stilljustbarra',
#   'ellacee83',
#   'justplainzack',
#   'eldudette',
#   'carolinehaf',
#   'csa_original',
#   'sisson_jane',
#   'thecanongurl',
#   'jenijebs',
#   'CynthiaTweetsIt',
#   'winkiesword',
#   'grande_dr',
#   'pinkie_pie_40',
#   'agendahurts',
#   'haegarrnc',
#   'Shayna_Adele',
#   '_smartchat',
#   'MissEmmsinger',
#   'joetabletop',
#   'jaque_ribeirooo',
#   'ulubobbins',
#   'arianzew',
#   'madam_boi',
#   'abdulp1984',
#   'ryangrim',
#   'walkinginpretty',
#   'micks85',
#   'ambushjj88',
#   'hellicksons580',
#   'omochan_ch',
#   'iesshhaa',
#   'Silvinvh1',
#   'MillieTooth',
#   'Dani_Di_Placido',
#   'nosysknows',
#   'willekeve',
#   'aitchquex',
#   'bruceriversclr',
#   'lunarod',
#   'rantyalex',
#   'ginacar25911809',
#   'postpunkbunny',
#   'zimmbiogal',
#   'bblatt11',
#   'asranomani',
#   '1joyfulgirl76',
#   'doridatabae',
#   '901lulu',
#   'polirealm',
#   'twittingrandma',
#   '_debbieo_',
#   'awesomismmom',
#   'lordbuckly',
#   'gonnatrymybest1',
#   'plzdontlookatm2',
#   'hunleyeric',
#   'lunamars2017',
#   'lawtubeclips',
#   'amandadecadenet',
#   'itzmeroyal1',
#   'MeganFoxWriter',
#   'enterhacker',
#   'horaeof',
#   'katarific2010',
#   'shebepamella',
#   'socialtheorycan',
#   'jennamarie227',
#   'jacquelineca1',
#   'realpamster',
#   'amigoodheart',
#   '__Mxddiegrxce__',
#   'JenniferHush1',
#   'rdubhall',
#   'popcultnerd',
#   'noxnigo',
#   'dlordepp',
#   'shineypinguin',
#   'lavsirng',
#   'higginsmommato2',
#   'shez1124',
#   'nottimpressed_',
#   'adam_waldmignon',
#   'dolly_faith2015',
#   'wars_everything',
#   'ninterit',
#   'disneywithjaime',
#   'dukemedschool',
#   'djearicpatten',
#   'dkcripple',
#   'djmichaeltoast',
#   'shortbusdave86',
#   'kay_2405',
#   'notapopularop',
#   'don_sharp12',
#   'jonygitar',
#   'djkurx',
#   'themuppets',
#   'stern_angelica',
#   'pittstick',
#   'r4vi4rt',
#   'iratemaxwell',
#   'kiddiepax',
#   'neddokhan',
#   'integrityshines',
#   'jdah2022trial',
#   'Carlzmeister',
#   'icklepickle',
#   'kevinmuehleisen',
#   'proudtx73',
#   'jamizz97',
#   'johndeppchris',
#   'natlawyerchic',
#   'randi_savage',
#   'eatdeux',
#   'TaraKilshaw',
#   'skoobee63',
#   'raisin_patriots',
#   'itsafact3',
#   'gnukman',
#   'jrosengard',
#   'glaciemot',
#   'fettigator',
#   'Blackfished2',
#   '60mins',
#   'evilpeamia',
#   'gbnews',
#   'nerdlecca',
#   'NatetheLawyer',
#   'TheLegalMindset',
#   'outspokenokie',
#   'johnraf10618715',
#   'foxy_feminist',
#   'gemrosep',
#   'gabeisabadwolf',
#   'rosey_dobbs',
#   'joonpearllondon',
#   'oweandersen',
#   'paleogranny58',
#   'forestindie',
#   'ThatPirateChick',
#   'rose_24k',
#   'iheartart1789',
#   'Sadangel13_Gish',
#   'forcefischer',
#   'dsmnyc1',
#   'duchess_neeka',
#   'caseystorment',
#   'shastr6',
#   'hellogemmx',
#   'hellsspawnworld',
#   'shay_brunick',
#   'HoegLaw',
#   'peposlawa',
#   'perceptionchek',
#   'epaldelta',
#   'outofstocktoys',
#   'MorganTremaine',
#   'AlexaGNovak1',
#   'TouchinDaButt',
#   'jennafischer',
#   'jnnfr965',
#   'jnmourao',
#   'emmacarnell9',
#   'emmapeel_',
#   'emmnichol',
#   'emperortoch',
#   'mrcsths',
#   'empire0084',
#   'gregeqed',
#   'GordonDimmack',
#   'shuler_lauren',
#   'spackler68',
#   'FaranBalanced',
#   'greenranger1701',
#   'junespiders',
#   'gretaaurora',
#   'restingsithface',
#   'oldmenwguitars',
#   'erraticopinions',
#   'esaezclarke',
#   '336sevilla',
#   'seadboat',
#   'tblawgroup',
#   'elisadayj4j',
#   'sdle1999',
#   'kaelhyun',
#   'happybox365',
#   'TSis73',
#   'kaetarturo',
#   'elles_21',
#   'MaeWhip',
#   'hachimamatv',
#   'hamrhedbear',
#   'halfway_hannie',
#   'antphrodite',
#   'reigntea',
#   'reknewmoon',
#   'jmcdance',
#   'lottiehistory',
#   'louise75997969',
#   'depplyhaiiows',
#   'lorioct',
#   'missvicious86',
#   'libleigh1',
#   'barbsmar',
#   'beeznitchio',
#   'beckster_2',
#   'becauseican2',
#   'mlmslayer',
#   'bbwriterchick',
#   'bbrrii_elle',
#   'bkblackstone',
#   'mommypanetta',
#   'togekirst',
#   'traceybaby',
#   'justice4line',
#   'justice4theline',
#   'lookingupmon',
#   'johnny1depp',
#   'atomicrougee',
#   'unmasked_kim',
#   'upinct',
#   'jodyscorner1',
#   'm44386425mc',
#   'instagram',
#   'trundlesploot',
#   'babybluejfj',
#   'missterysinger',
#   'adamwalman',
#   'ADarkCuriosity',
#   'whoismrrobot',
#   'catmama_sam',
#   'thezakuza',
#   'mouthofdasouth6',
#   'cara_downey',
#   'lilsunshinesez',
#   'capitolninja',
#   'legalbytes',
#   'blondeapetite',
#   'boehsenichte123',
#   'llinda_w',
#   'ghostie_22',
#   'bobos9021',
#   'bookpublish101',
#   'blynnhilgeman',
#   'this_safe_place',
#   'littlemsrobbie',
#   'thisissaffers',
#   'breezyygirll',
#   'bornunderstars',
#   'bornstarvenus',
#   'bord2is',
#   'michaelbay',
#   'jjabrams',
#   'infinitumnihil',
#   'sukisueali',
#   'wtf_m0ni',
#   'marshmallow8753',
#   'absterwales',
#   'marsupial_gamer',
#   'djtashy4624',
#   '_starwhisperer',
#   'kitiharumi',
#   'TwitterSupport',
#   'TwitterSafety',
#   '_EmilyNagle_',
#   'beatriXXX_666',
#   'biglydisaster45',
#   'wittertainee',
#   'lawtalkwithmike',
#   'chrissiemayr',
#   'conmomma',
#   'originalrecipeg',
#   'mcdizzle17',
#   'mbogie34',
#   'msmagazine',
#   'realclownfishtv',
#   '2facedpink',
#   'realkerismith',
#   'mean_vagine',
#   'barnes_law',
#   '1atomikpunk',
#   'saltycracker9',
#   'melissa_1312_',
#   '_bre_lemus_',
#   'magaposse1776',
#   'violentkittycat',
#   'vicinitythree',
#   'vernacularvixen',
#   'andersonbasia',
#   'huffpost',
#   'magmojave',
#   'mintystays',
#   'mackette52',
#   'mirror54719495',
#   'artista_n',
#   'user1236707',
#   'vanieciafergus1',
#   'AmyMoretz_',
#   'amyfros12690046',
#   'whitealakazam',
#   'wheezy526',
#   'marcelinetogba',
#   'mangycoyote73',
#   'alittlebitofsp5',
#   'manrvxz',
#   'michael_oberg',
#   'maria_summerz',
#   'mariabella444',
#   'ameliahammy',
#   'v_Ahmadz',
#   'warriorxqueeng',
#   'valkyriansvals',
#   'alwaysjulyart',
#   'louisa_douglass',
#   'almightea100',
#   'allthemoneys',
#   'amazonpyjamason',
#   'chanmasta',
#   'cudltheef',
#   'collurr',
#   'multipod74',
#   'lejournaldesje3',
#   'nbc',
#   'laura_llb',
#   'tggi',
#   'lemortekali',
#   'starrgh',
#   'channelclaireyt',
#   'nebulalawrence',
#   'stacihpi',
#   'ddrey',
#   'larana_k',
#   'teejayventura',
#   'krystinadarfus',
#   'damian17236445',
#   'Ryan_Daigler',
#   'cielhunterzzzz',
#   'steventhatway_',
#   'ciliciasubero',
#   'chelsrrstiv',
#   'daniellespoview',
#   'AchakpoM',
#   'cloudjumper1996',
#   'teslianu',
#   'leeclower',
#   'nerdgirl_jean',
#   'clmediaarts',
#   'neneisme',
#   'clivetheunicorn',
#   'MattJardin',
#   'JohnnyTrialzz',
#   'l51251581',
#   'nicolevbalaoing',
#   'kitasstrophy',
#   'christinapykles',
#   'natisashupp',
#   'mskatiekate88',
#   'nicoleashlei',
#   'GreenMonkeySoup',
#   'cathalassophile',
#   'maryfer48807040',
#   'sunsetprince_l',
#   'randomsucculent',
#   'lifeofcrazymum',
#   'discoveryplus',
#   'denisecastlung1',
#   'lifeandtimesm',
#   'thejasonbyrne',
#   'catystrophia',
#   'cazza0707',
#   'andreacanalesss',
#   'kkatbat412',
#   'theacecampaign',
#   'kjclarksays',
#   'spontanja',
#   'thatumbrellaboy',
#   'lesliehaugen',
#   'synyste84987177',
#   'nataliekellyj89',
#   'pgh_geo',
#   'peperoncinodark',
#   'no_onei5per4ect',
#   'naydene_44',
#   'childrensla',
#   'pennademocrat',
#   'pessoafan1',
#   'GuerrillaVomit',
#   'nonhleskosana',
#   'peejsaid',
#   'meiginalah',
#   'perrypoppinz',
#   'jamieharrington',
#   'midsearch',
#   'pmgsmbl',
#   'melbicket',
#   'nicolegmp',
#   'melaniejesc',
#   'ngorges',
#   'nicbu0n',
#   'melodywhore',
#   'pollylogic',
#   'nina7infinity',
#   'nightguardian34',
#   'GrimsBar',
#   'stormysEDC',
#   'Nhem31926',
#   'pooks82official',
#   'attorneysings',
#   'alice2096xo',
#   'neon_wolf111',
#   'phoenixdelamerr',
#   'nerdynattyg',
#   'piikuliisi',
#   'miamay08979380',
#   'pheobeh3',
#   'mevolviaenojar',
#   'mfanton',
#   'mh44461',
#   'Bingbong_84',
#   'thebehaviorguy',
#   'newsome_dianne',
#   'piratetomski',
#   'nettytemp',
#   'pjparkjd',
#   'overthebeaaan',
#   'objeckshin',
#   'AmyPudds_',
#   'LawTalkWithMike',
#   'moonwispart',
#   'nyrex_x',
#   'moonshinejune',
#   'pammy77',
#   'muletowning',
#   'murray__sarah',
#   'musicluva2488',
#   'billieperry',
#   'mushmushmania',
#   'paperboats4',
#   'murphystina',
#   'pablo77110484',
#   'pacellitroy',
#   'mrs_hopewhite',
#   'mrsangelmiller',
#   'ohdear23',
#   'filer_kim',
#   'msfwhat',
#   'msgracietwitch',
#   'ollytang',
#   'ms_blondeasian',
#   'ms_mtdewqueen',
#   'mariilyntv',
#   'olimac_iii',
#   'oldmank2020',
#   'montana4lax',
#   'Zendaya',
#   'msmelodius',
#   'mowingmcs',
#   'optistrong',
#   'JuleneRenee99',
#   'oniesyr1126',
#   'Alexis_Sharell',
#   'offcdl',
#   'iamdrsoup',
#   'misannthropic',
#   'nameis_pete',
#   'BeautyBellaReid',
#   'paul6230s3',
#   'JuJuCurious',
#   'missconniebb',
#   'truegoss',
#   'notsocoolguy666',
#   'pansy',
#   'notthatthermo',
#   'missa_beet',
#   'naicoronnoc',
#   'misscasshoskins',
#   'naia_k0520',
#   'naomihildersley',
#   'nope_923',
#   'mikepamelap',
#   'mindfulfreya',
#   'minervawalker20',
#   'mininemi',
#   'Mystifeye',
#   'tmzi',
#   'nabilaburr',
#   'mydarkestdiary',
#   'myerske',
#   'parlousbitch',
#   'parledespirit',
#   'mlss__e',
#   'mizchele6',
#   'mjbenedicto',
#   'muziclady',
#   'umbrellaguy',
#   'mollykropp_',
#   'thenamesq',
#   'npost89',
#   'mzmarcopolo',
#   'missylou4643',
#   'nuggypanda',
#   'britbountree',
#   'megmafia',
#   'missfalv',
#   'thtgingrchick42',
#   'tiggetalks',
#   'Goodstyle42',
#   'Insomniac1985',
#   'goseals',
#   'thisisfunhuh',
#   'thisismycredo',
#   'JC4EVERYONE',
#   'anoushasakoui',
#   'twitterspaces',
#   'thequeenmac',
#   'thescottcj',
#   'thescr33nqu33n',
#   'theoptimisticbn',
#   'rihanna',
#   'tqmeri01',
#   'tonyasaid',
#   'toobsandstuff',
#   'traceymccaffery',
#   'tmlevick85t',
#   'tinymercinary',
#   'tomr15288961',
#   'tokyodiiva',
#   'tammiemcdonal17',
#   'talentedeukarya',
#   'baileysarian',
#   'tallulah_bear7',
#   'deniseknows1',
#   'swashworks',
#   'sweetishblonde',
#   'sweetkritter',
#   'sydneyadmirer',
#   'synthbabie06',
#   'systemicdunking',
#   't0mmi3b',
#   't3r3gram',
#   'sweetvee_13',
#   'swoop_13_37',
#   'the_mermaidian',
#   'theaftermathone',
#   'thatcasinochick',
#   'thebooknerdess9',
#   'theashleyvrana',
#   'WildeRochester',
#   'thatumbrellaguy',
#   'Thoughtful2030',
#   'CreatER1N',
#   'tess_flycrow',
#   'texasblue48',
#   'AmaralForte',
#   'BitcheeBarbie',
#   'JayIslaMilaAbel',
#   'LoveLincoln1900',
#   'Minji_Me',
#   'MsJenSteele',
#   'NAACP_LDF',
#   'ScottLCostello',
#   'TsukiHio18',
#   'bIusnydior',
#   'opinionudntwant',
#   'reineyelah',
#   'wildblackrose15',
#   'wildflower2317',
#   'witsendhanging',
#   'DWCompassion',
#   'kissumisha',
#   'wearenot_amused',
#   'webgyreuser',
#   'ajaisen',
#   'wanderingstar78',
#   'whereisbp',
#   'woodybeker',
#   'yummyyet',
#   'yusufnim',
#   'yuta89515664',
#   'williamshatner',
#   'zinniabees',
#   'juanita33456702',
#   'shawme101',
#   'zcruz2018',
#   'zee28___',
#   'zenpaxut',
#   'RiversMomma7',
#   'WaitingWriter',
#   'xenogearsfei',
#   'yongsuhh',
#   'yaraad_sa',
#   'yigh',
#   'yaldacollection',
#   'xmrxzerox',
#   'y00nko',
#   'txmomhollie',
#   'turkbros',
#   'unicaivahblogs',
#   'vanessafiorella',
#   'ugadawgsac48',
#   'ultimateone',
#   'DeppUruguay',
#   'truthw1llout',
#   'YellowFlashGuy',
#   'kimstweety',
#   'stefalternerd',
#   'ttinaelisabeth',
#   'viclaws2013',
#   'victori17400403',
#   'vidoslava',
#   'vinith_rdj3000',
#   'Firefox1310',
#   'zirconvondoom',
#   'ElleHiott',
#   'vettielou',
#   'viablesystems',
#   'ArtyMarika',
#   'MissShuffles',
#   'vortexglitter',
#   'vswizzle36',
#   'vyyyper',
#   'changeaus',
#   'mamamia',
#   'vjaydesigns',
#   'BookofBogan',
#   'vampire_fairy',
#   'usafluva',
#   'rjs11123',
#   'rmlawson4',
#   'rn_in_christ',
#   'robaclinch',
#   'rochelle9812',
#   'makeawish',
#   'arleth_prieto',
#   'renazing1',
#   'regardssuki',
#   'renee101',
#   'KarfikovaJana',
#   'rezzachamp',
#   'sacresinge',
#   'sadieb65497222',
#   'sa_rosen03',
#   'ethantrace',
#   'saltysusan_',
#   'samilouise1206',
#   'salman_1562',
#   'LittleNashyYup',
#   'rogerma95197435',
#   'ronibennett',
#   'jackposobiec',
#   'roxx8825',
#   'darth_news',
#   'ruthmariebutler',
#   'rvanova01',
#   'roxyred2006',
#   'royalapplem',
#   'rreddingtn',
#   'qseoiga',
#   'pauljotting',
#   'queenadalite',
#   'quickshot',
#   'pv_lawyer',
#   'rachella86',
#   'clarkshann',
#   'r3dbe4rd',
#   'prince1antonio',
#   'ptcfarms52',
#   'ptown49',
#   'purebredbootsy',
#   'TeeMar7727',
#   'priya_b',
#   'professortenshi',
#   'prose_ana',
#   'proxima2022',
#   'red___shoes',
#   'redcruz19',
#   'realitvpod',
#   'realrecaps',
#   'realziggyflo',
#   'randomindy',
#   'rangerthewonder',
#   'rajdip93',
#   'amberherd',
#   'ravivarakala',
#   'ravenowl2988',
#   'ravenouscurves',
#   'spacekidette',
#   'spat64',
#   'sonjacirilo',
#   'soounsuh',
#   'soria_giulia',
#   'slimerdude',
#   'AliObscene',
#   'sm9690',
#   'skyler_vogel',
#   'skalnajs',
#   'skatergirl70',
#   'snezhanao3',
#   'snoozells',
#   'socalmarla1',
#   'spekshn',
#   'stoweby',
#   'los',
#   'stephxxmichelle',
#   'pearlyross5',
#   'sub_boo',
#   'sugabuga16',
#   'summerspirit_',
#   'stephlilienthal',
#   'srqje',
#   'ssj3_jay',
#   'sta_ceyb',
#   'stacysawyers03',
#   'spunkiesteffie',
#   'scribbleburger',
#   'schanunser',
#   'seriouslykelly',
#   'seasonalhalotop',
#   'sarah_fenola',
#   'sarah_g_barker',
#   'mtaibbi',
#   'sandityche',
#   'savagelady16',
#   'saya__kennedy',
#   'sarassilkymoves',
#   'sassyliltutus',
#   'shmuue',
#   'adamcrigler',
#   'simiaexspiravit',
#   'simplyhappysm',
#   'shareenrobson',
#   'sharonsedgwick',
#   'shaunab44',
#   'BradBallanger',
#   'shhcharliebray',
#   'shellbell123r',
#   'crobb203',
#   'deeayepee',
#   'coragreenleaf',
#   'corey_tailorr',
#   'cookie4658',
#   'constantlydizzy',
#   'controversialog',
#   'cormoranv',
#   'cpu_tech0110',
#   'masterpt',
#   'debnbed',
#   'dawnnoelehull',
#   'dburridge010',
#   'debsdistwit',
#   'decidetotry',
#   'popcornplanet',
#   'ThatUmbrellaGuy',
#   'debsappy',
#   'thatnataliecole',
#   'danielle_est98',
#   'dannytheukman',
#   'damseldisgusted',
#   'daveforgiveness',
#   'Schwaz00m',
#   'daphnesargent',
#   'darcycharles708',
#   'darklordslush',
#   'dasupermom',
#   'darrenimms',
#   'dasilvamarye',
#   'channerz_maiden',
#   'charle6',
#   'cfold2',
#   'chelseaacliffe1',
#   'cherubicdoll1',
#   'charlotteracher',
#   ...],
#  ['decquine',
#   'deppheardtruth',
#   'aronberg',
#   'ixchelroy',
#   'guymrdth',
#   'webb0412',
#   'thirdgirlll',
#   'BellBlock',
#   'KL87120899',
#   'myeyeshaveseen1',
#   'DeppHeardTruth',
#   'TheNamesQ',
#   'Lil_Misstake',
#   'AnUnabashedNerd',
#   'exiled_Lover',
#   'jacxpearl',
#   'Ernie2322',
#   'littlemissbants',
#   'corinne_steele',
#   'MelanieBridgen',
#   'KrispKiwi',
#   'CA_Divorce',
#   'Dominodomino19',
#   'EllenBarkin',
#   'lilylysandra',
#   'Bah_Bla_Bla',
#   'overexposed91',
#   'reillynjames',
#   'AlfredTheAbsurd',
#   'Yousavewithus',
#   'KevinRashidi',
#   'KaiserVallejo',
#   'CynicalCatnip',
#   'Luvlight44',
#   'BriThibodeaux',
#   'Stephanyxoxo87',
#   'rain_hay',
#   'fuklames99',
#   'elizabethrenate',
#   'source411',
#   'ibrokethebong',
#   'AHumbleTalent',
#   'ADS_Ami',
#   'bunnnylebowski',
#   'pardonsentients',
#   'lizel303',
#   'mwkcaroline',
#   'stepneyss',
#   'andressaholiday',
#   'HStoreyCarrasco',
#   'Truthse10335075',
#   'WherelsMySheep',
#   'MarilynMansonU1',
#   'sunflxwervolsix',
#   'truthforamber',
#   'teresamarkos',
#   'x_keepyourbliss',
#   '2for1Chumgum',
#   'imheretotalktoU',
#   'rupertmurdoch',
#   'itsahashtaglife',
#   'JohnPow62265340',
#   '202s32s1c41',
#   'GW439321702',
#   'LadyDetectives1',
#   'CastanzaGeorgie',
#   'Truthndarehere',
#   'keepitrealcmon',
#   'monchxriii',
#   'StevenCrowley',
#   'treetop32243990',
#   'pengxuechun1',
#   'DavidVa00885306',
#   'madelineymaga',
#   'Fcfcfc67051808',
#   'luuzenit',
#   'caro_metcalf',
#   'Dorothy96305103',
#   'lilmissaurora1',
#   'khimeraxkaeru',
#   'MrsTooty79',
#   'expressionthro2',
#   'tseek84',
#   'RobynDMarley_',
#   'scottishlass84',
#   'TalkTV',
#   'Mrs_Nutbridge',
#   'RWTaylors',
#   'TryingNotToLook',
#   'TrevorMisc',
#   'LadyNadiaEssex',
#   'Kelly_K_9',
#   'MHaywood2468',
#   'Luisdcv',
#   'natesaver',
#   'NessaaaEvans',
#   '__HAARV',
#   'kaimiakid96',
#   'bb17fanatic',
#   'abusehasnogende',
#   'subastraI',
#   'SAmRAis6',
#   'Iromg',
#   'JulieWi01978654',
#   'CounsellRenae',
#   'CandidToAFault',
#   'KassandraSeven',
#   'Gypsy_Visions',
#   'fashiondiyteam',
#   'AndrewR506',
#   'francobianco',
#   'AnastasiosPach1',
#   'cookie_aunty',
#   'deeb_thee',
#   'curlyalicia1',
#   'couldwellbe',
#   'ashjswan',
#   'Dette2323',
#   'arianaxlove64',
#   'Aijalon323',
#   'Aeone99',
#   'Ego_death18',
#   'hodlocache',
#   'goldenfreckles3',
#   'Azille93480483',
#   'Bombshellbakes1',
#   'mderndarkwizard',
#   'mar7729',
#   'BrickLili',
#   'j0hnnycdpp',
#   'Crofty78185826',
#   'itsgabrielleu',
#   'incomparable_ss',
#   'fruittingle21',
#   'tasteofsanity',
#   'google',
#   'Annalee_Perez',
#   'AshleyJudd',
#   'MindOverHeart11',
#   'JasonLahme',
#   'MaryCanady4',
#   'Mariska',
#   'MacsEsq',
#   'Jemandcats',
#   'LuckyLo59037265',
#   'LuckyAbiP',
#   'MiraSorvino',
#   'NJRugbyGrl',
#   'MrRagnarac',
#   'MrNoNameToYou',
#   'deltanila',
#   'TeamYouTube',
#   'Calerios',
#   'Llani90',
#   'LisaGandini',
#   'LexiBananas',
#   'LeslieM12018144',
#   'Victori17400403',
#   'astoldbydejaa',
#   'RemWhenPod',
#   'Musks_Next_Wife',
#   'Variety',
#   'VanieciaFergus1',
#   'FatihOz82970331',
#   'jaamiike',
#   'awagyee',
#   'NickelsJessica',
#   'bookishwish',
#   'LauraBockov',
#   'SophiaBush',
#   'SchmoJosey',
#   'Roslyn715',
#   'Rafaela65096325',
#   'HalalalalaBOOOM',
#   'HappyRogue_121',
#   'talesnail',
#   'chicfilheyy',
#   'mustafaabazari',
#   'silkcharm',
#   'shuckleshells',
#   'lauriedesjardi8',
#   'purpleforamber',
#   'chris_houghton9',
#   'avonworldwide',
#   'clarehill__',
#   'dreamybanter',
#   'Rebecca91921211',
#   'LisaKsMom',
#   'st49295602',
#   'rosiecannonBall',
#   'theevilleaper',
#   'quiltsavvy1',
#   'pizzakatzen',
#   'nanana_987',
#   'nevereverdoit',
#   'minhaltaher',
#   'nishads_44',
#   'themaryjproject',
#   'louisandlestat',
#   'peripatetics',
#   'nwl88444048',
#   'veennuhs',
#   'yoabbaabba',
#   'kellyblaus',
#   'roslyntalusan',
#   'hummbaby40',
#   'bmurphy63',
#   'iam__vt',
#   'markkelly1962',
#   'winonasrider',
#   'mrgangster21',
#   'angiex0101',
#   'mculokii',
#   'analeypoldt',
#   'bRI_MIXX',
#   'vanderrwaals',
#   'itsalyssa_12',
#   'AmandaLax1977',
#   'theblaze',
#   'Noelle09253967',
#   'itweeter8',
#   'glyphcom',
#   'ElanaVital3',
#   'ValentinePomMom',
#   'thomgrantbruso',
#   'ElFrankfurter',
#   'Alesandra811',
#   'JeanMarie91558',
#   '_LOVEINVAIN',
#   'JohnnyIsDead_',
#   'John72805238',
#   'irishson19161',
#   'KayteeT1',
#   'KnightressH',
#   'Kugrox',
#   'north_deborah',
#   'holywitchgirl',
#   'EydieBurchfiel1',
#   'dobert_bobbs',
#   'HashtagShrid',
#   'prasantabhuyan',
#   'intlmllc',
#   'ProjectTabs',
#   'dcentofficial',
#   'planetaintshit',
#   'practicallykara',
#   'neo_valkyrie',
#   'No_Reason_Jenz',
#   'ishiee29',
#   'jdeppfxnn',
#   'iitsBreeezy',
#   'smatos76',
#   'j_ar_of_d_irt',
#   'janparavan',
#   'javanoob2',
#   'damirra1910',
#   'emurph42',
#   'cpsuk',
#   'morningwouldx',
#   'justicefor_ah',
#   'calzonagreys_',
#   'katyrichards_77',
#   'smandersonsusan',
#   'malfunkn',
#   'buzzy009',
#   'MusialFan73',
#   'LokeshSathish5',
#   'Losersan',
#   'thewayineverlie',
#   'Successdrive9',
#   'Soraya371',
#   'verysimple',
#   'Shantel02480571',
#   'SandyAtkins_',
#   'narcapocalypse',
#   'Nessj958',
#   'kenyaisdraining',
#   'Monatseng',
#   'xemopeachx',
#   'PattyEmmyy',
#   'youowetheworld',
#   'Panfulies',
#   'fatirishman',
#   'Madsonovich',
#   'rebeccajoc',
#   'ElizabethMcGov',
#   'opinionmadame',
#   'grimoire200',
#   'LASDHQ',
#   'ddanirojass',
#   'ganthew',
#   'geness63',
#   'flyingkulau',
#   'jorlizl',
#   'JordanCarruthh',
#   'sgunn2930',
#   'Dominic00719779',
#   'her_maj_borg',
#   'SouthernGirlTea',
#   'ixt0i',
#   'ChristinaPykles',
#   'nymeria_rhaenys',
#   'harmony12x',
#   'justinefairgro1',
#   'starlaitalia',
#   'thatNortherner1',
#   'NawiTheCore',
#   'triciauno',
#   '1618_aj',
#   'Bad_Wolf_Nine',
#   'madsdunn1112',
#   'blairsaetre',
#   '_deliriousx',
#   'LatinOnyx44',
#   'Ier_is_',
#   'molly_brown420',
#   'AndrewRhinier',
#   'DeniseDT',
#   'averagetweet75',
#   'AnonOpsSE',
#   'maleedus',
#   'mashable',
#   'melanieps7',
#   'Shelores',
#   'mort_rainey777',
#   'majkearney',
#   '_Mz2u',
#   'lita_rich',
#   'brittsutton777',
#   'skyedevonshire',
#   'Health_Care_CEO',
#   'JLoo12345',
#   'theninjafemme',
#   'camshaftf1',
#   'kents_2_cents',
#   'cam1nc',
#   'Sunflow21952299',
#   'moon_lights_owl',
#   'redlianak',
#   'tkelly65212002',
#   'Alisha_ash',
#   'person_von',
#   'thisislaceface',
#   'jasmineaminee',
#   'bristoltwo',
#   'AcklandVeronica',
#   'boring_boring1',
#   'Tweet_Twitches',
#   'helpme68419',
#   'wtfjag',
#   'PSheppard22',
#   'SandraHelton',
#   'crawford_maci',
#   'ace_venturistic',
#   'ladbible',
#   'sam79445979',
#   'adhd4life72',
#   'RachelG69564736',
#   'Ty_The_Climber',
#   '_celestialpeach',
#   'RealTayChaTLC',
#   'yomnasherif',
#   'TheDeppFan',
#   'argusjuno',
#   'BilliePerry',
#   'EllaCupcakes',
#   'milliehardysims',
#   'leonbrass',
#   'changshafu',
#   'ddsnorth',
#   'NickBelcourt',
#   'woodsrogersplc',
#   'audreyalison',
#   'porksmith',
#   'ktavolieri93',
#   'kurisusensei_',
#   'cladame1982',
#   'KarenRollings3',
#   'PandaDaManda',
#   'fiiinix0',
#   'kristiederyn',
#   'TracyLSteel',
#   'laurenhiggins_',
#   'kw4487',
#   'missford2005',
#   'defense_diaries',
#   'AuroraMya',
#   'AaronGriffin0',
#   'AmyP59111068',
#   'AlexKiddo9',
#   '2018_Bela',
#   'Bennyt_92',
#   'Angel_Devil982',
#   'Platoon19792',
#   'catsfightback89',
#   'auronburner',
#   'crownchaan',
#   'dailylaney',
#   'SocratesSnow',
#   'Marrinator13',
#   'anaheimyet',
#   'KroganCharr',
#   'noland_misty',
#   'nnek01',
#   'muchmanils17',
#   'Crypto_A_J',
#   'midgetmummsie',
#   'Annameitaa',
#   'melaniesback',
#   'stevedescano',
#   'mencommission',
#   'ians_india',
#   'natalieiee',
#   'CarlMcCormack9',
#   'BeeKay4ME',
#   'obsolete__units',
#   'nice_cuppa',
#   'Hotmesscakes',
#   'pan_toffels',
#   'CarlieWeddingt1',
#   'SummerSpirit_',
#   'illumigomez',
#   'karma4amber',
#   'monsantocharles',
#   'hyundai',
#   'tlc7695',
#   'ohnoyoudidnt116',
#   'spi_ilm',
#   'macskakaland',
#   'redleg01',
#   'mothering_in_22',
#   'DABSupport',
#   'MENDFamilyCourt',
#   'OrdinaryGuyUK',
#   'mr_karma_cool',
#   'realXanderXjork',
#   'ofdresistance',
#   'paulschoenmann',
#   'TristaCrass',
#   'nplvinh',
#   'nrasmuss',
#   'AlexJam91754067',
#   'misternsa97',
#   'ThowaRei',
#   'arekkusasan',
#   'LadyBlaze214',
#   'MSN',
#   'Marina_Save_EU',
#   'Mione48',
#   'MyGrindelwald',
#   'PENN52565467',
#   'SPECTRE_Chief',
#   'SweetChastityYT',
#   'TinaCol98878579',
#   'crystalcohen502',
#   'fredwibblington',
#   'gaynor_lee',
#   'henrycdorsett',
#   'itunes',
#   'KHWAJAMMOHSIN1',
#   'zema673111014',
#   'Juju86229235',
#   '81AngelicArtist',
#   'AngelAnneKnight',
#   'AngieFB',
#   'Atmosphere140',
#   'Delmar53875783',
#   'DoGood444',
#   'IDLY__Oh',
#   'sarahalpotter',
#   'theniftyartist',
#   'toutsuitesinner',
#   'SmileyBlanto',
#   'GojiraIRL',
#   'Kay_2405',
#   'Lilimex00',
#   'MlYarger101',
#   'Nainaloo',
#   'RIshgard',
#   'RoseMQueen1',
#   '__tiredmom__',
#   'crpatterson2010',
#   'danceforthesky',
#   'elisa_baumgarte',
#   'just_brash1',
#   'ky_liberal',
#   'lesliebooks',
#   'louvelune',
#   'piscesflowers',
#   'GNinjuh',
#   'Degetika',
#   'DDM_WOW',
#   'Avarith_Grey',
#   'CBikufa',
#   'CourtneyLynn40',
#   'laura_auerbach',
#   'tanhongyi90',
#   'tdavis85759563',
#   'AlisonS58',
#   'GozenaP',
#   'Kaarne14',
#   'VictoriaLuvzYhu',
#   'covert_annette',
#   'migrainemia',
#   'notyourbaetho',
#   'pastexpiry',
#   'sunshin71320087',
#   'Coleys_Creation',
#   'sureyyakiral',
#   'Gardencomet',
#   'thecompletejeff',
#   'AlexFacis',
#   'Janelle_Int',
#   'TriplesX3',
#   'texasgem0',
#   'ready_set_live',
#   'sezaynma',
#   'yousefearth',
#   'IIIlIIlIlIIIlIl',
#   'Life0fHigh707',
#   'susanschedules',
#   'xhunterashex',
#   'JijiB1974',
#   'Cassandra_H41',
#   'BashfulApothic',
#   'AmbyR00',
#   'yateswilburn',
#   'lea00040923',
#   'talkspace',
#   'KellyS_1981',
#   'twiddlebug7',
#   'tru_honestly',
#   'LieStronger',
#   'CammieMcGovern',
#   'smithsoniannpg',
#   'tsukisaltdealer',
#   'Jess_Coo',
#   'TashOldershaw',
#   'noleprincess1',
#   'vickimorgan22',
#   'rmi930',
#   'ariana_fsouza',
#   'footballconfid1',
#   'rocksolidalibi',
#   'sabrinascope',
#   'samatharogers16',
#   'ronduncan7',
#   'kj_ashby',
#   'quiddities15',
#   'CiaraWildhorse',
#   'Sardonicus_Rose',
#   'r_e_davidson71',
#   'Calisunshyne',
#   'pumkin54',
#   'bellanettie0218',
#   'rajanparekh18',
#   'realbilingram',
#   'soflaitalgal1',
#   'TurboChards',
#   'sociallyfein',
#   'johnnychrisdepp',
#   'skyaswriter',
#   'summernskulls',
#   'streetheat_1',
#   'catturd2',
#   'sretrodude',
#   'srinate_singh',
#   'stabbybirbboi',
#   'RealHoeyHimself',
#   'itsdavidben',
#   'srenee22',
#   'spring_atha',
#   'ElieNYC',
#   'JoyAnnReid',
#   'sempercoeur',
#   'Steven_Friedman',
#   'si_pemerhati68',
#   'silentwhoa',
#   'savemesaveyou',
#   'shadowalpha',
#   'sitikasim',
#   'Callie_G29',
#   'shesfnspeaking',
#   'shevestigates',
#   'soulstarfree',
#   'curfmannicole',
#   'cyclone_momma',
#   'scottishsweeney',
#   'SpankieV',
#   'RealPamster',
#   'Elcruz_96',
#   'cordelia_wolff',
#   'Agent_Wolfkey',
#   'coochiegangx',
#   'ClaudjaHaris',
#   'HerExcell',
#   'LittleMissMe525',
#   'OhHelloJack',
#   'Ras_Al_Him',
#   'bexybeatdown',
#   'jdnoscrubz',
#   'lepht_anonym',
#   'davecolan',
#   'david_dauphine',
#   'AlexN_z',
#   'angeItit',
#   'changeengineoil',
#   'betterhelp',
#   'charlicass',
#   'celluloidmaven',
#   'emmabeaumusic',
#   'coconutthug',
#   'Ravenmerc',
#   'chickcallednic',
#   'chillkitty',
#   'chipper_magee',
#   'urlocaltrxsh',
#   'littlequake',
#   'CockrumDebra',
#   'KrugNancey',
#   'NewfyPearl67',
#   'Shizznittle726',
#   'MoazaAlSharif',
#   'cinemamack',
#   'cicezen',
#   'Jafartomo',
#   'tedraimi',
#   'christo45193920',
#   'christo72001319',
#   'dsmblackrose',
#   'Makalicioussss',
#   'dudecrypto420',
#   'GitchiGamiFan',
#   'LouDobbs',
#   'conservatismDNA',
#   'BigPissGuy',
#   'drwhowhy',
#   'everare4',
#   'Allycat2804',
#   'krystaleconley',
#   'ellepole22',
#   'elizabethavr',
#   'MissMiaMina',
#   'Solomfimo',
#   'summergirl776',
#   'WillowBlossom08',
#   'abs7876',
#   'abendo1',
#   'YgritteVt',
#   'WishesMacleod',
#   'Wendy15817401',
#   'sicgirl1078',
#   'Wasabi_Ciri',
#   'VixcorOmega',
#   'TonyaSteiger11',
#   'ThomasB10275700',
#   'alexizolag',
#   'ara_first',
#   'baddley_em',
#   'blancagis2',
#   'brxhyl',
#   'carmarie1979',
#   'cat_piller',
#   'chuujisoolia',
#   'TheHelennofTroy',
#   'Tempora80335786',
#   'QualiaRedux',
#   'NicholeRenee1',
#   'NoodleNatty',
#   'OceansGreen222',
#   'Onthefritzie',
#   'PR1NCESSD10R',
#   'PatrickJeanPhi3',
#   'Peachyfruitcake',
#   'RiaBeevor',
#   'RobinYvarra',
#   'SOOJINBAE123',
#   'Seafarerbaby',
#   'Sparrow0hawk',
#   'StaceyMagnuson',
#   'Starskreem1982',
#   'StreetsOfRaith',
#   'TKadotani',
#   'depphead_savvy_',
#   'londonayerish',
#   'lovetodaydream',
#   'lucy_carling',
#   'marleyg13ems',
#   'melisah100',
#   'mellodiesmoon',
#   'mellymellz____',
#   'memehoe50',
#   'mondipun',
#   'mynameisCHANTE',
#   'nha715',
#   'nursenic8',
#   'nvrluvanyonelse',
#   'onlyonemera',
#   'osheblows',
#   'paulameninato',
#   'pauliereynolds',
#   'penguinchemist',
#   'rationalhuman15',
#   'kymom07',
#   'doraspenlows',
#   'duchessmeghanx',
#   'ellie_ellie666',
#   'emmaIeighxo',
#   'extremely_tired',
#   'gemmeri1',
#   'gowiththeflow81',
#   'greeknemesis1',
#   'honeygnomes',
#   'hope_balco',
#   'i_am_chaos_1',
#   'jadeizspam',
#   'jen_maran',
#   'jigglebugs',
#   'jlooney2',
#   'joelandelIie',
#   'jololikejazz',
#   'kayleig77506547',
#   'korineeeee',
#   'kouroshmoini',
#   'Nancydariella',
#   'Monicao20909532',
#   '13844502x4x',
#   '1GrammyJill',
#   'Aalliiccee10',
#   'Agent_Scarn420',
#   'LilMrsMurder',
#   'RebeccaKalyani',
#   'ReverieCrimePod',
#   'delurajulie',
#   'AilsaBristow',
#   'AmberTurdLies',
#   'Missa_Beet',
#   'Jennife58372495',
#   'Footballholic89',
#   'Galaxy_RL_',
#   'GillianFortune',
#   'GironZeus',
#   'GreenKayArt',
#   'HBSoulStains',
#   'HTinajane',
#   'HeatherHart7717',
#   'IamDawnWebb1',
#   'JDvsAH',
#   'Jenn_seger0131',
#   'Fifthwave6',
#   'Jfeb_ox',
#   'KRhaeMom',
#   'KaftanMac',
#   'Komal_Prasad96',
#   'LauraSSFreitas',
#   'MastersonsDoll',
#   'MeganRG10',
#   'Mesa_Brown',
#   'MimiGlandon',
#   'Fido64261825',
#   'AnnLogue',
#   'DaisyDoardo',
#   'AnnaVersteeg',
#   'ArvenKateBlack',
#   'BangaaaX',
#   'BhaskarMC',
#   'Blondielibra',
#   'BonneAphrodite',
#   'Burt6Gill',
#   'Butterflies949',
#   'CcVator',
#   'Change',
#   'DCAKdarling',
#   'DMW9699',
#   'DarrenCHoffman',
#   'Evelynm57864806',
#   'DeppHeads',
#   'Divyansh1999',
#   'DollyArthur_',
#   'DontFwMee',
#   'DownsLarche',
#   'DreaJoyz',
#   'Elisa_Cabral',
#   'Evelyan94',
#   'skirmley',
#   'djdubmasterflex',
#   'Stephan61422627',
#   'slopedsleep',
#   'star03c',
#   'strangeharbors',
#   'sussexgirl3',
#   'swagbug33',
#   'teamdepp_',
#   'tjeffer35270772',
#   'trinamichellew',
#   'truth_karl',
#   'twarner50',
#   'upbeatdata',
#   'upseteyess',
#   'vicky_okonkwo',
#   'wanqianz1',
#   'windmolenjonge',
#   'zevdain',
#   'digibirdy',
#   'dilleycouture',
#   'anand11112293',
#   'bwcibobach',
#   'Ashcroft46',
#   'arresttrumpnow3',
#   'aquarius_gypsy',
#   'artisannes',
#   'KShoe_Shoe',
#   'Brandini710',
#   'DAppalled',
#   'wmespeakers',
#   'annaiz4real',
#   'Chexor',
#   'mjmhayward',
#   '_aki7an',
#   '1wontevercare',
#   'LidyaBerhe',
#   '2290dmx',
#   'alan_smithee_2',
#   'LisaMaccarley',
#   'BESTCreativeLds',
#   'liamoatesss',
#   'supraman0511',
#   'CoinWoof',
#   'bree93540139',
#   'LauraPe60651074',
#   'ParrotKeith',
#   'YvonnePanzarel2',
#   'marloweKit',
#   'captainmarvel76',
#   'DestiGrace1',
#   'ADHD4Life72',
#   'MrsRobinsonXo',
#   'babs7101',
#   'ilovemyboys1988',
#   'bajablastthesad',
#   'bangtansmomo',
#   'atashijho',
#   'ashleytruong13',
#   'big_blonde_05',
#   'blacrose_',
#   'behvlnd',
#   'ChickJew',
#   'Childof07628468',
#   'IndictPOTUS45',
#   'kudusnemesis',
#   'Marilu95330735',
#   'liz_htafc',
#   'kkklaytonbigsby',
#   'JuliedeSouza',
#   'leannem44605862',
#   'MoniqueEngelb10',
#   'TheGlitzyGiGi',
#   'Dagui01',
#   'Imageekluvr',
#   'RicksReflection',
#   'SweetnCynful',
#   'nuboj',
#   'russrusso',
#   'laanie_87',
#   'lady_pirate',
#   'Lita_Rich',
#   'lauradelcea',
#   'HPforter',
#   'laurahuntori',
#   'RD04954960',
#   'elle_ilene',
#   'jowipe',
#   'kelley62760279',
#   'kelly__diote',
#   'AllenCaraway',
#   'katrinatatina',
#   'MuskyBaby',
#   'kazcook1',
#   'kids_safe_1st',
#   'AY64027641',
#   'JohnHag15101512',
#   'Lozv1',
#   'BlacRose_',
#   'kenzi18mac',
#   'kappoww',
#   'TexasToe',
#   'TolosaRafaela',
#   'kmnon04',
#   'laylah1991',
#   'katiquesa',
#   'HighasaPie1',
#   'LixiaSaran',
#   'maebykate',
#   'sashtlfc',
#   'mablomeano3',
#   'meagantweets',
#   'manshipolatta',
#   'mariahappychic1',
#   'Laanie_87',
#   'Sunflowerflee',
#   'opinvestigator',
#   'Yiskah879',
#   'lpgetsitdone',
#   'goodwitch829',
#   'JackieJanes8',
#   'lov3sick21',
#   'MeganYaeger',
#   'marmur2010',
#   'AzuraOrion',
#   'georgiadawes',
#   'lorrrraaaaine',
#   'loretta44546354',
#   'internationalm',
#   'gretchintn',
#   'amarveIa',
#   'glossandgroom',
#   'goolag3',
#   'godisklown',
#   'heidos777',
#   'hey_geria',
#   'Jimmy10127925',
#   'antibotlogic',
#   'latimesopinion',
#   'handleanother',
#   'TakenUserNombre',
#   'harnitica',
#   'hanzrenegade18',
#   'happysad55',
#   'fajerioz',
#   'falen_jones',
#   'gendimero',
#   'CatLadyCrazy23',
#   'FLouskii',
#   'gigicaponepr',
#   'fouberz',
#   'jasminejagger6',
#   'janesmonday',
#   'Samantha861012',
#   'iamjknighton',
#   'hopelov42916227',
#   'holycowbatman1',
#   'JlO4SP6BsqKmqem',
#   'izink_38',
#   'JustOneSpark74',
#   'TRUTHinTRUTHout',
#   'TammyPescatelli',
#   'mylalouras',
#   'zzziiinnnggg'],
#  ['realamberheard',
#   'lisasays_9',
#   'briajasminelynn',
#   'knuthaugen6',
#   'texasmagnolia2',
#   'celticcrusade',
#   'FantasticBeasts',
#   'disney',
#   'damn_it_linda',
#   'solereum',
#   'warnerbros',
#   'dccomics',
#   'crejohndesign',
#   'texastoe',
#   'cpatrickis',
#   '7newsdc',
#   'Soul_of_Lilith',
#   'wizardingworld',
#   'rebecca91921211',
#   'aclu',
#   'malik_eva',
#   'lorealparisusa',
#   'annecarea',
#   'taylorpieffer',
#   'nijackal',
#   'liamcoote6',
#   'getoffthecross1',
#   'evelynzaida',
#   'Asunas1972',
#   'justagirl043',
#   'BillieBergmann1',
#   'soxfanmap',
#   'poppytuffy',
#   'monkey_butz',
#   'diandragatti',
#   'kal_1979',
#   'DCComics',
#   'BreezyFrisco',
#   'apa',
#   'peanatxo',
#   'geekybar9',
#   'djjdiljot',
#   'lizshrum',
#   'carliepinc',
#   'mooshfelia',
#   'glitteryytatts',
#   'lorealparisuk',
#   'lorealusa',
#   'dailymail',
#   'msdwright',
#   'aquamanmovie',
#   'nada0hy',
#   '123gotozoo',
#   'BoundingComics',
#   'darrell02554398',
#   '60minutes',
#   '60minutesaus',
#   'bubsdeep',
#   'thewayizeeit',
#   'gameofthrones',
#   'slynns74',
#   'stephpcrogers',
#   'fungus_jimmy',
#   'drphil',
#   'droz',
#   'danielgbates',
#   'demoncreegan',
#   'monaddevs',
#   'mattmurphy3',
#   'deisywithane',
#   'roydswithyking7',
#   'snackbyteso1',
#   'AdvocatingFreed',
#   'kimstrangelove',
#   'JedimindtrikZz',
#   'oldwarmovies',
#   'PaolaAuditore',
#   'clownworldusa66',
#   'disneyplus',
#   'SheHulkOfficial',
#   'Marvel',
#   'skynews',
#   'ejtowne',
#   'ladywilletts_eh',
#   'egworldx_',
#   'change_mex',
#   'IamEdwardCantu',
#   'kat_strutt',
#   'shanlanhen',
#   'laurieasimonds',
#   'theitw',
#   'johnjohnnydepp',
#   'ezekielbourne',
#   'cpt_jck_sparrow',
#   'eparishio',
#   'disneystudios',
#   'very_olympia',
#   'AAAAA5A51',
#   'oprah',
#   'ashgenx',
#   'askkarmagirl',
#   'r_cho888',
#   'gregsorganic',
#   'ariesanelephant',
#   'johnnydepptrial',
#   'acasualgenius',
#   'JeffBadley2',
#   'jenna__lp',
#   'annamarieasha',
#   'jenniferedward',
#   'rapedearth',
#   'jj22d48',
#   'glenregret',
#   'TabbyB78',
#   'lucyendragneel',
#   'bastian_arndt',
#   'warnerbrosuk',
#   'ines2493',
#   'jamielorraine73',
#   'realcranky69',
#   'silverronin88',
#   'princesacrowned',
#   'jenrev22',
#   'cinemacon',
#   'rcq402',
#   'kayvandej',
#   'j3nn1f34',
#   'kayleeswantek',
#   'sl_cake',
#   'dior',
#   'iamedwardcantu',
#   'iamapant',
#   'iamkeke8',
#   'skyadventblog',
#   'smbslt',
#   'wbpictures',
#   'Wiseronenow',
#   'soapreporter',
#   'ultabeauty',
#   'dianeev62398271',
#   'itsbayyyyyy',
#   'FloridaMan4040',
#   'skinnytrees',
#   'oshestopalko',
#   'jamesjwan',
#   'lorealgroupe',
#   'wbhomeent',
#   'grahamkalei',
#   'tkscoggins',
#   'lizvlx',
#   'hex3993',
#   'etbnetwork',
#   'beyondthebench1',
#   'knackbags',
#   'nickwriteswords',
#   'nmorgasenradio',
#   'starbucks',
#   'tiktok_us',
#   'LadyRegen',
#   'Nathanl26915987',
#   'saitamasinceaug',
#   'eyprilsix',
#   'ehmmiest',
#   'fk2z1',
#   'sg_securities',
#   'MajaSeif',
#   'seanszeto',
#   'rebzmcw',
#   'reddiamond5',
#   'camillevasquezz',
#   'karlarobson',
#   'twiiter',
#   'sharadaramanat1',
#   'heather_brockie',
#   'jggrnt22',
#   'pensfan67',
#   'engelanael',
#   'IAMXEE91',
#   'gymkova',
#   'fairfaxcounty',
#   'samsmeltzer20',
#   'jknowles1228',
#   'el11112011',
#   'peachykeen2pt0',
#   'habshappy',
#   'Ruchika87373449',
#   'lozzie_ash',
#   'gypsygossiptt',
#   'belivinmylife',
#   'lorrainealysha',
#   'mommak_c',
#   'waltdisneyco',
#   'jbfilms',
#   'bettyinlove08',
#   'ufoteacher',
#   'astronaught420',
#   'realjohnnydep',
#   'ashbaby07',
#   'ashlie7news',
#   'unimatrix999',
#   'warnerbrostv',
#   'TheDCUniverse',
#   'gracearmagh',
#   'badspellcheck83',
#   'misswittank',
#   'babybirdrip',
#   'johnnydeppnews',
#   'mrskoutlaw',
#   'canadianmusings',
#   'tiny_toff',
#   'tildabeau',
#   'lnglivdakng',
#   'monicag72',
#   'bradbjornstad',
#   'abbysummer5',
#   '_inneverland',
#   'primevideo',
#   'wits_x_giggles',
#   '1_2692',
#   'alyshastefanie',
#   'melanietmartin',
#   'y2hero',
#   '77sylvia',
#   'mikefliegel',
#   'angstsan',
#   'emmylou30',
#   'arkgal89',
#   'mirrornow',
#   'katemosse',
#   'miridelcastillo',
#   'reesew',
#   'vera57945773',
#   'apaulog',
#   'johnnyycakes',
#   'brianaevigan_2',
#   'iamlenaheadey',
#   'michell68520741',
#   'chaperon_jalex',
#   'latestly',
#   'davidmkeynes',
#   'insideevs',
#   'denisedt',
#   'nevernormal88',
#   'taggajac',
#   'klsmtl',
#   'newsgramdotcom',
#   'teamtimmons15',
#   'krystlgames',
#   'tericarson',
#   'chazzp12',
#   'teeshepz',
#   'emiliaclarke',
#   'chirontabak',
#   'kristinkaits7',
#   'liestronger',
#   'demvoterusa',
#   'cat_disgusted',
#   'hodakotb',
#   'thecomp12192824',
#   'copyfishcat',
#   'suprman5047',
#   'warnermedia',
#   'discovery',
#   'cksays',
#   'crownedvictory9',
#   'syllabooze',
#   'catontheright',
#   'perdue_jrp',
#   'perlaigualada',
#   'vanityfair',
#   'nc_stanhope',
#   'nolamama78',
#   'allure_magazine',
#   'noffa1111',
#   'personified_war',
#   'midas_forever',
#   'natillywelshie',
#   'natecmerritt',
#   'mikah_dang',
#   'pnaranlal',
#   'johnkrasinski',
#   'melomaniacred',
#   'mellyb0000',
#   'nikkithetucker1',
#   'nightmistress35',
#   'nicolemw1981',
#   'nepaligentleman',
#   'metaplayio',
#   'nkyngpresents',
#   'Disney',
#   'pheonixee',
#   'rondarousey',
#   'THR',
#   'pipluproom',
#   'piratlifeforme',
#   'MarvelStudios',
#   'lorealpariscan',
#   'britneyspears',
#   'femcondition',
#   'mswingz',
#   'moraven12',
#   'paninuma',
#   'nurulas21597684',
#   'paisley_ponders',
#   'johnnydeppreads',
#   'johnnydeppwatch',
#   'okmagazine',
#   'ew',
#   'ms_fiberlicious',
#   'olesenbrun',
#   'mrsmc19_',
#   'ms_truth15',
#   'KayvanDej',
#   'msnatashaalicia',
#   'rohitwellington',
#   'avniraja',
#   'aashnaharjani',
#   'pattmarie30',
#   'crimeandlawblog',
#   'namratha_bemane',
#   'missemmsinger',
#   'notsure35869688',
#   'patricecarby',
#   'mycrankyboosez',
#   'annie_grimm12',
#   'parasite_ir',
#   'mynameiskatarin',
#   'mom2many317',
#   '_jasonmomoa',
#   'mzcoach15',
#   'missraqq',
#   'misterman_007',
#   'FLAVINMcFLAVIN',
#   'MaruscakMary',
#   'thekayleen_',
#   'theewzine',
#   'thegirlsaidwhat',
#   'thereal96119019',
#   'Tennesseeplaceh',
#   'therealleaflet',
#   'theonlyja',
#   'duargaryen',
#   'tpwkftwallows',
#   'tonybagademnutz',
#   'tonysolz1987',
#   'jeze_bel00',
#   'trashandtrauma',
#   'tinkytink',
#   'tomyhans',
#   'tamarar17020450',
#   'spencerpratt',
#   'tamflj',
#   'ufc',
#   'heathermcdonald',
#   'tdbeek',
#   'adzz_ayse',
#   'taylortalkslove',
#   'taylorswift13',
#   'syracuse_eric',
#   'sweetydreamy',
#   'the_backagain92',
#   'theamruthareddy',
#   'thebankizope',
#   'thebearrage1',
#   'tharpey',
#   'apapsychiatric',
#   'condenast',
#   'goshcharity',
#   'vastatebar',
#   'th3oneaboveall',
#   'joeroganhq',
#   'texasbowlegs',
#   'gregellis',
#   'willyknows_best',
#   'wickedblonde44',
#   'wisdom_quo',
#   'wepisknews',
#   'warmmonkey',
#   'whatson365',
#   'LexieTalionis',
#   'zackryker',
#   'zewildcat14',
#   'you_listen_up',
#   'wtf33090',
#   'lukemyerson',
#   'wtfisgoinghere0',
#   'yojaydawg',
#   'xoxovcarla',
#   'xuxaxu1',
#   'trent_bratt',
#   'triciramirez',
#   'victoriasaxecob',
#   'vintg_butterfly',
#   'valerieeefaithh',
#   'v4vend8a',
#   'rightfullyragin',
#   'rileymalloy22',
#   'HeardSimp',
#   'WBHomeEnt',
#   'johndeppwarrior',
#   'screenrant',
#   'ripdajuulz',
#   'robplayingames',
#   'rickcall0',
#   'ryuuoftruth',
#   'jessharnell',
#   'yakkopinky',
#   'samadoodledoo1',
#   'saltwatercolour',
#   'saldanaa80',
#   'sallyca47126306',
#   'rodriguez_binx',
#   'puttingthe_q',
#   'r3licx',
#   'pug_oddie',
#   'pru72',
#   'proudmomof4l1s',
#   'katesbooksnooks',
#   'wwiggie',
#   'redszxoxo',
#   'realrelliks',
#   'jussiesmollett',
#   'ragdollmegatron',
#   'realdaisydeclet',
#   'theoscars2023',
#   'spankster67',
#   'Sunshine_bestUK',
#   'sludgefactory__',
#   'TourmalineFB',
#   'stephkauf',
#   'stacie_white',
#   'stacy_rucker',
#   'deppheadjustice',
#   'spirit_4jesus',
#   'steffie707',
#   'scarlettjamescc',
#   'MaTalocalpyse',
#   'Matt2KGames',
#   'razzieawards',
#   'seattleman99',
#   'securehell70',
#   'seghabir',
#   'sarahlouise1123',
#   'sarahwe06172678',
#   'samsamiereal',
#   'sandra_16_',
#   'sarapianelli',
#   'savviianna',
#   'StrongDuchess81',
#   'sillysgood',
#   'silverfoxsami',
#   'shoreymichael',
#   'shortyk48',
#   'sisterofnight_c',
#   'sistersmercy73',
#   'shantel91505',
#   'sherdubsquared',
#   'Prismatic85',
#   'D00MZJAY',
#   'shelizasha',
#   'shedontlive',
#   'lorealuki',
#   'shellsbells23x',
#   'medicinsko',
#   'cspellot',
#   'newyorker',
#   'd_ntf_ckw_me',
#   'cw_writes',
#   'cworldrefugee',
#   'cynicadamus',
#   'MCJPeel',
#   'conrad61009123',
#   'corpse_flower12',
#   'cplusm81',
#   'craigdlyons',
#   'creativecadence',
#   'cricketburps',
#   'courtne91162652',
#   'bijouxgaga',
#   'darbymoo',
#   'dasnandini97',
#   'chantellframpt1',
#   'chellemarie11',
#   'chelseyovery',
#   'cherylwvinson',
#   'charnecharnexo',
#   'catchvandoos',
#   'claudet58268837',
#   'con___c0n',
#   'cococq19821',
#   'coffee_kittie',
#   'coffeeheretical',
#   'colekendalltcg',
#   'clair12556106',
#   'cjstewss',
#   'christineh1973',
#   'christobartlett',
#   'christopher8101',
#   'christsaurabh63',
#   'edsternnp',
#   'dunk0n',
#   'changepilipinas',
#   'doodydododo',
#   'dottiesmore',
#   'dublincalling',
#   'theusmle',
#   'AuriAuri12',
#   'cevichegirl',
#   'ex0t1c_markets',
#   'mlb',
#   'elzjosephson',
#   'kateamoss',
#   'emilybug8',
#   'denisehupp2921',
#   'denise_f_dehaan',
#   'deesback',
#   'djbobbyryan',
#   'OMO_BABAAJALA',
#   'desireebeard42',
#   'dharmarajgaut10',
#   'analaurad1',
#   'angela13809645',
#   'andieblackwood',
#   'amelia_mcj',
#   'alyzehhkhn',
#   'ariidarliing',
#   'armstrongjill',
#   'ashleelee819',
#   'ash_therealist',
#   'mythnmonsters',
#   'Catontheright',
#   'ankitisninja',
#   'antistupidityca',
#   '7eights2nine10',
#   '71northmoore',
#   '___vaso___',
#   'nydailynews',
#   'AwardsDaily',
#   'metoomvmt',
#   '_ill_be_mac_',
#   'billgates',
#   '_sergio_michel_',
#   '_dnvrgrl',
#   '3421ross',
#   '1purdyb_th',
#   'brycewhitlow11',
#   'ahmodshadi',
#   'adsh96030154',
#   'afggvv4',
#   'alexzvampyrock',
#   'aj_thebatman',
#   'akdwivedi_',
#   'akkeroef',
#   'abbieinla',
#   '_zoeli',
#   'aaleighiamaria',
#   'adolflikewhoa',
#   'adithimenon',
#   'aplusk',
#   'bmmartinezwrite',
#   'bookrobberbob',
#   'danawhite',
#   'yoelromeromma',
#   'bobborden1516',
#   'capebretoner82',
#   'cannabischris6',
#   'casilecheyenne',
#   'casper69rules',
#   'ofcom',
#   'casperthegh0st',
#   'carla_baron',
#   'carlachandler22',
#   'nevium',
#   'carrie_in_wi',
#   'buh_bye_birdie',
#   'bunnycaoi',
#   'wishshopping',
#   'cakennedy6',
#   'bye_whatever99',
#   'babsmom98',
#   'babyplutoskrtt',
#   'Ms_NickyJ',
#   'b1azeinthedark',
#   'baranovskygleb',
#   'astralyne_x',
#   'atomicginge',
#   'awambezi',
#   'ayeseltpw',
#   'bigfanojustice',
#   'bilaltheanalyst',
#   'beyondthestars4',
#   'bgrdf12',
#   'bharatinaiknews',
#   'birdyv87',
#   'bjpstweets',
#   'tiktokcreators',
#   'beinloveart',
#   'beautybellareid',
#   'bethenny',
#   'justbpodcast',
#   'berrell_jane',
#   'dojacat',
#   'hasselblad',
#   'knightsofthepac',
#   'knowwhentoholde',
#   'kokekofu',
#   'elmo',
#   'klaybabies',
#   'SoSofieFatale',
#   'kleinraych',
#   'kirajscott',
#   'kittehboopurr',
#   'lazytweeterrr',
#   'leonieb94',
#   'lebowskijohnny',
#   'labaleriol',
#   'lady_death2000',
#   'ladyinred111194',
#   'kziwica',
#   'amberheardsourc',
#   'lakedaniel11',
#   'landingzone19',
#   'just4bensimmons',
#   'aleaugeazam',
#   'madameask',
#   'jwhitford327',
#   'john_c_depp',
#   'jworderth',
#   'jz4realspeaks',
#   'Solo_PvP',
#   'justin_m_joy',
#   'jordans92248235',
#   'jonasgustavof',
#   'jonoguildford',
#   'juliaharrison4',
#   'joyfulnoyz',
#   'marvelstudios',
#   'kevin16133',
#   'kai_m17',
#   'katieblount',
#   'katiedaines82',
#   'liv_lucy',
#   'lorettarwll',
#   'matilda_w_',
#   'twinparanormal',
#   'atheworldsedge',
#   'majodete',
#   'ArleneHayle',
#   'JDepp94',
#   'm290592',
#   'marvell65645506',
#   'AriJenRuby',
#   'mari3francis',
#   'manmadeerror',
#   'manuelalatoya',
#   'marinan86466782',
#   'marisas1985',
#   'marlon112',
#   'mariana_houston',
#   'mariehi11609665',
#   'lindsey01778663',
#   'lluvia53',
#   'lizzyisapiggy',
#   'livefathandsome',
#   'lgb1964',
#   'real_vern',
#   'likelovebe',
#   'liliana18183555',
#   'lulu72_11',
#   'luvzfloyd',
#   'luciferslater',
#   'luizvaleria1',
#   'Shauna_too_dope',
#   'logivenchy',
#   'lonewolfleya',
#   'lookatdworld',
#   'Wetblankets4',
#   'JonnyPLLC',
#   'gliriza5',
#   'heto918',
#   'hellsurrey',
#   'gyrlhazel',
#   'hayleypendergas',
#   'fiveohfour',
#   'fjayne_',
#   'financeheo',
#   'final_arc_97',
#   'ford1066',
#   'ezriela',
#   'fernandeznitin',
#   'disneyparks',
#   'heyitsbinx',
#   'jeet_khakhar',
#   'jclayson01',
#   'jambriest',
#   'jamaral18',
#   'jamiedi26302726',
#   'lorealcommitted',
#   'lorealparisau',
#   'jane1618033',
#   'joe77374476',
#   'joesscrnnme',
#   'joaniemfc',
#   'johnnyamarilla',
#   'johnnydeppsupp1',
#   'johamotherofdog',
#   'jessica41515',
#   'jentheriot',
#   'jewcychezky',
#   'htop75',
#   'hubahuba79',
#   'whataburger',
#   'iantildeath',
#   'igiveyouabear',
#   'jamesgunn',
#   'iamtherealdrd',
#   'airynbe',
#   'rorysatran',
#   'hsbosley',
#   'hitcher1969',
#   'manuintiraymi',
#   'prideofgypsies',
#   'heythere091726',
#   'highdefthomas',
#   'housh_andrew',
#   'hmurf1331',
#   'itsleonorrivera',
#   'j4hellobeastie',
#   'iyorama',
#   'ilenikhenaehin1',
#   'intohollow',
#   'insertcomments'],
#  ['jwl2nd',
#   'chanleycourttv',
#   'courttv',
#   'adrferg',
#   'juliecourttv',
#   'stonedagainbro',
#   'ashleycourttv',
#   'tedcourttv',
#   'leahburke111',
#   'cathyrusson',
#   'lawcrimenetwork',
#   'digbylaps',
#   'ChanleyCourtTV',
#   'vinniepolitan',
#   'thelizrusso',
#   'lawyerschiff',
#   'CourtTV',
#   'blancacobb',
#   'florinalaw',
#   'michaelcourttv',
#   'courttvuk',
#   'lawcrimenews',
#   'taraeickenloff',
#   'White3Toy',
#   'realtalkwricky',
#   'bthequeen13',
#   'janyegwynne',
#   'mattjohnsonnews',
#   'tweetspice',
#   'jackrice',
#   'heather06898275',
#   'dare2bekhaleesi',
#   'bandofgypsys292',
#   'therebelnature',
#   'juliacourttv',
#   'berenzweiglaw',
#   'sethberenzweig',
#   'lorenkatie',
#   'fmgivemetruth',
#   'marcoiaatty',
#   'courttvfans',
#   'blablablubb1985',
#   'Stand_By_Johnny',
#   'lepalolivera',
#   'Leeannef1982',
#   'lakotadashing',
#   'pmt2387',
#   'JulieCourtTV',
#   'starwatch007',
#   'carlosmlastra',
#   'anyaglows',
#   'centaur1207',
#   'jessecordweber',
#   'joycourttv',
#   'long_tuesday',
#   'joonbug12345',
#   'Rickstroik',
#   'starjumper9',
#   'mollyvanpet',
#   'franklyme16',
#   'litigationlex',
#   'magesh_elumalai',
#   'An_elf_pirate',
#   'scandalous_pod',
#   'rossi4va',
#   'ballmercrypto',
#   'the_missyprissy',
#   'angenette5',
#   'dbeck57030037',
#   'matthewtmangino',
#   'hlntv',
#   'chloe_melas',
#   'joeyjacksonesq',
#   'dishymcdork',
#   'jecallaghan1',
#   'KeepItInReality',
#   'pompeyauslander',
#   'starpittsburgh',
#   'bubbasugly',
#   'meltaylor1007',
#   'tartantweetypie',
#   'kinglosoul',
# ...
#  ['debbieg68107721', 'ChuckCjmmn', 'mitchellreports'],
#  ['debcollie79', 'ObserverReport', 'WhiteOwlQueen'],
#  ['davos09061901', 'MysterySolvent', 'charles24154119'],
#  ['damanilesh', 'deepmind', 'philosophy_qu'],
#  ['davemac00', 'EllieCumbo', 'LfcMarty'],
#  ['dave_therealone', 'Ami_Jay', 'jdepps_crew'],
#  ['dashadeaux', '17StQrm', 'DavidCass19'],
#  ['chaka_khant', 'ScrtDrugAddict', 'MinnieStephC4'],
#  ['chefsteph407', 'blakelively', 'mannyiacal'],
#  ['cheekymark1917', 'BrummieBoy5', 'Grant_Colgate'],
#  ['casualfanatic79', 'HAWTToys', 'jaynetheory'],
#  ['comicsdaughter', 'Julius_Kim', 'kellyjohnsonhas'],
#  ['chiefjacob', 'WannaRathbone', 'scarletsouI'],
#  ['chypres89', 'BritMartinez', 'b_covers'],
#  ['ckilic75', 'SaveKuzeyali', 'arslnmelisaa'],
#  ['drama_mama_36', 'immabepetty', 'lrish_minx'],
#  ['drdana057', 'SerenityKeeper_', 'juanping_'],
#  ['drkidnurse', 'NancyLeeGrahn', 'jodaniecarpino'],
#  ['ernestborgten', 'DaleKeter', 'BriannaWu'],
#  ['esxzilya', 'Whuollyhx', 'changeger'],
#  ['elizabe88913074', 'RebelMom1994', 'stevebr94206122'],
#  ['engulfingflame1', 'Ranting_Monkey', 'RepLizCheney'],
#  ['denzallie', 'majorityfm', 'maxberger'],
#  ['defamep', 'BeauTFC', 'paulogia0'],
#  ['djfolamii', 'dbigscratcher', 'dahero_7teenth'],
#  ['diamandisla', 'EliaJanee', 'dani_di_placido'],
#  ['arm34', 'radiogunk', 'thedeppening'],
#  ['arnar87', 'ArmyStrang', 'PeterZeihan'],
#  ['arunsahluwalia', 'alastairdick', 'gwenley1961'],
#  ['anni3b3an', 'marcuslemonis', 'CampingWorld'],
#  ['antspantsvelo', 'RT_com', 'Unseenfac3'],
#  ['annsummtbe', 'AP4Liberty', 'RareCamellia'],
#  ['anthonyprouse2', 'spectator', 'lisamainwaring'],
#  ['__asht__oo', 'BuckBreakMan', 'GatorTimeYT'],
#  ['_failure_exe', 'gumihocosplay', 'gumihohannya'],
#  ['1sweet_wi', 'aurbinato', 'rbaby'],
#  ['aichamarghadi', 'RealNancySoto', 'LuisanaDeGolyer'],
#  ['ahmz1404', 'dark1x', 'kentank87'],
#  ['agarthan', 'APAPsychiatric', 'BlueNightBird'],
#  ['abigailesman', 'SoupandtheCity', 'lisa86550169'],
#  ['abby2418', 'johnnydepp767', 'hannyvampyre'],
#  ['adamkan29091501', 'Jessica_Smithxo', 'stephen__bear'],
#  ['breannetsang', 'ytunderground23', 'GSkooler'],
#  ['brendsteem', 'SCCADVASA', 'teamtrace'],
#  ['brodie07698058', 'DeppBSC', 'Stantek_SB'],
#  ['bloodline_rebel', 'eris_spiral', 'lawrence_spiral'],
#  ['carpeffingdiem', 'Gus_802', 'Lizzie02563572'],
#  ['bunmicheshire', 'Palmer18881314', 'berniedebusmann'],
#  ['californiaone2', 'BeingJWood', 'RhonaSparkesBre'],
#  ['calitextina', 'Annsoke', 'dpich2'],
#  ['badazjetta', 'facebookwatch', 'haolethai'],
#  ['barkleby1', 'cloudi_fanart', 'EvilEyeTweets'],
#  ['bambii9', 'NaomiSFB', 'daily_cat_image'],
#  ['bandarkaabaccha', 'Kuldeep74845900', 'scribe_prashant'],
#  ['baramosgonus', 'Acedefective3f', 'SupesBatsy'],
#  ['atrydka', 'bibibibeaut', 'LeanneMichelleB'],
#  ['ayuaty1', 'davido', 'officialdrkelly'],
#  ['augusti35194393', 'donaldjtrumpjr', 'gregkellyusa'],
#  ['autumnnn_rosee', 'autiadams', 'rohmontgomery'],
#  ['betsykellerpr', 'VictimsVoiceApp', 'physorg_com'],
#  ['bettyaburns', 'JhuwDee', 'maevewest45'],
#  ['beevinnydee', 'ThinkingAtheist', 'ginger613a'],
#  ['beechdreemer', 'jdoll_horne', 'RonChapmanAtty'],
#  ['bell524bell', 'bobpockrass', 'miniaturebadass'],
#  ['bbluecrush', 'BbbearBig', 'josephmorrisyt'],
#  ['benjijamin1', 'Allieraine_', 'angelene_botha'],
#  ['krissykitsune', 'RainyDaysUtube', 'Rwlshmakeup'],
#  ['knokknokwhodat', 'Ezfan1010', 'disclosetv'],
#  ['koalifiedgrace', 'HowieDittman', 'canadianaco'],
#  ['ktumulty', 'postopinions', 'erikwemple'],
#  ['kimjiwonsmyou', 'DaniWright888', 'HeLLBouND_xx'],
#  ['klowe212121', 'AltitudeSR', 'RadioMoser'],
#  ['lcn3wolf', 'fifi_the_fl0wer', 'sxnshineflwr'],
#  ['ldrcultleader', 'GraceRandolph', 'gomezandromeda'],
#  ['legalhackette', 'timeslaw', '5rb'],
#  ['laughatlefties', 'CarolinaThinks', 'politiwars'],
#  ['juno_macloon', 'rtenews', 'foodborn'],
#  ['justjebus', 'RosenfeldReport', 'alixabeth'],
#  ['justsomenobod12', 'Styx666Official', 'freeradicalpunk'],
#  ['justinsbeck', 'ACLgov', 'StateBarCA'],
#  ['joshlakey4', 'davechensky', 'thefilmcastpod'],
#  ['jonnyboyblock', 'CorbynRed', 'Tedsquare23'],
#  ['juliabrennan97', 'NBCNightlyNews', 'NormanCharles66'],
#  ['kazpendlebury', 'decentral_ise', 'hammo1859'],
#  ['kheller', 'emilyyahr', 'hankstuever'],
#  ['karlknaus', 'SpaceKidette', 'SCalliss'],
#  ['kartikeyab_', 'SumatiThusoo', 'deshwalshivangi'],
#  ['maldivesmart', 'soops_', 'MadelaineLucieH'],
#  ['madhumi07336801', 'Richard78854145', 'jamasmotoko'],
#  ['madlisa1967', 'jimrosecircus1', 'repairrestores1'],
#  ['matthew_t_lowe', 'brave', 'shiicoinprotips'],
#  ['max_roi', 'jcurant001', 'jilikoi9'],
#  ['marching_ants_', 'ChakaCannot', 'apmbsd'],
#  ['marciajacobsen2', 'OfficialOMD', 'alexina_regu'],
#  ['markpoepsel', 'dkiesow', 'iroughol'],
#  ['lifeinunreality', 'Adeleart3', 'mysticcshadow'],
#  ['likegointhisway', 'Guyz20051', 'parkes1900'],
#  ['lilacave', 'Jeff_Brunson', 'baconandtacos'],
#  ['lt4wom', 'KooterX7', 'scott_boyette'],
#  ['lollipoplozer', 'benjikrol', 'kuno_k0'],
#  ['louisa_oeffling', 'LottieHistory', 'shashatheitch22'],
#  ['granuailemalia', 'tesco', 'sluggishwalnut'],
#  ['guitarbuckeye', 'amandacarpenter', 'littlemissmarxi'],
#  ['helen_e_jones', 'ChanhNg6783279', 'chanhng6783279'],
#  ['heathba55613177', 'JohnnyDeppNFT', 'news_of_bsc'],
#  ['heroofxmas', 'xoshaiiii', 'JeffDah75244280'],
#  ['hellblazzrr', 'YoItsImran', 'vampirenazuna'],
#  ['fivecentcones', 'Sandor_clega', 'ghoulgaze'],
#  ['fkyeahgallavich', 'BluEyeTrue', 'ratedlocox'],
#  ['eylandertile', 'dickfacenfts', 'dicklebuttsnft'],
#  ['feudaltimes', 'alisonwallis60', 'amscanlon'],
#  ['gedthered68', 'mrdanwalker', 'jillianross10'],
#  ['garysbrain', 'Wulf_Helm', 'Starms6'],
#  ['garybuglass', 'scribunda', 'GaysForTrumpUS'],
#  ['freenloved', 'GodsArmyOfHmrs', 'JackieM29911084'],
#  ['ftwrubina22', 'birdiealyaa', 'chasingdrimz'],
#  ['gada_call', 'alicecooper', 'foxwoodsct'],
#  ['jd_belles', 'jimbourg', 'CloutNewsMedia'],
#  ['jcoughlin24', 'Courtilini14', 'OutLandAnatomy'],
#  ['jenna_orangeco', 'MikeSington', 'johnqlaw369'],
#  ['jakelarsen', 'keithlaw', 'caseyboguslaw'],
#  ['jake_sky_walker', 'Teri_Kanefield', 'AlsoWonderWoman'],
#  ['janehamilton22', 'cc_livingstone', 'beathhigh'],
#  ['jn_pickles', 'LincolnWatchman', 'ModoWriter'],
#  ['jerseykidpicks', 'cafeinawater', 'texasroadhouse'],
#  ['jennysindikat', 'ElPalPalacios', 'Jingjing_Li'],
#  ['jessesalisha', 'biggiesmalls', '2pac'],
#  ['jessblank', 'Rhylaa_', 'camdotmp4'],
#  ['jim_frgtar', 'biggestjoel', 'RobVTaylor'],
#  ['jillphys1905', 'CoreyRForrester', 'traecrowder'],
#  ['hugorune', 'IntoHollow', 'gabylinares'],
#  ['islandvivi', 'Gizzie_af', 'rainforestmel'],
#  ['jaamiewhite', 'bjandjamie', 'bjharrisradio'],
#  ['jac7724', 'Ali89_91', 'SBodratti'],
#  ['ittacocat', 'smallstreamersc', 'smallstreamersr'],
#  ['imshawncav', 'ShadowPatriot93', 'JamesLe99784440'],
#  ['ijoelpeterpage', 'SusanBanthonee', 'rapid_rar'],
#  ['insnyderwetrust', 'HotPanic', 'MelRamsayy'],
#  ['politicoin_1', 'purebloodtoken'],
#  ['guitarsoflove', 'realjohnnydep1'],
#  ['arinkaaaah', 'N_Cornerstone'],
#  ['definitelyfungy', 'chibilabs'],
#  ['reeast1205', 'TheDailyShow'],
#  ['gattonero', 'Hassanmirza'],
#  ['chloebumblebee', 'Peach_Schnapps'],
#  ['coolartbymboya', 'joinedmarch2014'],
#  ['sg___96', 'HASANSAIDBLAMO'],
#  ['gambling911', 'betonline_ag'],
#  ['fox5atlanta', 'tmzlive'],
#  ['robbielynn53', 'bizpacreview'],
#  ['erinelofficial', 'adezero'],
#  ['f4fartbot', 'rarible'],
#  ['azharha48293979', 'digg'],
#  ['otisorarthur', 'mrdougellin'],
#  ['sirjdog21', 'motivate51'],
#  ['laurenmintzer', 'mistymarris'],
#  ['bigsxysdaughter', 'lucascruikshank'],
#  ['farfarraway', 'independencenhp'],
#  ['darklordoftheit', 'w1tch_d0kt0r'],
#  ['kill_narcissus', 'TopGunMovie'],
#  ['davidbrumfield4', 'artpal'],
#  ['bijou_z', 'BRITTNEYSLU'],
#  ['bristolcorvid', 'mifellow'],
#  ['rwm2020', 'RealDeanCain'],
#  ['faeleure', 'anelicano'],
#  ['buch080', 'NoContextBrits'],
#  ['lisa_chudy2', 'GoldblattIrene'],
#  ['betsymoonbat', 'she_obey'],
#  ['judith_feyjude', 'smc429'],
#  ['lisa3pierce', 'NBCJoshua'],
#  ['dailymirror', 'megangoodwin_'],
#  ['linusrii', 'TheBarrylad'],
#  ['parabnormalshow', 'reversespeech'],
#  ['slothbear10', 'samfendermusic'],
#  ['kryptowinston', 'MikeBellATL'],
#  ['brotherevgeni', 'imbrettcooper'],
#  ['bhc3', 'JDeMolee'],
#  ['danielsingers', 'given2tweet'],
#  ['danigracewrites', 'OminousHallways'],
#  ['danny_is_king42', 'sherrifflucy'],
#  ['beverlycarter56', 'HenryDeFrances1'],
#  ['bryan_fx_', 'nickiclyne'],
#  ['kriswilliams__', 'HannahJayne07'],
#  ['nikkeh_jay', 'pressyb45'],
#  ['nickschadegg', 'jsspcr1'],
#  ['p__walleyxx', '10newsfirst'],
#  ['jones4tweet', 'mybright88'],
#  ['bonscotswelsh', 'hildymac'],
#  ['moonbunnyys', 'iwantmillk'],
#  ['flyinglandleech', 'FOX2News'],
#  ['robertferdina14', 'realjudgemiller'],
#  ['frappuccinoslim', 'vanillaopinions'],
#  ['rocksteadytech', 'stack_tracy_'],
#  ['rockledgehiker', 'MarkHertling'],
#  ['robins36', 'MegDoesHairx'],
#  ['blackmanusa', 'photochrist'],
#  ['fozra', 'Winter'],
#  ['francescaberry9', 'js_eskau'],
#  ['dedederinsola', 'gaz_colman'],
#  ['tobservor', 'RhonddaBryant'],
#  ['thriftshopmuske', 'AmySilverberg'],
#  ['bouncylittleba1', 'Jane_Suburbia'],
#  ['finaldaft', 'windcomecalling'],
#  ['lonelywhailes', '7EAVENS'],
#  ['brandyna3', 'punishedmother'],
#  ['dayanballweg', 'NoahHarald'],
#  ['brandogarlando', 'omgashcheeks'],
#  ['speaker23462594', 'UniofOxford'],
#  ['snowht44', 'msbananas_'],
#  ['lizobzri', 'PoliticusSarah'],
#  ['tiffany44541244', 'scottsimonsWVLA'],
#  ['kmaemaier', 'hwywhoney'],
#  ['flaffenbam', 'Carly4243'],
#  ['rousseaupisbuis', 'spinozaspinazie'],
#  ['kaylynn_barrett', 'schaney209'],
#  ['kaysharose_', 'gabsmolders'],
#  ['shinigami_eyess', 'shmergan'],
#  ['sherrigoodwin79', 'MrTAchilles'],
#  ['shieldzephyrone', 'watchmojo'],
#  ['dystopianr', 'RealKaylaJames'],
#  ['swimmersjackson', 'popepopemichael'],
#  ['siggystardust80', 'OhTheLies2'],
#  ['sycamoreavenue3', 'therecount'],
#  ['normanunaurbiz', 'PhillipsNanl'],
#  ['ejbusch', 'brittrobson'],
#  ['ehretdaryll', 'TheSGTJoker'],
#  ['eckbergjon', 'baym'],
#  ['chantalroomate', 'HollyOakau'],
#  ['kbishqbish', 'RealFanRZ'],
#  ['lawriter', 'tallhazelnut'],
#  ['shaunahair', 'virginmedia_tv'],
#  ['sharonjoy76', 'cheaptrickrules'],
#  ['n047201', 'usminitru'],
#  ['tarotontuesday', 'The_GLL_house'],
#  ['tanyat1020', 'myronjclifton'],
#  ['gaddmatt', 'goodyk'],
#  ['chigastronome', 'The_FFF'],
#  ['technotimed', 'TheBroku_Black'],
#  ['dijkstrandries', '561cdc'],
#  ['sky_blue34', 'Blueliner112'],
#  ['cwblogic', 'bruceanderson'],
#  ['necromancyblack', 'Zhukov82176036'],
#  ['thehstyle', 'littlemenot1'],
#  ['thelategreatzk', 'KellDA'],
#  ['candacetx', 'NINAFEELZ'],
#  ['stoppingplaces', 'JoyaBb1'],
#  ['kuster_mike', 'RichOToole'],
#  ['eponymousdj', 'butchanarchy'],
#  ['stuffwecomment', 'Michael_Z1012'],
#  ['erienoteerie', 'dshanico'],
#  ['carleastvold', 'BillSprague43'],
#  ['oniontaker', 'DaebakLyft'],
#  ['mr_james_c', 'ealexhudson'],
#  ['slfox48', 'HECVTE'],
#  ['calkid57', 'garkmallemore'],
#  ['olympicchenpion', 'LynthasLzCorner'],
#  ['mrjhessel', 'jpmsandie'],
#  ['sinceretactless', 'podbeancom'],
#  ['dgast68', 'stevedoocy'],
#  ['oden4cy', 'ScottC517'],
#  ['crazycoach_tv', 'Nutzypoo_ttv'],
#  ['crackinwax', 'snhs2'],
#  ['lesheath6', '10percentfilter'],
#  ['letsplayjen', 'cul_de_russie'],
#  ['simplephishin', 'WSJ'],
#  ['catselan', 'BeyondBlonde3'],
#  ['sudswatcher', 'RachelG4L'],
#  ['sueromulus', 'DrAmyCarson'],
#  ['cryobyte33', 'crymmace'],
#  ['emmyobleakly', 'DrDanilovic'],
#  ['nbeaudrot', 'opinion_left'],
#  ['cszsofy', 'Yassammez'],
#  ['thedailyhay', 'Truthbt75665966'],
#  ['sarahmaclean', 'XioAxelrod'],
#  ['savagegerbil1', 'pipkinpippa'],
#  ['libertycore', 'onlineet'],
#  ['libellawopener', 'Sanctionite'],
#  ['devanhewitt', 'MattWalshBlog'],
#  ['sunflower0264', 'habit_nr'],
#  ['jenbolt', 'donmoyn'],
#  ['remowilliams191', 'NationVexed'],
#  ['gwakanaka', 'DannyAraya'],
#  ['mariapadillal_', 'jessica6leal'],
#  ['photo59smart', 'wil_da_beast630'],
#  ['aflyover', 'Ta_Lon'],
#  ['groinsaw', 'saItkath'],
#  ['iamjacksmedulla', 'Iamucli'],
#  ['madinsociety', 'ireoluwa_e02'],
#  ['miniver', 'd0m1nat0r81'],
#  ['adrianj54716531', 'btb101livecouk1'],
#  ['resabi', 'whatchidid'],
#  ['mindguru888', 'AngelaBelcamino'],
#  ['pc2dc', 'HillbillyHighl1'],
#  ['_tstone92', 'TheActMan_YT'],
#  ['riversstyxx', 'bratzkiana'],
#  ['gotallygo', 'RadioEmmet'],
#  ['reuben2584', 'monchand'],
#  ['uwyphi', 'nakou'],
#  ['ad__ved', 'VrushabhGudade'],
#  ['iamrayroper', '300mirrors'],
#  ['jocknomore', 'DrJamesOlsson'],
#  ['queenphillippa', 'senorasantos'],
#  ['iclaudiusr', 'QuoteNone'],
#  ['great8outdoors', 'Megabyted'],
#  ['halifaxsampson', 'FlavioVolpe1'],
#  ['rayshep91675875', 'Historian_Steve'],
#  ['rayesunshine45', 'court'],
#  ['amyphillips_', 'radioandysxm'],
#  ['wartickwarti1', 'lawyersat_law'],
#  ['rebeibarrac', 'morningbrew'],
#  ['hhamaschiach', 'SlapperP'],
#  ['weknowyouslying', 'Karenrparry1'],
#  ['realmnchiefsfan', 'mrsmnchiefsfan'],
#  ['realjeffcesario', 'GinaGrad'],
#  ['aljosa6269', 'enn_nafnlaus'],
#  ['jerrythejunker', 'johngosullivan'],
#  ['jerrydeasley', 'Michael99061883'],
#  ['real_dguar', 'ladalavara'],
#  ['happy_cats2017', 'JaneBea5'],
#  ['metroopinion', 'loshearing'],
#  ['howardmegdal', 'MattBrownEP'],
#  ['jjenningsusa', 'VictoriaTaft'],
#  ['howmuchlonger75', 'lbdiditnice'],
#  ['vicestaff', 'PresidentToguro'],
#  ['viavoodoo', 'halljoy410'],
#  ['viapascua2', 'alexadobrien'],
#  ['peach_schnapps', 'chloeBumblebee'],
#  ['maebaesupport', 'stockguytwitch'],
#  ['wildesunshine', 'SRZ4NJ'],
#  ['margauxr15', 'tmcki62106'],
#  ['willcooling', 'Darren_Mooney'],
#  ['margoshatheking', 'Terriblexistenc'],
#  ['andreaboyack', 'MehrsaBaradaran'],
#  ['willsloanesq', 'LukewSavage'],
#  ['willvernjojones', 'Matthew82069336'],
#  ['hauntologuy', 'DineshDSouza'],
#  ['puissammy', 'audiomagnate'],
#  ['isra_mv', 'RevanX_Official'],
#  ['maufemor7', 'stonebwoy'],
#  ['mattyicefrates', 'driptripspill'],
#  ['girlbye91', 'kiaarasandhu1'],
#  ['iwebberley', 'JoosyJew'],
#  ['maxheadroomesq', 'GangHorror'],
#  ['bam_usmc', 'JulieCa61108705'],
#  ['yud87spn', 'DaynerysSwift_'],
#  ['ysufferer', 'jesusdersupajew'],
#  ['jay12543938', 'SheriffClarke'],
#  ['glynbowerman', 'MackLamoureux'],
#  ['matrixexpress2', 'enceladusw'],
#  ['bensonspot', 'Cake58357047'],
#  ['gandhirama', 'cleveland19news'],
#  ['mixosaurus', 'SuminZhao'],
#  ['lovelifethesame', 'Bloodloss_Movie'],
#  ['johnnie_torch', 'jeffrlasley'],
#  ['ge_kaitlyn', 'godlessengineer'],
#  ['gasfieldgorilla', 'craincompany'],
#  ['loyolatrue', 'JanetWe74616697'],
#  ['itsmattsherwood', 'TheArmag3ddon'],
#  ['beardownbureau', 'seriouspod'],
#  ['megb1985', 'Vic_Rollison'],
#  ['09072021', 'huffpostent'],
#  ['attertweet', 'jchervinsky'],
#  ['tymczyszyn_g', 'JoyofPhysics'],
#  ['godalcove', 'FarahnMorgan'],
#  ['_alastair', 'mckaycoppins'],
#  ['godzillagranny', 'ThisisDavina'],
#  ['travismcooper', 'KentDriscoll'],
#  ['jacksledge007', 'BlastNews2010'],
#  ['beryein', 'blackintheempir'],
#  ['poppy76339198', 'popi_ken'],
#  ['jac5connor', 'frenchstewart'],
#  ['jack929hfx', 'nicollarama'],
#  ['infobahnwarrior', 'BrianKarem'],
#  ['inescapabledeed', 'SxhillingCarson'],
#  ['goodie__27', 'ChadJessup'],
#  ['meatskies', 'MyNamesHannahx'],
#  ['intherealworld4', 'AlisonMichele29'],
#  ['jaimi_shrive', 'KimFawcett11'],
#  ['axelk', 'PopcornBambino'],
#  ['trakecarpenter', 'jbhofmann'],
#  ['kateiswell', 'AmandaE4575'],
#  ['politicalfubol', 'thekafkadude'],
#  ['king__julian7', 'EveMadLex'],
#  ['siaforreal', 'AiamKurama'],
#  ['jennamclarke', 'elliedudley_'],
#  ['heyitsheatherp', 'fijiwater'],
#  ['realitybuckeye', 'JoanieMFC'],
#  ['siliyellowfifi', 'loudthorpe'],
#  ['hopeforworldpe1', 'brittnisa'],
#  ['donnak831', 'HLNTV'],
#  ['shellys_wellie', 'notrealkev'],
#  ['dogsndemocrats', 'Tom49102098'],
#  ['katiepeslis', 'kathleenjoann'],
#  ['nikysner', 'nicoletttec'],
#  ['ravenfrench5', 'janeknowsshit'],
#  ['diydonkeyshow', 'KeithMo0316'],
#  ['izzylyman', 'biggbypetoskey'],
#  ['j3k420', '_eueucoyotl'],
#  ['kbruyneel', 'bonnie_honig'],
#  ['smutundercover', 'raincoaster'],
#  ['kevinspeaksonit', 'landaudave'],
#  ['jasoncmcbride', 'MicroFlashFic'],
#  ['pw140897', 'Life_IsPrecious'],
#  ['ira145', 'dytndya'],
#  ['iammanish3', 'neuralink'],
#  ['pixie_garette', 'azealiaishere'],
#  ['iainmacphoil', 'georgegriffiths'],
#  ['imrjpawar45', 'VtvGujarati'],
#  ['infosec_james', 'r0wdy_'],
#  ['killik69', 'HouseIntel'],
#  ['nk_johel', 'al_do_you'],
#  ['jdhyman', 'legalzoom'],
#  ...]

# %%
print("Numero comunità identificate con l'algoritmo Louvain: ", len(louvain_coms.communities))
# Out:
# Numero comunità identificate con l'algoritmo Louvain:  2462

# %%
stampa_nodi_coms(louvain_coms, 'Louvain')
# Out:
# Nodi nelle communities identificate con l'algoritmo Louvain : 18266

# %%
df_comunities_l = pd.DataFrame(louvain_coms.communities)
df_comunities_l = df_comunities_l.transpose()
string_names = ['community_'+ str(i) for i, c in enumerate(louvain_coms.communities)] 
df_comunities_l.columns = string_names

# %%
df_comunities_l
# Out:
#           community_0     community_1      community_2     community_3  \
# 0           simplyslj        decquine   realamberheard          jwl2nd
# 1      theemilydbaker  deppheardtruth       lisasays_9  chanleycourttv
# 2     legalbytesmedia        aronberg  briajasminelynn         courttv
# 3     tobiastheginger       ixchelroy      knuthaugen6         adrferg
# 4        thatumbrella        guymrdth   texasmagnolia2    juliecourttv
# ...               ...             ...              ...             ...
# 1463  Clementhillsong            None             None            None
# 1464      JackieG4111            None             None            None
# 1465       csmcdncr99            None             None            None
# 1466   inkedonculture            None             None            None
# 1467      ryanleone85            None             None            None
#
#         community_4      community_5      community_6    community_7  \
# 0         faisorler         elonmusk      GellertDepp    itsraining2
# 1       jossytweets    malinlovesshx      1800imnosey  heavy69342238
# 2     Bunmicheshire  fearfully_madee  queenoflockdown         nypost
# 3        DrProudman     cherienbenni          Bee75Mo  witch_natural
# 4     mensurvivetoo      ghostinkiss        CuteCrook       Newsweek
# ...             ...              ...              ...            ...
# 1463           None             None             None           None
# 1464           None             None             None           None
# 1465           None             None             None           None
# 1466           None             None             None           None
# 1467           None             None             None           None
#
#       community_8      community_9  ... community_2452 community_2453  \
# 0       stirgussa      SchizoSkits  ...       mr_bet01   mybizandlife
# 1       __towanda  robert__leonard  ...           None           None
# 2      Eve_Barlow     martinsrosie  ...           None           None
# 3     alargue4rfc       bnopeace69  ...           None           None
# 4      finwinston      DaaniMonday  ...           None           None
# ...           ...              ...  ...            ...            ...
# 1463         None             None  ...           None           None
# 1464         None             None  ...           None           None
# 1465         None             None  ...           None           None
# 1466         None             None  ...           None           None
# 1467         None             None  ...           None           None
#
#      community_2454 community_2455 community_2456 community_2457  \
# 0     thetalentguru          z2htv  socialrobbers     stoptechy1
# 1              None           None           None           None
# 2              None           None           None           None
# 3              None           None           None           None
# 4              None           None           None           None
# ...             ...            ...            ...            ...
# 1463           None           None           None           None
# 1464           None           None           None           None
# 1465           None           None           None           None
# 1466           None           None           None           None
# 1467           None           None           None           None
#
#      community_2458  community_2459 community_2460  community_2461
# 0     aylinaydindal  averagebeing99  lekucciglobal  faceswaponline
# 1              None            None           None            None
# 2              None            None           None            None
# 3              None            None           None            None
# 4              None            None           None            None
# ...             ...             ...            ...             ...
# 1463           None            None           None            None
# 1464           None            None           None            None
# 1465           None            None           None            None
# 1466           None            None           None            None
# 1467           None            None           None            None
#
# [1468 rows x 2462 columns]

# %%
df_comunities_l.to_csv("data/comunità/coms_louvain.csv")

# %%
df_comunities_l.shape
# Out:
# (1468, 2462)

# %% [markdown]
# -----

# %% [markdown]
# ## LABEL PROPAGATION <a id = 'labelprop'> </a>

# %%
labelp_coms = algorithms.label_propagation(g)

# %% [markdown]
# ### Valutazione interna

# %%
print('Sovrapposizione communities identificate con algoritmo Label Propagation:', labelp_coms.overlap)
# Out:
# Sovrapposizione communities identificate con algoritmo Label Propagation: False

# %% [markdown]
# ### Valutazione interna

# %%
coms_evaluation(labelp_coms, "Label Propagation")
# Out:
# --------------------------------------------------------------
#  Valutazione comunità ottenute con algoritmo Label Propagation
# -------------------------------------------------------------
#
# - Copertura nodi: 1.0
# - Modularity: FitnessResult(min=None, max=None, score=0.6554268112978178, std=None)
# - Numero Nodi: FitnessResult(min=1, max=449, score=3.8682761541719612, std=12.589233109841164)
# - Avg Distance: FitnessResult(min=0, max=3.173520521794464, score=1.1999321205247506, std=0.30227742587640266)
# - Conductance: FitnessResult(min=0.0, max=0.9166666666666666, score=0.20283221840226986, std=0.23559966822192818)
# - Avarage Node Degree: FitnessResult(min=1.0, max=3.8797327394209353, score=1.2126632453236696, std=0.30333219402514744)
# - Internal Edge Density: FitnessResult(min=0, max=2.0, score=0.7984670763538406, std=0.2751526801342246)

# %%
labelp_coms.communities
# Out:
# [['kkatbat412',
#   'davidterrace',
#   'snackbyteso1',
#   'llivv0123',
#   'comteberenguer',
#   'mintystays',
#   'MeekMill',
#   'crobb203',
#   'mackette52',
#   'Emmy_Jiyane',
#   'benkesslen',
#   'sosofiefatale',
#   'gemrosep',
#   'cojamielok',
#   'kaptainrblx',
#   'upinct',
#   'spekshn',
#   'clarissakay10',
#   'emma76history',
#   'dinahendler',
#   'here4thetearz',
#   'jamiediann003',
#   'lil_skyscraper_',
#   'nerdynattyg',
#   'lizbethne30',
#   'LilienStastna',
#   'thesunshinekey',
#   'comatose_almost',
#   'skkyyyyyyyyyyy',
#   'fettigator',
#   'roxyshores',
#   'shuckleshells',
#   'jamesydraws',
#   'mommypanetta',
#   'jrosengard',
#   'dasilvamarye',
#   'rottentomatoes',
#   'lumberlaw',
#   'ais1ing',
#   'thenerdreport',
#   'caityneill',
#   'niermanjoe',
#   'turkbros',
#   'jdlmediaco',
#   'donutclubsugar',
#   'systemicdunking',
#   'trundlesploot',
#   'simplyhappysm',
#   'femininityfawn',
#   'planetmonkie',
#   'dockedalpaca',
#   'masterpt',
#   'asadorasummers',
#   'magmojave',
#   'amandamarrie1',
#   'lorioct',
#   'damseldisgusted',
#   'spacekidette',
#   'fgirlofjustice',
#   'ephramstcloud',
#   'lonestarmomcom',
#   'nlwisco',
#   'solequeen2020',
#   'libleigh1',
#   'itsmarttayall',
#   'mrs_hopewhite',
#   'marian_lynnn',
#   'laurenrock',
#   'TragosLaw',
#   'bruceachterberg',
#   'bobos9021',
#   'mangycoyote73',
#   'jamesfromcourt',
#   'togekirst',
#   'vradke',
#   'catlaw05',
#   'whoismrrobot',
#   'soounsuh',
#   'factsoverbs',
#   'debsappy',
#   'secretsquizzer',
#   'jennamarie227',
#   'itza322',
#   'atesshz',
#   'bee75mo',
#   'MattJardin',
#   'britfree',
#   'heyitsgloriaw',
#   'highfiveg',
#   'thevampirerose',
#   'flirtynikka',
#   'tomr15288961',
#   'thatnataliecole',
#   'kay_2405',
#   'skoobee63',
#   'gellertdepp',
#   'maria_summerz',
#   'bronk34',
#   'corey_tailorr',
#   'danielle_est98',
#   'scribbleburger',
#   'nouzhanouzha05',
#   'Thoughtful2030',
#   'goodgolly247',
#   'pollylogic',
#   'kivers1975',
#   'sub_boo',
#   'renazing1',
#   'greenmonkeysoup',
#   'csa_original',
#   'novatempest_',
#   'klaus29131',
#   '007londongirl',
#   'pedrett',
#   'kimberlyconroy',
#   'pv_lawyer',
#   'formerpr',
#   'darklordslush',
#   'dannytheukman',
#   'raphaelmontero',
#   'NatetheLawyer',
#   'cpu_tech0110',
#   'jane_k',
#   'canadiankid095',
#   'ms_blondeasian',
#   'ultimateone',
#   'rvanova01',
#   'nataliekellyj89',
#   'directorevie',
#   'ministry_magic8',
#   '_angeled_',
#   'leannen04',
#   'butterbeanbill',
#   'life0fhigh707',
#   'dropbox',
#   'hachimamatv',
#   'frailnbedazzied',
#   'brelana88',
#   'aitchquex',
#   'afaprincess3101',
#   'flashpointsmed',
#   'zimmbiogal',
#   'sweetishblonde',
#   'constantlydizzy',
#   '_bre_lemus_',
#   'micwalden',
#   'pearljam',
#   'pammy77',
#   'camjphillips',
#   '1ca6',
#   'missfalv',
#   'lilsunshinesez',
#   'optistrong',
#   'lesliehaugen',
#   'nyrex_x',
#   'tmlevick85t',
#   'snowhitedriftd',
#   'nerdlecca',
#   'ant_sam54',
#   'teamyoutube',
#   'MaeWhip',
#   'barbsmar',
#   '0iivie',
#   'lawtubefashion',
#   'OneSickPup69',
#   'rjs11123',
#   'hhillmanlibrary',
#   'emmacarnell9',
#   'lawschoolgrit',
#   'darcycharles708',
#   'restingsithface',
#   'drgn_',
#   'ellejayem5',
#   'moralecompass',
#   'acstansyou',
#   'lovemichellexox',
#   'nicolegmp',
#   'perrypoppinz',
#   'bhaskarmc',
#   'regardssuki',
#   'freckledgirl426',
#   'brittanyy_4nn',
#   'littlemsrobbie',
#   'Schwaz00m',
#   'absterwales',
#   'vswizzle36',
#   'kyduiguy',
#   '_talolie',
#   'mdvolker',
#   'saifed99',
#   'nabilaburr',
#   'rosiepilsbury',
#   'neneisme',
#   'murray__sarah',
#   'druannawow',
#   'ninterit',
#   'Sarah4Justice',
#   'jglezpr',
#   'resistimpulse',
#   'jill77354601',
#   'mousears7',
#   'chelsrrstiv',
#   'pacellitroy',
#   'geekbrenda',
#   'charlotteracher',
#   'clivetheunicorn',
#   'paleogranny58',
#   'parlousbitch',
#   'urshy74',
#   'lamonique3',
#   'PhilMitchell83',
#   'forcefischer',
#   'ghostie_22',
#   'maryschild33301',
#   'ajasmine0715',
#   'acltxmt',
#   'leeann_ky',
#   'morgensmuede',
#   'sydneyadmirer',
#   'elles_21',
#   'foldsxs',
#   'govchad',
#   'kk2ndlaw',
#   'disneywitch22',
#   'andrea_bellamy',
#   'djliquiddrip',
#   'htebazile_a',
#   'nectarpeppervt',
#   'theashleyvrana',
#   'myerske',
#   'duchessofyinz',
#   'amyfros12690046',
#   'daphnesargent',
#   'kimwmoonchild',
#   'thelawkoala',
#   'deeayepee',
#   'almightea100',
#   'clalaleck',
#   'alison_diane',
#   'alexand51565083',
#   'bblatt11',
#   'pablo77110484',
#   'erraticopinions',
#   'ambushjj88',
#   'thebehaviorguy',
#   'professortenshi',
#   'lori_dicola',
#   'heater_zachery',
#   'daniellespoview',
#   'nosoyayamagucci',
#   'armarnaforbes',
#   'a_amanda_gomes',
#   'ADarkCuriosity',
#   'adamcrigler',
#   'hamrhedbear',
#   'redzesty11',
#   'jdah2022trial',
#   'vettielou',
#   'justice4theline',
#   '0xmelb',
#   'deltanila',
#   'kitasstrophy',
#   'getinthewordout',
#   'yongsuhh',
#   'beth_luciUSA',
#   'maidment_zena',
#   'wakeyourvintage',
#   'overthebeaaan',
#   'louise75997969',
#   'hoeglaw',
#   'midsearch',
#   'theumbrella',
#   'allthemoneys',
#   'shortbusdave86',
#   'teslianu',
#   'whatsthecraic1',
#   'JC4EVERYONE',
#   'lindaoc_dk',
#   'WildeRochester',
#   'teejayventura',
#   'tatey61',
#   'x_Katari_x',
#   'texas__nana',
#   'umbrellaacad',
#   'FloridaMan4040',
#   'coffeeloverpdx',
#   'justice4line',
#   'jessiramey_',
#   'megynkelly',
#   'denisecastlung1',
#   'flowender11',
#   'browney50081021',
#   'rachella86',
#   'realziggyflo',
#   'legalbytesmedia',
#   'megmafia',
#   'depplyhaiiows',
#   'kytavern',
#   'chrysaliscreate',
#   'xmrxzerox',
#   'jodylibka',
#   'yusufnim',
#   'wittertainee',
#   'kaelhyun',
#   'whereisbp',
#   'dianagurrola10',
#   'nickixdestiny',
#   'msmelodius',
#   'Traceonbase10',
#   'saltysusan_',
#   'shareenrobson',
#   '60mins',
#   'crazymomma007',
#   'kaetarturo',
#   'teresalolvera',
#   'mskatiekate88',
#   'Clarahereiam',
#   'marsupial_gamer',
#   'nettytemp',
#   'jaeviad',
#   'icklepickle',
#   'natisashupp',
#   'sugabuga16',
#   'kyliesm29507820',
#   'forestindie',
#   'johnhardy',
#   'phoenixdelamerr',
#   'deenag33',
#   'ianrunkle',
#   'lyssalexandru',
#   'bbwriterchick',
#   'beansandwaffles',
#   'linzernic3',
#   '1atomikpunk',
#   'frenchyinlondon',
#   'iamcefoley',
#   'kellieeeb3',
#   'viclaws2013',
#   'vernacularvixen',
#   'andreaelisii',
#   'mcdizzle17',
#   'tragoslaw',
#   'adayfulloffun1',
#   'alittlebitofsp5',
#   'dollar180998',
#   'lilone8377',
#   'hcampbell419',
#   'mbogie34',
#   'faranbalanced',
#   'hnnbnn88',
#   'unabashedgator',
#   'synyste84987177',
#   'marterinn',
#   'dorkamongus2',
#   'didulahatangala',
#   'baileysarian',
#   'spat64',
#   'cindyelise',
#   'bigleaguetj',
#   'LawTalkWithMike',
#   'whatifanynani',
#   'v_Ahmadz',
#   'mjbenedicto',
#   'tiggetalks',
#   'donnaeofsdakota',
#   'CreatER1N',
#   'ruthmariebutler',
#   'thisismycredo',
#   'biosnap',
#   'its_natacha',
#   'NiermanJoe',
#   'evelynsvision',
#   'msfwhat',
#   'kimberlykurz2',
#   'theumbrellaguy',
#   'junespiders',
#   'danceinline',
#   'JuleneRenee99',
#   'samilouise1206',
#   'rreddingtn',
#   'kumar_b1',
#   'deniseknows1',
#   'FaranBalanced',
#   'lawtalkwithmike',
#   'red___shoes',
#   '_debbieo_',
#   'assimp333',
#   'natethelawyer',
#   'iantildeath',
#   'no_onei5per4ect',
#   'capitolninja',
#   'uncivillaw',
#   'simplyslj',
#   'tallulah_bear7',
#   'left4beach',
#   'anotherothernic',
#   'loreslanguage',
#   'ssolorio77',
#   'el_caracara',
#   'thecanongurl',
#   'AmyPudds_',
#   'snoozells',
#   'rdubhall',
#   'sitikasim',
#   'jujube1431',
#   'simiaexspiravit',
#   'bluemedia68',
#   'jennder',
#   'ja_bittersweet',
#   'johnny1depp',
#   'thismisspenny',
#   'luly_ryu',
#   'hope_kailani',
#   'Callie_G29',
#   'spideyhypnosis',
#   'CornyCivilian',
#   'tess_flycrow',
#   'majaseif',
#   'randomindy',
#   'marisas1985',
#   'sukisueali',
#   'detectiveseeds',
#   'martitaromo',
#   'cfold2',
#   'emilydbaker',
#   'jemzzjulie',
#   'EnaCress',
#   'luxerina1',
#   'benzai_daegan',
#   'saya__kennedy',
#   'laura_llb',
#   'stace_actually',
#   'laurennfarmerr',
#   'vintagegirl1963',
#   'autumn_ivy_',
#   'roxyred2006',
#   'jasnakholin',
#   'carlzmeister',
#   'atomicrougee',
#   'whitlina',
#   'its_o_kk',
#   'gunbunny16',
#   'lozunicorn',
#   'sweetkritter',
#   'missvicious86',
#   'pmgsmbl',
#   'libhalps',
#   'daveforgiveness',
#   'the_mermaidian'],
#  ['badgirl_drone',
#   'newfypearl67',
#   '12onefortyfour',
#   'jentheriot',
#   'keepcalmpersist',
#   'jeremydday1',
#   'cheryld59995761',
#   'healthy_pooper',
#   'psychic_knife',
#   'barbaracallah',
#   'thekwomanrules',
#   'snoozlessnow',
#   'raine_swords',
#   'niviettina',
#   'hear_us_roar_',
#   'kathyprayforme',
#   'charles59232810',
#   'kennypowell55',
#   'wearenot_amused',
#   'koiosronin',
#   'loves_dandelion',
#   'broohaha13',
#   'aquarius_gypsy',
#   'thejulievirgo',
#   'hookssharon68',
#   'rosesandlillie2',
#   'jyotiar44085686',
#   'mikkovsviinikka',
#   'laurendamrich',
#   'ilike_dontlike',
#   'jasonhawke16',
#   'lawteoyer',
#   'famaay',
#   'missa_beet',
#   'juliafarmakidis',
#   'pinkubara',
#   'tobiastheginger',
#   'leximi84',
#   'whoiwannabek',
#   'gameon_will',
#   'belle_epoque86',
#   'arvindsharma007',
#   'albanuvo',
#   'imanimima',
#   'darrenimms',
#   '1crazeeturtle',
#   'toproyalmoments',
#   'rocknrollhobo',
#   'podrandomly',
#   'duchessofnewam',
#   'escalationc',
#   'darknessexposed',
#   'dianeg451',
#   'grannysouthern1',
#   'amyt36168833',
#   'alivingwell',
#   'minxiv7',
#   'diannebkrause1',
#   'ellenspeybrouck',
#   'inqstvmuse',
#   'parledespirit',
#   'kittybravofan',
#   'zxvvxzofficial',
#   'scottishlass84',
#   'authetnic',
#   '_franshon',
#   'morrowmoreno',
#   'peaceheartjava',
#   'kissycatclaw',
#   'gary995685151',
#   'beragon',
#   'barbarageng',
#   'gangster_times',
#   'summerb74746599',
#   'libsge',
#   'c0ttt0n',
#   'jdn031671',
#   'thaddeusp62',
#   'fatpapicreep',
#   '_drnichols',
#   'methylphenikate',
#   'abdul_robin',
#   'saitamasinceaug',
#   'twinks_ks',
#   'miss_laura_82',
#   'hazrdrosenyc',
#   'rozecrocs',
#   'shesshie2',
#   'traceybaby',
#   'stoner420peace',
#   'patrici42763932',
#   'matjustchillin1',
#   'truthisall1',
#   'brunocandce',
#   'kat_strutt',
#   'kazumi97732713',
#   'irenevautour',
#   'soulsenlighten',
#   'katthewonk',
#   'mary_mullarkey_',
#   'chaffee7bruce',
#   'fatmaxsa',
#   'ticketytock13',
#   'kvconner',
#   'ambuseruser',
#   'thmcarin',
#   'ne_ne_nay_nay',
#   'druttizen',
#   'edithpsrobert',
#   'strangelove101',
#   'midgetmummsie',
#   'adhdhurricane',
#   'basklootwijk1',
#   'katpatt29252996',
#   'traumatruecrime',
#   'evil__exists',
#   'shesaz',
#   'alexandrawakens',
#   'kwasi3000',
#   'mattallenco',
#   'dynastyaghughu',
#   'audaciouslife',
#   'nattywatty76',
#   'natnickidadun11',
#   'savida78',
#   'ladybird518',
#   'qab5znyd5ym81',
#   'nicolaxoxo1',
#   'nancyparadis66',
#   'eilatan87',
#   'chicky_463',
#   'jayceesunsetbk',
#   'cajun4evr',
#   'multipod74',
#   'annatimmerman3',
#   'paulabreuks',
#   'nctrnm',
#   'joshuamcgeesr',
#   'hoodiehinsch82',
#   'bombshellbakes1',
#   'kingben_tv',
#   'emilyblunt222',
#   'nspake',
#   'candyca47797626',
#   'misskaesayso',
#   'alexatbetsy',
#   'colbyone23',
#   'laperkaliloh',
#   'streaming4ddict',
#   'eytonshalom',
#   'shaunna_harper',
#   '1992nll',
#   'newsbite_usa',
#   'halo6181',
#   'giaguacamolee',
#   'ariya_lanox',
#   'nippi25james',
#   'doughbones',
#   'dolores86458182',
#   'oc_hiddentruths',
#   'tiabam67',
#   'paulus37981356',
#   'lindahlepou',
#   'mrswoodsbe',
#   '2l8icu',
#   'artbyakira',
#   'classnotcrass',
#   'islandthund3r',
#   'kendalmintcakex',
#   'positiv44884723',
#   'marissajweeks',
#   'sevlenty',
#   'arielavianello',
#   'browneyedlassy',
#   'wilsonzfam',
#   'ahngreatlife',
#   'urbansweetspot1',
#   'krosp_donna',
#   'imheretotalktou',
#   'jace2020',
#   'marykatherine70',
#   'angietweets12',
#   'upandadamlive',
#   'ashleykristen64',
#   'jackieb_mer13',
#   'annamaria290858',
#   'lorealusa',
#   'esmn0',
#   'youtube',
#   'lovintexas78612',
#   'makeup_gamer13',
#   'have2doxies',
#   'priceless7777',
#   'subtropixal',
#   'joonpearllondon',
#   'upwhitey',
#   'oldenbsi',
#   'imkeithappen',
#   'agnieszkaanton6',
#   'orderofthedimen',
#   'boranmfd',
#   'josie70423198',
#   'emmastrange2711',
#   'mi3jules_xo',
#   'r4vi4rt',
#   'ramasscreen',
#   'sunstella76',
#   'monique67350483',
#   'kirstyrowden',
#   'paulmcd85988004',
#   'blackdiamondz86',
#   'debracu52034075',
#   'Justice4Line',
#   'nc_stanhope',
#   'lbgdesigner',
#   'sherry_dorion',
#   'mariaangel367',
#   'newswestside',
#   'jensiphone',
#   'ingeborgkk',
#   'trisha_silveri',
#   'crimefranky',
#   'pelerin58580892',
#   'tristanludlow10',
#   'retrovgamer',
#   'cloudnikki',
#   'aaronnetsky',
#   'spicytea13',
#   'gianeshri',
#   'spiritmoonjewel',
#   'catntexas',
#   '80sdepphead',
#   'speakskevy',
#   'agamingmoment',
#   'elizabethborne6',
#   'nerd_tremble',
#   'dianareina67',
#   'spankyluvsit',
#   'mannyismynamehi',
#   'kittibee',
#   'tlsha',
#   'ttmw777',
#   'urbanpopfan',
#   'kelly17809230',
#   'riccinicolette',
#   'emmacharles9',
#   'kristie_holiday',
#   'lucythewhite',
#   'tiernan_joe',
#   'stokesaparicio',
#   'noopinionnewsn1',
#   'natalieritchey2',
#   'mjhopeful',
#   'nastaja1',
#   'tssuppository',
#   'melomaniacred',
#   'megeathpolitica',
#   'sadittymommy',
#   'melanie_lauren',
#   'maryycherryy',
#   'cj_blizzard',
#   'big_d_rants',
#   'kramon83',
#   'pquate',
#   '_3treats',
#   'francisco_tech_',
#   'imathew67',
#   'drortmeyer',
#   'loving_pink',
#   '_smprsn_',
#   'manontrembla',
#   'llinda_w',
#   'comptongoddess',
#   'jgc2004',
#   'audrey_swafford',
#   'tytoguardian',
#   'demottdanielle',
#   'lisajeffreys12',
#   'morgannaanna',
#   'olivialuvsshoes',
#   'suns_jewel',
#   'katknox12',
#   'covidfighter1',
#   'splatoonrajrouj',
#   'terrysharespics',
#   'riniedegroot',
#   'saraljordan',
#   'angel_dulce7',
#   'unravelingcrime',
#   'hellsspawnworld',
#   'what_big_eyes',
#   'dubbeljapp',
#   'minxy_one',
#   'juliewi01978654',
#   'jeangray46',
#   'amitsharmalie',
#   'themadametea',
#   'oumalahmed1',
#   'witeklonski',
#   'discogreenthumb',
#   'gypsysilver',
#   'ahhahahaaaaaa',
#   'gabrielayareliz',
#   'hankcookierich',
#   'blondeapetite',
#   'jamboosdad',
#   'roccohowat1',
#   'angie98933860',
#   'dee92626053',
#   'merakilous_ind',
#   'joseph7173',
#   'melika__1',
#   'sweetestsands',
#   'nutansi66936934',
#   'roots4days',
#   'kenijefferson',
#   'amstillion',
#   'kaseyja11633178',
#   'princessleah444',
#   'lizzscurvs8',
#   'wereoffended',
#   'jostrofsky',
#   'iron_celtic',
#   'rosey_dobbs',
#   'midnitamerican',
#   'ouudiee',
#   'janetsnews2022',
#   'spaceweasel',
#   'agneswax000',
#   'ginnikilife',
#   'hisrazzleaces',
#   'humblescotty',
#   'erikarasmus',
#   'rainna_j',
#   'jdknight78',
#   'jackthetesla1',
#   'karrieat',
#   'catmanicure',
#   'mmemnoch',
#   'raissadevereux',
#   'karengulley',
#   'pier_parker',
#   'max62153089',
#   'artturitech',
#   'just_jonoe',
#   'nightbaneaus',
#   'mwatwan',
#   'cluelessrogue',
#   'brandonrileyesq',
#   'sassyliltutus',
#   'adriejessicah',
#   'quendrita',
#   'sadtitansfan',
#   'randoma45785036',
#   'cookiecataldo',
#   'arianzew',
#   'shannadugan',
#   'catbiguns',
#   'angievanderbur3',
#   'samarasmile99',
#   'naomiwarne',
#   'conniemarash',
#   'laurast51362949',
#   'lazykidzzz',
#   'nj_fadwa',
#   'johnnysrelative',
#   'ofdresistance',
#   'wvaspartan',
#   'spunkiesteffie',
#   'previatarago',
#   'let_it_be_77_',
#   'magaposse1776',
#   'dpdvcvmvu3rxulb',
#   'soulanba',
#   'key13673237',
#   'absalonlord',
#   'losstar22',
#   'littleponies',
#   'capttokki',
#   'sparkyroots',
#   'yellowflashguy',
#   'marshare',
#   'rexsterlinglive',
#   'naominishikawa',
#   'te11ta1eheart',
#   'shastr6',
#   'dandakich',
#   'drapert1999',
#   'maryamatif627',
#   'tuesdaywish',
#   'thetarot_knows',
#   'saphi114',
#   'dianebizier'],
#  ['Iromg',
#   'SchmoJosey',
#   'javanoob2',
#   'Butterflies949',
#   'Tempora80335786',
#   'deppheardtruth',
#   'FormerPr',
#   'xemopeachx',
#   'Wasabi_Ciri',
#   'gowiththeflow81',
#   'vanderrwaals',
#   'HBSoulStains',
#   'Nessj958',
#   'LokeshSathish5',
#   'Starskreem1982',
#   'Jenn_seger0131',
#   'FatihOz82970331',
#   'janparavan',
#   'bb17fanatic',
#   'Azille93480483',
#   'LuckyLo59037265',
#   'upbeatdata',
#   'TKadotani',
#   'Divyansh1999',
#   'JasonLahme',
#   'Evelyan94',
#   'webb0412',
#   'Mesa_Brown',
#   'Jfeb_ox',
#   'brxhyl',
#   'Panfulies',
#   'AnnaVersteeg',
#   'RobinYvarra',
#   'abendo1',
#   'theevilleaper',
#   'ADS_Ami',
#   'Ernie2322',
#   'BhaskarMC',
#   'TheHelennofTroy',
#   'nvrluvanyonelse',
#   'calzonagreys_',
#   'st49295602',
#   'Burt6Gill',
#   'jadeizspam',
#   'WillowBlossom08',
#   'Evelynm57864806',
#   'strangeharbors',
#   'itsgabrielleu',
#   'pauliereynolds',
#   'abs7876',
#   'ellie_ellie666',
#   'corinne_steele',
#   'AndrewR506',
#   'nevereverdoit',
#   'jen_maran',
#   'amandadecadenet',
#   'WherelsMySheep',
#   'grtamericanovel',
#   'Elisa_Cabral',
#   'Seafarerbaby',
#   'Missa_Beet',
#   'lizel303',
#   'theonlyju1',
#   'Genxpunk69',
#   'Kugrox',
#   'BonneAphrodite',
#   'lovetodaydream',
#   'VGladimar',
#   'BigPissGuy',
#   'KL87120899',
#   'MindOverHeart11',
#   '13844502x4x',
#   'Dette2323',
#   'AilsaBristow',
#   'kayleig77506547',
#   'kaimiakid96',
#   'cpsuk',
#   'TonyaSteiger11',
#   'teamdepp_',
#   'Ego_death18',
#   'MHaywood2468',
#   'BangaaaX',
#   'JamesHerdmanxD',
#   'DeppHeads',
#   'arianaxlove64',
#   'shrutid203',
#   'veennuhs',
#   'LexiBananas',
#   'dsmblackrose',
#   'francobianco',
#   'InJDWeStan',
#   'msjenniferjames',
#   'emurph42',
#   'vicky_okonkwo',
#   'FionaCh01958269',
#   'MatTheExBot',
#   'MeganRG10',
#   'sussexgirl3',
#   'John72805238',
#   'paulameninato',
#   'Nainaloo',
#   'BriThibodeaux',
#   'PopcornedPlanet',
#   'TryingNotToLook',
#   'Onthefritzie',
#   'morningwouldx',
#   'nwl88444048',
#   'DarrenCHoffman',
#   'DownsLarche',
#   'Roslyn715',
#   'AlexKiddo9',
#   'Fifthwave6',
#   'gemmeri1',
#   'incomparable_ss',
#   'damirra1910',
#   'DollyArthur_',
#   'StaceyMagnuson',
#   'AHumbleTalent',
#   'overexposed91',
#   'rosiecannonBall',
#   'Jennife58372495',
#   'AaronGriffin0',
#   'Wendy15817401',
#   'IrinaPloba',
#   'yoabbaabba',
#   'twarner50',
#   'justicefor_ah',
#   'i_am_chaos_1',
#   'TalkTV',
#   'marleyg13ems',
#   'Peachyfruitcake',
#   'AmberTurdLies',
#   'tgustincic',
#   'CastanzaGeorgie',
#   'MaryCanady4',
#   'Mariska',
#   'AlfredTheAbsurd',
#   'ica_baby_la',
#   'AndrewRhinier',
#   'slopedsleep',
#   'paul_smudga',
#   'Dominodomino19',
#   'BrickLili',
#   'Komal_Prasad96',
#   'Soraya371',
#   'HeatherHart7717',
#   'KRhaeMom',
#   'extremely_tired',
#   'Nancydariella',
#   'greeknemesis1',
#   'MarilynMansonU1',
#   'kouroshmoini',
#   '1GrammyJill',
#   'Aeone99',
#   'Truthndarehere',
#   '__HAARV',
#   'Blondielibra',
#   'hodlocache',
#   'Jemandcats',
#   'Losersan',
#   'cat_piller',
#   'YgritteVt',
#   'MacsEsq',
#   'StreetsOfRaith',
#   'SOOJINBAE123',
#   'Lil_Misstake',
#   'quiltsavvy1',
#   'SandyAtkins_',
#   'witch_natural',
#   'PamelaMcCaffer5',
#   'NJRugbyGrl',
#   'WishesMacleod',
#   'carmarie1979',
#   'NickelsJessica',
#   '80sDepphead',
#   'AnnLogue',
#   'wanqianz1',
#   'truthforamber',
#   'AmyP59111068',
#   'mar7729',
#   'star03c',
#   'soa_bia',
#   'chuujisoolia',
#   'HalalalalaBOOOM',
#   'ibrokethebong',
#   'KevinRashidi',
#   'owenjones84',
#   'Crofty78185826',
#   'youowetheworld',
#   'KassandraSeven',
#   'DMW9699',
#   'Angel_Devil982',
#   'nha715',
#   'LadyNadiaEssex',
#   'realdavidgrace',
#   'SAmRAis6',
#   'fuklames99',
#   'KaftanMac',
#   'nursenic8',
#   'peripatetics',
#   'CounsellRenae',
#   'PatrickJeanPhi3',
#   'jlooney2',
#   'NicholeRenee1',
#   'LuckyAbiP',
#   'Rafaela65096325',
#   'PaulaSchultze1',
#   'GironZeus',
#   'upseteyess',
#   'MusialFan73',
#   'MastersonsDoll',
#   'Annalee_Perez',
#   'ArvenKateBlack',
#   'swagbug33',
#   'tkscoggins',
#   'depphead_savvy_',
#   'memehoe50',
#   'truth_karl',
#   'QualiaRedux',
#   'deeb_thee',
#   'osheblows',
#   'Footballholic89',
#   'PaolaAuditore',
#   'jololikejazz',
#   'Bennyt_92',
#   'honeygnomes',
#   'Sparrow0hawk',
#   'KrispKiwi',
#   'RiaBeevor',
#   'TaraKilshaw',
#   'Luisdcv',
#   'ingredientsmeow',
#   'ashjswan',
#   'Victori17400403',
#   'hope_balco',
#   'nanana_987',
#   'skyaswriter',
#   'HStoreyCarrasco',
#   'ThomasB10275700',
#   'GillianFortune',
#   'lawyercoachuk',
#   'DCAKdarling',
#   'Bombshellbakes1',
#   'neo_valkyrie',
#   'JDvsAH',
#   'MrNoNameToYou',
#   'lucy_carling',
#   'minhaltaher',
#   'alexizolag',
#   'couldwellbe',
#   'OceansGreen222',
#   'jigglebugs',
#   'goldenfreckles3',
#   'HTinajane',
#   'mondipun',
#   'Successdrive9',
#   'londonayerish',
#   'nishads_44',
#   'duchessmeghanx',
#   'NoodleNatty',
#   'Monicao20909532',
#   'LeslieM12018144',
#   'GW439321702',
#   'Shantel02480571',
#   'tjeffer35270772',
#   'SheBePamella',
#   'hawaiianvalent',
#   'LauraSSFreitas',
#   'jacxpearl',
#   'Alyssa_Milano',
#   'KnightressH',
#   'Fido64261825',
#   'HashtagShrid',
#   'lilylysandra',
#   'buzzy009',
#   'KayteeT1',
#   'GreenKayArt',
#   'Change',
#   'LilithRising1',
#   'x_keepyourbliss',
#   'JulieWi01978654',
#   'AlexJam91754067',
#   'mellodiesmoon',
#   'practicallykara',
#   'LadyDetectives1',
#   'planetaintshit',
#   'korineeeee',
#   'DaisyDoardo',
#   'penguinchemist',
#   'subastraI',
#   'rationalhuman15',
#   'Aijalon323',
#   'Makalicioussss',
#   'Kelly_K_9',
#   'Yousavewithus',
#   'AshleyJudd',
#   'Agent_Scarn420',
#   'curlyalicia1',
#   'ixchelroy',
#   'Gypsy_Visions',
#   'skirmley',
#   'JohnnyIsDead_',
#   'TrevorMisc',
#   'HappyRogue_121',
#   'thewayineverlie',
#   'pardonsentients',
#   'Mrs_Nutbridge',
#   'MrRagnarac',
#   'sassy_evee',
#   'JohnPow62265340',
#   'DontFwMee',
#   'RWTaylors',
#   'emmaIeighxo',
#   'IamDawnWebb1',
#   'Stephanyxoxo87',
#   'keepitrealcmon',
#   'SophiaBush',
#   'CandidToAFault',
#   'trinamichellew',
#   'MiraSorvino',
#   'sydcmorse',
#   'MimiGlandon',
#   'pizzakatzen',
#   'melisah100',
#   'TashOldershaw',
#   'sicgirl1078',
#   'r_e_davidson71',
#   'KaiserVallejo',
#   'CcVator',
#   'RavalKanhai',
#   'onlyonemera',
#   'VanieciaFergus1',
#   'AnastasiosPach1',
#   'andressaholiday',
#   'VixcorOmega',
#   'mellymellz____',
#   '2018_Bela',
#   'blancagis2',
#   'lilimadsn1965',
#   'Galaxy_RL_',
#   'White3Toy',
#   'PR1NCESSD10R',
#   'guymrdth',
#   'teresamarkos',
#   'kymom07',
#   'verysimple',
#   'Llani90',
#   'mynameisCHANTE',
#   'zevdain',
#   'doraspenlows'],
#  ['mattjohnsonnews',
#   'janna_bastone',
#   'gafamilylawyers',
#   'janyegwynne',
#   'mghnn_jn',
#   'carollbrady',
#   'villalonalaw',
#   'KeiranSouthern',
#   'partygoddess',
#   'ZeldalaGrangeSA',
#   '_a_woman',
#   'lakotadashing',
#   'pheramuse',
#   'kathrynaegis',
#   'anyaglows',
#   'borghardtlaw',
#   'daly_anna',
#   'lucia_e_qui',
#   'sashacairesse',
#   'brithibodeaux',
#   'tmgallegos_',
#   'Tallie_Anne',
#   'centaur1207',
#   'slickxnickk',
#   'kellywhola',
#   'joonbug12345',
#   'kimberly1261',
#   's_h_e_a_t',
#   'zozo1521',
#   'usdiplowife_ish',
#   'courttv',
#   'amandas56969475',
#   'lcingrana',
#   'taconurse13',
#   'donmc01195764',
#   'lorah519',
#   'brandi9821',
#   'whotrendedit',
#   'blujayk',
#   'chanel732',
#   'ljxk7',
#   'matthewtmangino',
#   'b_wlle',
#   'charmin',
#   'vinniecourttv',
#   'joycourttv',
#   'theplannersclub',
#   'JoshuaGeorgia',
#   'kinglosoul',
#   'juliacourttv',
#   'maryspiky',
#   'adrferg',
#   'petunia1tgwy',
#   'tedcourttv',
#   'lulatrixiebelle',
#   'Gingereed',
#   'burntduck2',
#   'megansmiles',
#   'b3xbentley',
#   'dyson',
#   'toolegit2quitr',
#   'mercylaw_ga',
#   'webnewsproducer',
#   'jeancasarezcnn',
#   'procras05110869',
#   'brebea11',
#   'milenazp_',
#   'CindiMartin57',
#   'mike_simmonds_',
#   'lizziecundy',
#   'ashleycourttv',
#   'comedyfan1981',
#   'cranky_tracy',
#   'norcrosslaw',
#   'Windali',
#   'nickjax222',
#   'courttvuk',
#   'juliecourttv',
#   'chanleycourttv',
#   'lola6307',
#   'bydeaddude',
#   'imrachelschmidt',
#   'diealoguepod',
#   'sladebaker',
#   'simonereyes',
#   'creep1twe1rd',
#   'leahburke111',
#   'thegrumpychunk',
#   'nurmiunchained',
#   'annembremner',
#   'mnviper',
#   'emz_2184',
#   'coldcasetips',
#   'thekansan',
#   'karima_bright',
#   'deejensen74',
#   'secretarypoot',
#   'amypolacko',
#   'mcinally_marc',
#   'marishah77',
#   'jess_jay_josh',
#   'starwatch007',
#   'trialdiariesj',
#   'imatti_',
#   'sandra_radna',
#   'legacygrid',
#   'crimepsycfiles',
#   'lancenorris20',
#   'willcottashley',
#   'gotamightyboosh',
#   'ronnielouise2',
#   'digbylaps',
#   'ptsd_grl',
#   'shellymoorebb13',
#   'lmpsych',
#   'tweetspice',
#   'lawyerschiff',
#   'Elenasmindset',
#   'natea11',
#   'vintagewingnut1',
#   'stephkauf',
#   'davidmcollings',
#   'thelizrusso',
#   'abbysummer5',
#   'ohmeowitsnorms',
#   'michaelcourttv',
#   'vinniepolitan',
#   'kittybox1',
#   'tsiltsil',
#   'franklyme16',
#   'fnjerseygirl',
#   'aim_me_jo',
#   'warnerbrosuk',
#   'worddiva',
#   'the_missyprissy',
#   'valthehbic',
#   'grinsli',
#   'rimongelluzzo',
#   'courttvfans',
#   'shanbamanana',
#   'caligirlleftie',
#   'pmt2387',
#   'dishymcdork',
#   'stonedagainbro',
#   'msjnicolex',
#   'annier1989',
#   'magniloquensica',
#   'lmn',
#   'blancacobb',
#   'homehotyoga',
#   'ajqueen31',
#   'addicted_2_spn',
#   'maggiebp1',
#   'Laughs_4_All',
#   'hollimorrow',
#   'shipmeant2b',
#   'bandofgypsys292',
#   'neamarahmani',
#   'momofdeputy338',
#   'tiny_toff',
#   'bluerosegirl',
#   'wordygirl639',
#   'JUSTinPUSHPLAY',
#   '7lakeorenda',
#   'bguendling',
#   'michiallen',
#   'bittertweetcat',
#   'goprtraitors2us',
#   'AshleyCourtTV',
#   'qsopht',
#   'misha_correa',
#   'lady_leo_74',
#   'khhanlon',
#   'shelizasha',
#   'bthequeen13',
#   'drlaurapettler',
#   'lorenkatie',
#   'realtalkwricky',
#   'toastymist',
#   'magesh_elumalai',
#   'liesh_blanco',
#   'marcoiaatty',
#   'jocs64',
#   'jordieishair',
#   'westcoasttrial',
#   'fuk_ups',
#   'deniseisherex',
#   'mollyjo45939875',
#   'yotusabe2',
#   'itsadriienne',
#   'tinarasmussen',
#   'AJintheKy',
#   'sparklyeyedone',
#   'staceybeth69',
#   'reesekelli',
#   'freesat_tv',
#   'websleuths',
#   'EeveeTheFirst',
#   'sharp_bradley',
#   'LeslieG1819',
#   'nbcnewsthink',
#   'missbuffinno',
#   'ptown49',
#   'janielacy',
#   'lisafs_cpa',
#   'jackrice',
#   'adapozo',
#   'cassh0le',
#   'calley_criminal',
#   'bmo016',
#   'tinydropsofrain',
#   'bondjane007',
#   'sadeismymom',
#   'changed_man920'],
#  ['ripdajuulz',
#   'jordans92248235',
#   'midas_forever',
#   'texastoe',
#   'nepaligentleman',
#   'adsh96030154',
#   'amelia_mcj',
#   'buh_bye_birdie',
#   'alexzvampyrock',
#   'rodriguez_binx',
#   'doodydododo',
#   'arkgal89',
#   'hellsurrey',
#   'mooshfelia',
#   'jworderth',
#   'tomyhans',
#   'hmurf1331',
#   '1_800_anita',
#   'annamarieasha',
#   'kayleeswantek',
#   'krystlgames',
#   'thebankizope',
#   'astralyne_x',
#   'damn_it_linda',
#   'nicoleashlei',
#   'denise_f_dehaan',
#   'katiedaines82',
#   'willyknows_best',
#   'astronaught420',
#   'therealleaflet',
#   'samadoodledoo1',
#   'grahamkalei',
#   'chellemarie11',
#   'newsgramdotcom',
#   'mariehi11609665',
#   'mom2many317',
#   'sludgefactory__',
#   'heythere091726',
#   'seghabir',
#   'warmmonkey',
#   '_dnvrgrl',
#   'demoncreegan',
#   'tonybagademnutz',
#   'shantel91505',
#   'gypsygossiptt',
#   'atomicginge',
#   'igiveyouabear',
#   'hubahuba79',
#   'housh_andrew',
#   'joaniemfc',
#   'sarahwe06172678',
#   'angela13809645',
#   'ladyinred111194',
#   'kleinraych',
#   'sg_securities',
#   'taylorpieffer',
#   '3421ross',
#   'lisasays_9',
#   'bmmartinezwrite',
#   'ahmodshadi',
#   'casilecheyenne',
#   'christopher8101',
#   'jj22d48',
#   'lakedaniel11',
#   'jambriest',
#   'eyprilsix',
#   'medicinsko',
#   'luvzfloyd',
#   'pensfan67',
#   'texasbowlegs',
#   'babyplutoskrtt',
#   'dasnandini97',
#   'sistersmercy73',
#   'saldanaa80',
#   'zackryker',
#   'slynns74',
#   'jessica41515',
#   'cricketburps',
#   'samsmeltzer20',
#   'nightmistress35',
#   'redszxoxo',
#   'wepisknews',
#   'chazzp12',
#   'insertcomments',
#   'analaurad1',
#   'monkey_butz',
#   'th3oneaboveall',
#   'mellyb0000',
#   'pug_oddie',
#   'shoreymichael',
#   'stacie_white',
#   '1_2692',
#   'princesacrowned',
#   'heather_brockie',
#   'labaleriol',
#   'nevernormal88',
#   'cannabischris6',
#   'thegirlsaidwhat',
#   'final_arc_97',
#   'mzcoach15',
#   'jclayson01',
#   'aaleighiamaria',
#   'ashgenx',
#   'perdue_jrp',
#   'aj_thebatman',
#   'kokekofu',
#   'antistupidityca',
#   'akdwivedi_',
#   'ford1066',
#   'heto918',
#   'scarlettjamescc',
#   'christobartlett',
#   'fjayne_',
#   'jewcychezky',
#   'nicolemw1981',
#   'metaplayio',
#   'cpt_jck_sparrow',
#   'majodete',
#   'chaperon_jalex',
#   'hayleypendergas',
#   'htop75',
#   'kimstrangelove',
#   'olesenbrun',
#   'claudet58268837',
#   'capebretoner82',
#   'ms_fiberlicious',
#   'tpwkftwallows',
#   'catontheright',
#   'y2hero',
#   'saltwatercolour',
#   'personified_war',
#   'laurieasimonds',
#   'notsure35869688',
#   'you_listen_up',
#   'shortyk48',
#   'ms_truth15',
#   'wtfisgoinghere0',
#   'ejtowne',
#   'realdaisydeclet',
#   'noffa1111',
#   'j3nn1f34',
#   'd_ntf_ckw_me',
#   'shanlanhen',
#   'knuthaugen6',
#   'proudmomof4l1s',
#   'cplusm81',
#   'vera57945773',
#   'financeheo',
#   'stephpcrogers',
#   'bigfanojustice',
#   'seattleman99',
#   'mari3francis',
#   'johnnydeppsupp1',
#   'emilybug8',
#   'cworldrefugee',
#   'dunk0n',
#   'kayvandej',
#   'natillywelshie',
#   'christineh1973',
#   'akkeroef',
#   'davidmkeynes',
#   'lindsey01778663',
#   'desireebeard42',
#   'baranovskygleb',
#   'theamruthareddy',
#   'coffee_kittie',
#   'syllabooze',
#   'crejohndesign',
#   'andieblackwood',
#   'manmadeerror',
#   'sandra_16_',
#   'bastian_arndt',
#   '_sergio_michel_',
#   'berrell_jane',
#   'realamberheard',
#   'con___c0n',
#   'sarahlouise1123',
#   'casperthegh0st',
#   'crownedvictory9',
#   'cjstewss',
#   'trashandtrauma',
#   'trent_bratt',
#   'el11112011',
#   'cat_disgusted',
#   'logivenchy',
#   'puttingthe_q',
#   'kittehboopurr',
#   'lluvia53',
#   '77sylvia',
#   'cococq19821',
#   'the_backagain92',
#   'lazytweeterrr',
#   'taggajac',
#   'michell68520741',
#   'v4vend8a',
#   'm290592',
#   'afggvv4',
#   'beinloveart',
#   'johnnyamarilla',
#   'mswingz',
#   'chelseyovery',
#   'thebearrage1',
#   'cherylwvinson'],
#  ['DaaniMonday',
#   'AichaMarghadi',
#   'Diana__A93',
#   'chuwareewap',
#   'Protosz',
#   'Fibutton',
#   'KatieeeeBishop',
#   'b_obreezie',
#   'vvadskamanheta',
#   'MuuPuklip',
#   'lorraine_hickey',
#   'RooNelson1',
#   'ZikkenAlkarp',
#   'Lady_Nickeh',
#   'locanica31',
#   'Michaela_jayne1',
#   'TheComp12192824',
#   'lil_fairy_doll',
#   'bosoxmonica',
#   'MsRedTwice',
#   'underscoremolls',
#   'HaloTitan',
#   'Luvlight44',
#   'dwellsauthor',
#   'robert__leonard',
#   'eclarim_',
#   'Skippeedie',
#   'RonnieLouise2',
#   'PureRuns',
#   'JunoLynnSpears',
#   'VGray1984',
#   'ChadGuapoSancha',
#   'BWidow2015',
#   'Starrgh',
#   'Fairyswirls1',
#   'VarahnTet',
#   '1GirlGamer',
#   'jnngtrrz',
#   'hey757hey',
#   'maknatste',
#   'TheCanonGurl',
#   'sixinheels',
#   'AngryScottishL',
#   'ravenflake',
#   'BlueFranArts',
#   'PopMelancholic',
#   'SimasRealEstate',
#   'ClalaLeck',
#   'MiikaKelly',
#   'iamgravejones',
#   'superjusticeboy',
#   'teenagemars',
#   'maddiepie97',
#   'Erin__Maxwell',
#   'Rickstroik',
#   'thebreespree',
#   'Mike_Phillipson',
#   'tweeter_aashna',
#   'georgeannemarco',
#   'OniesyR1126',
#   'Rubeign',
#   '40dirtracin',
#   'IamDeeDiaz1',
#   'JessLynn90',
#   'Wendie07',
#   'AstraLyne_x',
#   'AzazelComplex',
#   'DanDanger_1776',
#   'aine_333',
#   'MarianMorticia2',
#   'Wee_Sammy_xoxo',
#   'Jareisabear',
#   'geestfu',
#   'soft_sunflowers',
#   'Blitzy4B',
#   '_bexorcist',
#   'shannonsistrunk',
#   'tghdecor',
#   'florida_ready',
#   '__Towanda',
#   'BrandyinBelize',
#   'ComandanteKemal',
#   'iibetto',
#   'Blackfished2',
#   'Sharksgrl408',
#   'PresidentSweden',
#   'dim_hey',
#   'kateeeraeee',
#   'MonsteraDelboy',
#   'itsaIexbitch',
#   'shoppurrr',
#   'Luv_And_Rockets',
#   'ViolentlyHappy0',
#   'dropofscott',
#   'hanahbeb',
#   'Gaby20748779',
#   'Studiof6mumbai',
#   'getRdone1812',
#   'SouthernAtHear4',
#   'Mikof_Time',
#   'tracey_sensei',
#   'yak_mary',
#   'jcd_phoenix',
#   'JanowskyKristen',
#   'J_yM_ck',
#   'LeonaWhitten',
#   'TheDUIGuy',
#   'MentalHGaming',
#   'Slackone',
#   'JK11114987',
#   'NakulX',
#   'TaktuBou',
#   'LadyBravestrong',
#   'NoheliC',
#   'haniabdelmageed',
#   'KIMJIWONSMYOU',
#   'K32fce',
#   'emc0014',
#   'GoBronson',
#   'LiamHamer',
#   'Pinesrob',
#   'skye3notes',
#   '_bethany_thomas',
#   'vioIetdepp',
#   'TheonlyArantxa',
#   'lkjmca',
#   'Tiffy_Craig',
#   'GirleyStuff',
#   'LuciaGranus',
#   'CrystalSunrose',
#   'kristamayla',
#   'NFitandfab',
#   'MylasMoon',
#   'TheOnlyJFalz',
#   'EAnimator87',
#   'Serene_Gem',
#   'Benand_rews',
#   'peer_taylor1',
#   'MimiLoveee71',
#   'LRTKH',
#   'GoGettaVeeeee',
#   'KimwhittyKim',
#   'bellescharms',
#   'depptrialupdate',
#   'paraskevivi',
#   'ULTTweets',
#   'HelloEssJay',
#   'KateSim97065783',
#   'StarWatch007',
#   'LikeYouOwnIt',
#   'praying_blondie',
#   'SchizoSkits',
#   'EmmaMur14070789',
#   'SueAllergic',
#   'LisasBeautySpot',
#   'BesteButter',
#   'SharyAllan',
#   'Soft_J',
#   'BarbaraMogeni',
#   'Katnow123',
#   'Decan__Frost',
#   '_simplyxme',
#   'Alalikwt9890',
#   'The_MERMAIDIAN',
#   'ZombieDoris',
#   'therealjamee',
#   'PollMeister9',
#   'ClaudioVerga',
#   'wruang9999',
#   'Merlinslyth',
#   'louist91ofTPWK',
#   'BruntonLindsey',
#   'sicssorluv',
#   'Kelly17809230',
#   'Angeleenie',
#   'KelsyHonick',
#   'SHESAUVAGE',
#   'JD3Boom',
#   'ddanirojass',
#   'J3zz1T',
#   'Reneein23',
#   'rachelqxo',
#   'Mr_Bouche',
#   'WinkiesWord',
#   'LeJutko',
#   'ReemSalameh_',
#   'Theycallme_anto',
#   'LKJMCA',
#   'BootsTinker',
#   'painterstape1',
#   'Jany_aka_Chaos',
#   'iamnenestwin',
#   'Itsraining2',
#   'JoePillarToPost',
#   'sickbbs'],
#  ['ljh_3pups',
#   'thissmallplanet',
#   'guire89',
#   'amiablephantom',
#   'l2049s',
#   'adhilhussain97',
#   'casslovedog5',
#   'mianwonderland',
#   'stephweekly',
#   'krakray',
#   'saddlesurfer2',
#   'roy114sumit',
#   'realchinkk',
#   'rowdursrinivas',
#   'annabelpark',
#   'barbaramerryg',
#   'maries_thoughts',
#   'melissa_1312_',
#   'lstuggi',
#   'belieberbwoy',
#   'rcq402',
#   'fearfully_madee',
#   'jonathanhuneau3',
#   'williesayso',
#   'zeke47899373',
#   'karenheard',
#   'thebatman135',
#   'courtneysully32',
#   'thamilton007',
#   'thyheighho',
#   'melisanotmartha',
#   'midnight_nougat',
#   'dljdjalak',
#   'gate_marks',
#   'jetset_monkey',
#   'm44386425mc',
#   'real_alperesat',
#   'elenchickk',
#   'cable_glark',
#   'hazexotica',
#   'robertldarling3',
#   'turdfurgeson716',
#   'cherienbenni',
#   'himynameisola',
#   'madmax1459',
#   'janecooketh',
#   'thehook83081094',
#   'trin0610',
#   'thatumbrelaguy',
#   'dax_mccaskill',
#   'rishgard',
#   'obamabinbidenn',
#   'melindamartinez',
#   'kivalk5201',
#   'steffie707',
#   'thesentinelca',
#   'askkarmagirl',
#   'nellzcomics',
#   'shellbell123r',
#   'anyankablack',
#   'joshkimber',
#   'melaniesback',
#   'shubham_gupta_',
#   'mrrecord',
#   'elonmusk',
#   'elonmuskradio',
#   'itsdrdemonic',
#   'warriorxqueeng',
#   'polynorph',
#   'purebredchaos97',
#   'sportblooded',
#   'lolocraiger29',
#   'rickrobles444',
#   'brian2beers',
#   'danhugo',
#   'sikhyorks',
#   'ferrellkayla',
#   'altcoindailyio',
#   'tcaoittw',
#   'shayjay850',
#   'moinshekh',
#   'nicoledominic18',
#   'dadalives',
#   'sbm97555',
#   'aprilelevenone1',
#   'djjdiljot',
#   'LillyJane916',
#   'hashtagthisok',
#   'thorkrum',
#   '_mika_und_mond',
#   'denham0001',
#   'carbsanddrama',
#   'andresjose694',
#   'jj63402332',
#   'suraiel',
#   'stelladiva1',
#   'lc_chem',
#   'kathleenfuery_',
#   'bearfootncrazy',
#   'moetitude',
#   'natnathi',
#   'btippers',
#   'nuerons_active',
#   'guidoheidmann',
#   'cameronsomal',
#   'lllshuyi',
#   'aliratwebsites',
#   'crimsonaasimar',
#   'tallie_anne',
#   'dvanessavalente',
#   'krimbolina57',
#   '_silversatin',
#   'terryfr46810488',
#   'debasis83030036',
#   'jesusfacekilla',
#   'mariahamaya10',
#   'urtoxic0',
#   'jlan410',
#   'dharmeshshah47',
#   'inspiredbohemia',
#   'barbarajen',
#   'maleedus',
#   'baigsonauctions',
#   'dacusronda',
#   'thegatorsenju',
#   '1776_2021_0',
#   'faire_passer',
#   'cayssielloyd',
#   'ambergermany85',
#   'sarj37',
#   'hussainnabbasi',
#   'robertalanmore',
#   'evermoving9',
#   'react2_dat21',
#   'nat24944392',
#   'caradelevingne',
#   '48waterfalls',
#   'glittert1nk',
#   'thecrimediva2',
#   'dennism39398123',
#   'mikaelbenbaruch',
#   'jesussteelo',
#   'meetthespidy',
#   'marc_beauregard',
#   'fistedsisters1',
#   'jacqui607',
#   'barbaraem77',
#   'mrs_right_a',
#   'wearejudasgoats',
#   'kimbradbury16',
#   'macbethany_',
#   'jarlebreivik',
#   'jesus_saved_me7',
#   'hodlxyz',
#   'ahmed8_official',
#   'awprokh',
#   'intensemisery',
#   'badasskitten69',
#   'stevedescano',
#   'mrsunnydeyz'],
#  ['marsbarwilliams',
#   '2facedpink',
#   'kittycatlitter',
#   'misannthropic',
#   'ajbartram',
#   'moonshinejune',
#   'popcultnerd',
#   'srqje',
#   'theacecampaign',
#   'lafintexas',
#   'mininemi',
#   'queenadalite',
#   'msgracietwitch',
#   'andersonbasia',
#   'banneduser9876',
#   'traceymccaffery',
#   'lifesapprentice',
#   't0mmi3b',
#   '_starwhisperer',
#   'digitalsparky',
#   'cmerkl1',
#   'itzmeroyal1',
#   'justcalmnsense',
#   'lilithsubmerged',
#   'cazza0707',
#   'breezyygirll',
#   'lexisjean86',
#   'cmdyment',
#   'yaraad_sa',
#   'itsafact3',
#   'rmlawson4',
#   'theemilydbaker',
#   'toobsandstuff',
#   'a_oriordan11',
#   'bytchty',
#   'coragreenleaf',
#   'emmnichol',
#   'walkinginpretty',
#   'rantyalex',
#   'offcdl',
#   'skyler_vogel',
#   'glocksondeck_',
#   'edwardmurph2',
#   'debsfennell',
#   'chuckufarley81',
#   'itsokaybarbie',
#   '42theanswer_',
#   'theaftermathone',
#   'quickshot',
#   'iamdeandrep',
#   'mindfulfreya',
#   'summerspirit_',
#   'spontanja',
#   'redcruz19',
#   'violentkittycat',
#   'misscasshoskins',
#   'vyyyper',
#   'moonwispart',
#   'sandityche',
#   'thequeenmac',
#   'lovetohatepod',
#   'mad_soulless',
#   'girlisgray',
#   'realitvpod',
#   'murphystina',
#   'makeupbymoon',
#   'mikepamelap',
#   'melbicket',
#   'user1236707',
#   'anoushasakoui',
#   'wildflower2317',
#   'shay_brunick',
#   'wanderingstar78',
#   'imsaneuarent',
#   'djmichaeltoast',
#   'lottielouise_uk',
#   'jenlauma',
#   'thisliberty',
#   'aerinmoriarty',
#   'cloudjumper1996',
#   'emperortoch',
#   'blondebecca28',
#   'unicaivahblogs',
#   'sweetvee_13',
#   'chiaandsue',
#   'gina412',
#   'melodywhore',
#   'rezzachamp',
#   'addis_blabla',
#   'decidetotry',
#   'asmrparadiseyt',
#   'y00nko',
#   'vidoslava',
#   'mariabella444',
#   'bindybea',
#   'gritcitywitch',
#   'marcus_creel',
#   'cjperezjr77',
#   'kimbakimothy',
#   'nadinebaden',
#   'mfanton',
#   'melaniejesc',
#   '_z0327',
#   'erin_cullen1122',
#   'bbrrii_elle',
#   'thebooknerdess9',
#   'burgenah',
#   'hollienemitz',
#   'nonhleskosana',
#   'christi72039917',
#   'rochelle9812',
#   'carolinekren08',
#   'gameoverrhi',
#   'joncampbell912',
#   'zcruz2018',
#   'twittingrandma',
#   'helenroberta19',
#   'thatcasinochick',
#   'sta_ceyb',
#   'boehsenichte123',
#   'tinymercinary',
#   'evilpeamia',
#   'kellyclinger',
#   'tonyasaid',
#   'kiraeyl',
#   'belleofbabble',
#   'lumireu',
#   'jdfanshop',
#   'skalnajs',
#   'naomihildersley',
#   'proxima2022',
#   'stephlilienthal',
#   'emmapeel_',
#   'vortexglitter',
#   'debnbed',
#   'vjaydesigns',
#   'twitterspaces',
#   'sisson_jane',
#   'noxnigo',
#   'amusedcrow',
#   'katiekay0216',
#   'journaldelux',
#   'kitkatdani',
#   'mollykropp_',
#   'yaldacollection',
#   'stacysawyers03',
#   'ameliahammy',
#   'ellacee83',
#   'socalmarla1',
#   '_mzfreddie',
#   'dasupermom',
#   'loislovesmusic'],
#  ['lorbe',
#   'cheetah1961',
#   'DavidSting1989',
#   'rlgriebe',
#   'notascranky',
#   'fxstguy',
#   'michaelschweitz',
#   'GermainLussier',
#   'RPat360',
#   'mason4922',
#   'RepPatFallon',
#   'CREWcrew',
#   'RaulM956',
#   'MaryMarybrogdon',
#   'painting_tlc',
#   'usairforce',
#   'Carmichelle',
#   'AndyOstroy',
#   'rick00979',
#   'JasNuss',
#   'mentalcasemama',
#   'MorteHoeDevon',
#   'NeilLowenthal1',
#   'CynthiaHarless1',
#   'AccountableGOP',
#   'MLedaloo',
#   'Allenleech',
#   'onlylight210',
#   'carlhurdmba',
#   'mhall55nine',
#   'TheBigBrownGirl',
#   'elyse4design',
#   'RUntEntrtaind',
#   'docrocktex26',
#   'Vaw511',
#   'robertjlundberg',
#   'madmillennial77',
#   'patriottakes',
#   'ToddKolod',
#   'summerbrennan',
#   'four4thefire',
#   'outmagazine',
#   'Billbrowder',
#   'FrauDoktor11',
#   'pannlewis44',
#   'llkrome',
#   'tnqindy09',
#   'stacisglover',
#   'EenuffCed',
#   'tina_leeds',
#   'dfs3660',
#   'johnfeal2',
#   'EstyMunMom',
#   'Norm_berry',
#   'GOPAreCorrupt',
#   'nihil_ad_rem',
#   'SeabreezeCheryl',
#   'donjefferis214',
#   'kerrylovesbrie',
#   'LaneZane1',
#   'jmaxwell319',
#   'DetHippieChick',
#   'HBawsac',
#   'DowntonAbbey',
#   'UdnSpeak4me',
#   'JoFroggatt',
#   'CajunBlueAZ1',
#   'courageousgirl2',
#   'AGirlHadNoPOTUS',
#   'awelab1956',
#   'Dontbeadick21',
#   'jordanalipscomb',
#   'markandmeuk',
#   'GlasnostGone',
#   'cristofle',
#   'Jana89021920',
#   'FPWellman',
#   'tucsonrosie2001',
#   'hannahblue3',
#   'hughbon',
#   'cooperchip1',
#   'reenie62',
#   'chantalsygk',
#   'mmcclure88',
#   'KapeciaResists',
#   'Tongueofwood',
#   'SalVadacchino1',
#   'iamAtheistGirl',
#   'rockinrobray',
#   'paul_romanow',
#   'Lissthesassy',
#   'StolenSceptre',
#   'VeronicaSam13',
#   'CharonLucas1',
#   'dahliabloom',
#   '1983resist',
#   'Ireland0828',
#   'global_states',
#   'FurbabiesRmyGo2',
#   'ida_skibenes',
#   'MsTreeWoman',
#   'USSupremeCourt',
#   'CyrusMMcQueen',
#   'Heidi_Maed_It',
#   'PrincessBravato',
#   'dharmafarmer1',
#   'Dr_TheHistories',
#   'BarbaraOdra_Mo_',
#   'TheJusticeDept',
#   'beachbirds72',
#   'markghost45',
#   'DowntownPatmore',
#   'TonyHussein4',
#   'HawkBlueback',
#   'CawthornforNC',
#   'AmericanIndian8',
#   'ebikeadvocate',
#   'misplacedsouthy'],
#  ['jesskapizzle',
#   'diamondbabbyyy',
#   'mrs_gonzalez05',
#   'elisadayj4j',
#   'farmama7983',
#   'valenitta8',
#   'jaws0129',
#   'lidskylidsky',
#   'waqqy14',
#   'elenehendriks',
#   'hahahaasif',
#   'cazadoresel',
#   'odiesislandlife',
#   'spymom10',
#   'hflavor512',
#   'maurodiogo',
#   'annmichellesal1',
#   'kennareigns',
#   'coops_kay',
#   'wyatt_zip',
#   'gianniceddu',
#   'nicole_el',
#   'ktglitz',
#   't_bird_tarot',
#   'shardoflove',
#   'truthful_moon',
#   'duncancan1',
#   'lissy7318',
#   'kocan610',
#   'jayday230',
#   'itswhattttever',
#   'missquittner',
#   'brosie_v',
#   'tatasmcgeee',
#   'jacbazz',
#   'joangvs',
#   'slmgentry66',
#   'deborah05695068',
#   'miriy_chan',
#   'neelamtewar',
#   'mimifrominazuma',
#   'amberisalier',
#   'c4w31',
#   'junymosthigh',
#   'hedgehogplus',
#   'floridagenxr',
#   'karweasl',
#   '_missbhaven',
#   'saucyjack73',
#   'jacksloaneee',
#   'anabananaaa91',
#   'genieofesthetic',
#   'tmz',
#   'emmadanielle4',
#   'aad_crypto',
#   'lillitumodel',
#   'machemahehe',
#   'itsbetsyh',
#   'b_to_the_ecky',
#   'thatmomcerena',
#   'mimiwdf',
#   'keyngofboston',
#   'tobeseenagain',
#   'sunsalesnft',
#   'shefsam1',
#   'princonsuella_',
#   'weedandwarrenz',
#   'hesthehome',
#   'talksreality',
#   'bangingnamjoon',
#   'caraslimelight',
#   'jjmarcos_si',
#   'servnmythoughts',
#   'chelarvale',
#   'oldloggie1',
#   'mattressbilly',
#   'rumawalker',
#   'lauralsweet',
#   'jamiesartin2',
#   'ryansutts',
#   'samlguile',
#   'couvegirl',
#   'shortprincess98',
#   'galmarielena',
#   'singingm',
#   'kursedfrogurt',
#   'therealofimile',
#   'varahntet',
#   'love___life___',
#   'igtzalcorta',
#   'dollyarthur_',
#   'khushverse',
#   '18thofnov',
#   'thefandemic',
#   'zombiepoops',
#   'silverrvixen',
#   'bucksfan1645',
#   'ladyedlynn23',
#   'hellomrsentity',
#   'alexpearsonuk',
#   'yermom1234567'],
#  ['agendahurts',
#   'TobiasTheGinger',
#   'ollytang',
#   'tggi',
#   'ugadawgsac48',
#   'katw825',
#   'txmomhollie',
#   'jenny_balchin',
#   'bluesamuraizero',
#   'yigh',
#   'pgh_geo',
#   'meganfoxwriter',
#   'notthatthermo',
#   'jordanreapers',
#   'fleuranais1',
#   'thtgingrchick42',
#   'longinus357',
#   'nicolevbalaoing',
#   'jay77947606',
#   '_tidewillroll_',
#   'talentedeukarya',
#   'ronibennett',
#   'squidlord',
#   'mzmarcopolo',
#   'honornc',
#   'eldudette',
#   'pennademocrat',
#   'optimus_d_',
#   'aburkhartlaw',
#   'ampllama',
#   'macgregor_lol',
#   'mdknight2016',
#   'piratetomski',
#   'texasblue48',
#   'neon_wolf111',
#   'oweandersen',
#   'hunleyeric',
#   'perceptionchek',
#   'sonjacirilo',
#   'fickiethoughts',
#   'jcantdraw',
#   'sysco7t',
#   '0ciestiel0',
#   'brvtvsmaximvs',
#   'mydarkestdiary',
#   'dburridge010',
#   'mainer_gal',
#   'rohitkulk29',
#   'catystrophia',
#   '_smartchat',
#   'lordbuckly',
#   'longliv04611701',
#   'halfpintdynami1',
#   'joshthepunished',
#   'sparky027',
#   'lawselfdefense',
#   'gnukman',
#   'nope_923',
#   'r3dbe4rd',
#   'dkcripple',
#   'higginsmommato2',
#   'awesomismmom',
#   'xia_land',
#   'bealmearamanda',
#   'cielhunterzzzz',
#   'missconniebb',
#   'nina7infinity',
#   'kiwi74_2010',
#   'ivanka_jade',
#   'thelegalvices',
#   'heatherventures',
#   'manrvxz',
#   'peposlawa',
#   'thelegalmindset',
#   'kittyb0bitty',
#   'ddrey',
#   'sharonsedgwick',
#   'kdubsmiles',
#   'MeganFoxWriter',
#   'yummyyet',
#   'joetabletop',
#   'kaizerpineapple',
#   't3r3gram',
#   'rekietalaw',
#   'sdle1999',
#   'attorneysings',
#   'roncoleman',
#   'lisan_al_mahdi',
#   'miaamiam',
#   'bartonbella1',
#   'starrgh',
#   'maxcaudell',
#   'seriouslykelly',
#   'ttinaelisabeth',
#   'tractordrivnsob',
#   'linehacker',
#   'stephxxmichelle',
#   'shhcharliebray',
#   'commbatboots',
#   'stilljustbarra'],
#  ['kittbartel',
#   'jimorourkeesq',
#   'patm08901',
#   'astrosexologist',
#   'sara67505393',
#   'strikeforcekid',
#   'malikdshawn',
#   'forbeskl',
#   'jensey109',
#   'christi05706540',
#   'quickwitter',
#   'inscarll',
#   'snglong',
#   'krod082',
#   'abigguitar',
#   'deboritas33',
#   'gingersheart',
#   'dominic00719779',
#   'dpsfor_days',
#   'delicatelyfe',
#   'togetherwelead',
#   'shoebzama83',
#   'nancylipschult2',
#   'mosemichaelson',
#   'marm0629',
#   'dazzbo1',
#   'manabduch',
#   'paulbazz',
#   'catosknife1',
#   'bbiteme27',
#   'justtruthmyopi1',
#   'lisa_zembal',
#   '_d_o_r_y_a_n_n_',
#   'starsonb',
#   'naa0011',
#   'kkarenq',
#   'mjisthebomb',
#   'sportsdadmoody',
#   'az_oray',
#   'brandon70567390',
#   'apoorvahere',
#   'flmomnygirl',
#   'eugene646',
#   'je17118537',
#   'jdoglala',
#   'kitty_fixer',
#   'paulvrapisarda8',
#   'nathanielcurr20',
#   'amazonpyjamason',
#   'skinnykiss',
#   'ovgrot',
#   'wotwodney',
#   'marmar_85',
#   'jeshieeeeeeee',
#   'sorrellsales',
#   'kelizh',
#   'emmagemstone',
#   'noworrienow1970',
#   'thebiggersull',
#   'drew2c',
#   'dantebrandolini',
#   'cooks_tk',
#   'jasonwo97579812',
#   'guillotinesplic',
#   'michael57329689',
#   'emilylodge007',
#   'byronlesane',
#   'hcook1966',
#   'congressgohome',
#   'mia626',
#   'gamyed',
#   'athancolorado',
#   'pricelessopin',
#   'gregorymelody',
#   'deborahhig',
#   'bussycat29',
#   'bosnerdley',
#   'gangster_kitty',
#   'nypost'],
#  ['bedoor11',
#   'thescottcj',
#   'mplatypus82',
#   'thescr33nqu33n',
#   'leafyfififoo',
#   'nuggypanda',
#   'thezakuza',
#   'alyssachavez_xo',
#   'john_greely_666',
#   'nicbu0n',
#   'kjacks0815',
#   'maria06581190',
#   'cheydiah',
#   'ssj3_jay',
#   'cherubicdoll1',
#   'whitealakazam',
#   'hellbound_xx',
#   'thatumbrellaboy',
#   'mizchele6',
#   'chelseaacliffe1',
#   'stoweby',
#   'kabutoridermav',
#   'johnnydeppital1',
#   'grassgrassone',
#   'dink_nyc',
#   'sarah_fenola',
#   'charle6',
#   'ravenowl2988',
#   'soria_giulia',
#   'everything_eri',
#   'fireusi',
#   'pooks82official',
#   'mushmushmania',
#   'kamtot1138',
#   'mevolviaenojar',
#   'schanunser',
#   'sarassilkymoves',
#   '_kimmixoxo_',
#   'eva_leenders',
#   'tokyodiiva',
#   'thatumbrella',
#   'prose_ana',
#   'becauseican2',
#   'xenogearsfei',
#   'aderynthehylian',
#   'proudtx73',
#   'basedtexans',
#   'jaimesummerz',
#   'igossipedagain',
#   'nottimpressed_',
#   'flowerspots14',
#   'synthbabie06',
#   'jazzsummers',
#   'jambrady',
#   'edward_huber',
#   'l51251581',
#   'gabeisabadwolf',
#   'sm9690',
#   'realrecaps',
#   'savagelady16',
#   'kisywisy',
#   'pheobeh3',
#   'sweetieshortie2',
#   'geekdaddy75',
#   'alottateahere',
#   'ivoryimmanuel',
#   'tammiemcdonal17',
#   'missylou4643',
#   'robaclinch',
#   'angeleenie',
#   'clarecanino',
#   'fortherecord323',
#   'brunson_tessa',
#   'peperoncinodark',
#   'mouthofdasouth6',
#   'vicinitythree'],
#  ['benande35091840',
#   'bachbabble',
#   'spikyjuice',
#   'the1harleyqueen',
#   'ezymare',
#   'delaney08810827',
#   'smccallum93',
#   '_ft_bm',
#   'careyxcarter',
#   'lucie_grayy',
#   'trapthestarsin1',
#   'lorraineoshea15',
#   'haytch92',
#   'chanel',
#   'pooproductions1',
#   'ba2121991',
#   'meagpint',
#   '1amdoug',
#   'girlfriday_atl',
#   'jlizcasas',
#   'nanami_tremblay',
#   'jasmine60178611',
#   'sami06187957',
#   'jerusalem_post',
#   'bixoooo',
#   'christianm_make',
#   'annoyingcar',
#   'maniaandcoffee',
#   'paperboats4',
#   'laurenlflower',
#   'jonasfarr55',
#   'crownv_16',
#   'and_1_one_1',
#   'ahronrshapiro',
#   'myem04',
#   'slimmickky',
#   'drno80156937',
#   'lodiannabelle',
#   'iobliviate',
#   'justfrostyman',
#   'yallmental',
#   'moi09091174',
#   'munitedgirl',
#   'lisae333',
#   'rubberducky_iso',
#   'loftlizard26',
#   'hanlipirie',
#   'guggyandrade',
#   'ella83706561',
#   'ukcats0817',
#   'taenemcrazy',
#   'themotherof5k',
#   'watermelonhaii',
#   'latinadesign',
#   'gonzozillatv',
#   'olivedean13',
#   'emmylou30',
#   'castlebroadview',
#   'jonnychilders',
#   'tejinde52441549',
#   'itsyamm',
#   'blthtony',
#   'varandelle',
#   'lori_nalette',
#   'gorgeikim',
#   'trollwithmela',
#   'emilykschrader',
#   'lucii_90',
#   'eve_barlow',
#   'letstweet921',
#   'abrandnewname_',
#   'nhem31926'],
#  ['fear_terry',
#   'tane77996',
#   'Dana92601297',
#   'pennydejulia58',
#   'Pebbles24227080',
#   'sommer_andersen',
#   'glittermarcy',
#   'Omogebukola',
#   'briajasminelynn',
#   'DJusticeforj',
#   'ReleaseMinamata',
#   'arekkusasan',
#   'ABC7NY',
#   'DisneyStudios',
#   'tillyrn',
#   'EthanTrace',
#   'Feastonmybehind',
#   'madsonovich',
#   'verge',
#   'c_kedge',
#   'bella_frannie5',
#   'crissyrissa',
#   'TifftyACo',
#   'SimoneDawkins82',
#   'HappyBox365',
#   'CrimesOfDepp',
#   'AmyBomaye88',
#   'OdeToMisery',
#   'OnlyTheSpiciest',
#   'Bee75Mo',
#   'manibusliliaa',
#   'RobzzyD',
#   'MarjorieAuroras',
#   'lip_rocks',
#   'JesusFaceKilla',
#   'Jermo43',
#   'notapopularOP',
#   'PasajeroToro',
#   'Nurselove_719',
#   'firstis_love',
#   'samjrakoh',
#   'GarlicBreadBen',
#   'NoctrnlValkyrie',
#   'DrRichardTop1',
#   'MarciDi84149950',
#   'JenMishCockled',
#   'GellertDeppBR',
#   'itz_just_ez',
#   'nearlydear',
#   'modestychild',
#   'twyla411',
#   'msshivanimathur',
#   'gabus08',
#   'blacklabel2021',
#   'MattGertz',
#   'spirituallyemp1'],
#  ['_nefelibata_88',
#   'babyesiza',
#   'heidifrogner',
#   'hmongqueen1',
#   'shakofilm',
#   'gothic_vik',
#   'comedyfinn',
#   'maggierochi',
#   'catportals',
#   'marciasgreen',
#   'redlikejungle',
#   'louellamccarthy',
#   'scobuntu',
#   'jperezporrua',
#   'bisonopolisfood',
#   'gretchensumms',
#   'paperbackgabi',
#   'mery_fr',
#   'xagzanotm',
#   'ancientchildren',
#   'jnfr',
#   'paulageraghty',
#   'dccc68',
#   'janire',
#   'akmakansi',
#   'ambergal47',
#   'laludi',
#   'voxdotcom',
#   'velvet_tread_',
#   'theellybee',
#   '1moregayshark',
#   'brainyudemy',
#   'periphperson',
# ...
#  ['wilsonsadler', 'apes147', 'williampettrey', 'BBCNews'],
#  ['DonnaFairchild9', 'JaingaJzzz', 'mikapeltokorpi', 'pratt745'],
#  ['hatspin', 'JohnHyde1982', 'law_and_policy', 'MarinaHyde'],
#  ['karenyater', 'RVAwonk', 'ottokummerspeck', 'babssheking'],
#  ['AmandaLax1977', 'itsalyssa_12', 'glyphcom', 'Noelle09253967'],
#  ['imannashva1', '__february23', 'versace', 'visine'],
#  ['maventmn', 'marciasmilack', 'savannahguthrie', 'Sally8246'],
#  ['1989irmo', 'soopticboop', 'ironasticgirl3', 'Heavencakewalk'],
#  ['boxyuk', 'azorinfo', 'gregginkpen', 'Cheamane'],
#  ['savesob', 'Timcast', 'the_kolt', 'mixixoplix'],
#  ['asranomani', 'imquishak', 'fdrlst', 'itsmercadante'],
#  ['AvantePlays', 'trishamott', 'mkolken', 'worldwelivein20'],
#  ['flurocarbonline', 'christy0826', 'gillyhgs', 'cskfkvsgw2'],
#  ['Kristyann39', 'gtfckt', 'SomeAnneEnergy', '337laurie'],
#  ['drmammal', 'juliebrethauer', 'u_damn_kids', 'brianstelter'],
#  ['si_pemerhati68', 'fightforthruth', 'krystaleyez', 'nakedvix'],
#  ['missmollymarie', 'fox5ny', 'jzorth', 'Daily_Press'],
#  ['_a_blackheart', 'BaileySarian', 'bellazuist', 'fishyfishfry'],
#  ['unusual_whales', 'JStevie112', 'PupBiden', 'fubsatbirth'],
#  ['damtom79', 'petefromhaynsw', 'qldpolice', 'gloriaallred'],
#  ['_richem', 'music_amigo', 'covalsky_', 'skynewsaust'],
#  ['LolOverruled', 'darthdarthrice', 'pooroldcripple', 'e21_bmwregister'],
#  ['JoonPearlLondon', 'globetrekking9', 'cloffles_lane', 'KittyWillCutYou'],
#  ['3Lil_Birdies', 'kimworldwide', 'Kuntryswagger1', 'kdlark'],
#  ['k_dewolfwrites', 'azarilaw', 'newday', 'johnberman'],
#  ['pewgaloo', 'everybodysmad', 'itsJeffTiedrich', 'majesterludi'],
#  ['joisullivan7', 'Kelly_ann89tsk', 'kay23854407', 'bmunch14'],
#  ['loftipixels', 'shou__tan', 'realzainarif', 'h3h3productions'],
#  ['r4_', 'mst3k', 'frankconniff', 'tracebeaulieu'],
#  ['realdmitchell', 'stephenmerchant', 'sethrogen', 'kevlarsjael747'],
#  ['cat_a_estranha', 'neilhimself', 'karate__karen', 'kikielephants'],
#  ['cdnchange', 'nizzy416', 'mousmamlouk', 'seasonsathomedp'],
#  ['GwenEvaBearLuvs', 'ki_native', 'simpi_lovemyway', 'houghtontweets'],
#  ['dgtlone', '15afame_', 'irish1620', 'theyuccs'],
#  ['etnow', 'malexandraya', 'ann67173240', 'sjjohns11'],
#  ['Gillian31632193', 'luumethazine', 'mehtabackupacc', 'dev_ilmoon'],
#  ['AmyReedJarrett', 'Fol77Sunny', 'annsilvers', 'bronfoth'],
#  ['tanya_plibersek', 'russellcoburn10', 'NomessTess', 'stuartrobertmp'],
#  ['MrsFluffyBunny2', 'onlythespiciest', 'ElCuscuz', 'TheRealKevinTE'],
#  ['lbc', 'littlespottydog', 'Matthew_Wright', 'LBC'],
#  ['neontaster', 'parab3llum', 'rilingbill', 'Shawn_on_Games'],
#  ['CatLadyCrazy23', 'FLouskii', 'ganthew', 'RemoraMaestro'],
#  ['jeffbry23952885', 'DeppvsHeard', 'johnnydeppfan80', 'unmaskthenarc'],
#  ['LeeS60541769', 'ghtruths', 'lenlins11', 'Londoneye40'],
#  ['BADWOLF765', 'jonnnyspinster', 'bnwmage', 'lja_photography'],
#  ['ImranKhanPTI', 'shaancheema', 'usmansaeedbasra', 'SHABAZGIL'],
#  ['rami_princess', 'imrankhanpti', 'jawadahmadone', 'arydigitalasia'],
#  ['razzieawards', 'seanszeto', 'Matt2KGames', 'MaTalocalpyse'],
#  ['aDoseOfReality8', 'Pedalsoflove_NY', 'kaminokuni___', 'k1ngmick3y'],
#  ['ZeldaFreak94', 'hellogemmx', 'haesus7', 'Im_Screwed_'],
#  ['kennedynation', 'emilycompagno', 'kayleighmcenany', 'realwebb22'],
#  ['dagenmcdowell', 'biasedowl', 'jimmyfailla', 'foxbusiness'],
#  ['markduddridge', 'jesi1981', 'rustyrockets', 'drw_indy'],
#  ['AppyAmmer69', 'drcherylllp', 'MayaInMars', 'THColman'],
#  ['JDsrelatives', 'dailymailuk', 'mrskcan', 'SaraKean'],
#  ['soy_chan9', 'bootdee_wk', 'all_grimes', 'hisel_joe'],
#  ['TrollYourRole', 'johnredjr', 'Chelseaacliffe1', 'AuranJackson'],
#  ['JudgeJeanine', 'jesseprimetime', 'TheFive', 'scsoltesz'],
#  ['MelissaZol86', 'Edwina2018', 'harmoniouslivn', 'holloway_marc'],
#  ['carmenllywelyn', 'reeny841', 'amisha_kaur25', 'lazerteets'],
#  ['dontlickchalk', 'lizwonders1', 'pfels1', 'logik007'],
#  ['eriqgardner', 'ShyCybertruck', 'GarysBrain', 'tpwk_now'],
#  ['catslaveto4', 'lookinupatstars', 'brunko_ccc', 'Hairy_Laphroaig'],
#  ['torinogoth', 'redpilleddawg', 'SHARONR86283091', 'onlyyou7778'],
#  ['UnityNewsNet', 'baggytrousers87', 'Skellywag1', 'northernoutrage'],
#  ['barabeke', 'the8thredfox', 'OulTate', 'maxosirisart'],
#  ['coll1986', 'thepeepingdog', 'itsjust_sherx', 'Simi_Mathers7'],
#  ['KalhanR', 'CassieTeam', 'TomNamako', 'calliope__m'],
#  ['caesarssports', 'fanduel', 'litigation_nn', 'arabgodzee'],
#  ['blynnhilgeman', 'Debear_', 'annelizabeth_ls', 'BrazilianBatgrl'],
#  ['madartists2', 'updownupatom', 'andrewgeczy', 'guebsi11'],
#  ['PaternityU', 'spiccoli', 'ryanwokefather', 'letshearthetru'],
#  ['roseross1958', 'coyoteshivers', 'nutlawpete', 'JewelEldora'],
#  ['adbor_aycem97', 'ZellnerLaw', 'toomuchhate20', 'ivansto40590091'],
#  ['mcr1b69', 'ocmd73', 'KevMagnet', 'vizwatcher'],
#  ['barbmcquade', 'AymanMSNBC', 'BarbMcQuade', 'zafu_sunflower'],
#  ['d2davison', 'neubergerlaw', 'notonrecord', 'maxsilverberg'],
#  ['maudephd', 'cbsmornings', 'gayleking', 'dishcentral'],
#  ['KariWells_', 'turnbullmalcolm', 'ibelievejdepp', 'magpie_2021'],
#  ['timandfriends', 'tim_micallef', 'vachon4vachon', 'jesserubinoff'],
#  ['aashnaharjani', 'rohitwellington', 'avniraja', 'mirrornow'],
#  ['ashleelee819', 'marlon112', 'ragdollmegatron', 'katemosse'],
#  ['mindi_1111', 'itsgreatreally', 'TrumpGirl_67', 'TheRevengeOfP1'],
#  ['daniphilipson', 'kate_manne', 'iainz1', 'thenation'],
#  ['AttisDezigns', 'Tilly1305', 'MillieSansoye', 'americia411'],
#  ['carradanvers', 'mintyoongi94', 'theoceanblooms', 'ctheterm01'],
#  ['artcinqmas', 'the1998deck', 'WonderingWit', 'MandyHagy'],
#  ['Rach_Vicente', 'Isuckatbeingag1', 'samwlodawski', 'christmas_bbq'],
#  ['Digibirdy', 'EleanaBelle', 'stephanieriou', 'clarahereiam'],
#  ['susannaschrobs', 'louise_p_king', 'intuitivekind2', 'jessicabennett'],
#  ['mompreneur_of_3', 'terry4al79', 'beachbard', 'Wolfiesmom'],
#  ['lesterholtnbc', 'davidmuir', 'norahodonnell', 'democrats2022'],
#  ['cristhiandrumm', 'iamkarenmauro', 'whitexrussian', 'node_ks'],
#  ['countrygrllife', 'higurlkailua', 'mytfunny', 'naveenics'],
#  ['usgovernment1', 'usgovernment20', 'catw44', 'usgovernment3'],
#  ['BuriedPleasures', 'between_friends', 'declaireit', 'nyt'],
#  ['JoannaIsBack16', 'spaciekadet', 'proud_survivor1', 'jkenney'],
#  ['todayshow', 'grass76', 'computeblu', 'janetframe3rd'],
#  ['FedUpInMiddle', 'cclub2022', 'Sinta_Sulu', 'roann_mendriq'],
#  ['mikefromjersey9', 'ringsidenews_', 'TonyKhan', 'steve_carrier'],
#  ['nikkithetucker1', 'triciramirez', 'perlaigualada', 'vanityfair'],
#  ['mactad', 'isabellamariags', 'michel_estefan', 'nbedera'],
#  ['notcapnamerica', 'garywhitta', 'natlopez85', 'wyndelllong'],
#  ['ebjjcomicnutyt', 'fernandoemh', 'KARLAAGUILARLA1', 'ColUpton'],
#  ['fightowensfight', 'samizayn', 'codyrhodes', 'pocius_terry'],
#  ['7thsimpleguy', 'oh_for_fucks_s', 'waltdisneyworld', 'WaltDisneyWorld'],
#  ['finallylucid', 'DrewBarrymore', 'addobboart', 'pompeybird61'],
#  ['mfstern', 'elwoodlampblack', 'DarkWebWarrior', 'merrsstinkeye'],
#  ['pop_culture2020', 'spotify', 'rellrk9d', 'stephaniethorb1'],
#  ['oann', 'chanceseales', 'sjcheatwood', 'newsy'],
#  ['ShanklynRebecca', 'tanzacochran', 'HOOPSnix', 'ovarb8'],
#  ['Brendon5374', 'Linda36993618', 'LeniPars', 'orrite_then'],
#  ['mjmoomin', 'moonbirdgarden', 'tammybrisker', 'McCool4u'],
#  ['PaulRev90604674', 'moon1ightrose', 'desselle0010', 'cspanwj'],
#  ['pinkjenn12', 'MissChief__', 'olateesteven', 'we_dontpreorder'],
#  ['murpharoo', 'okka_au', 'PressClubAust', 'AlboMP'],
#  ['friendlyjordies', 'ticketek_au', 'msmegtutor', 'nugstar'],
#  ['MENDFamilyCourt', 'mothering_in_22', 'sabrinascope', 'OrdinaryGuyUK'],
#  ['pattyanne67', 'jamescyphers4', 'Danak65', 'Rogue_Rooster'],
#  ['paulberrymwbb', 'laws_brent', 'masshodler', 'caitoz'],
#  ['annettesjl', 'paulbernaluk', 'southlondonscum', 'happyborg'],
#  ['royals', 'stlouisblues', 'cardinals', 'missourisports'],
#  ['spyrobotpigeon', 'crediblela', 'dogood444', 'RollingStone'],
#  ['thorntonniwot', 'davidgallen', 'izzydew', 'UncvrngTheTruth'],
#  ['thelostdebate', 'ravimgupta', 'rikkischlott', 'corybradford909'],
#  ['thefamilylawco', 'truethingmies', 'imrankhodabocus', 'thetimes'],
#  ['thesilentlie', 'Gnerdicus', 'nojr28', 'apurepolitical'],
#  ['hbee25973', 'haunterv', 'willsmith', 'equity_avenger'],
#  ['dailyblastlive', 'aljackson', 'iamlindseyg', 'toryshulman'],
#  ['karlbykarlsmith', 'positiveOmajaz', 'tony6138420', 'JusticeJohnny7'],
#  ['tomknieper', 'annieleibovitz', 'ladygaga', 'anntelnaes'],
#  ['MatthewModine', 'thedvdgen', 'GatenM123', 'NYRangers'],
#  ['UtkarshSingh_', 'tataetaebts', 'ravishankar966', 'lmao86daniel'],
#  ['Clumsycatty', 'Tampa12', 'Andreawk_RI', 'tdcook70'],
#  ['taylortalkslove', 'zewildcat14', 'taylorswift13', 'b1azeinthedark'],
#  ['JessicaFey7', 'Hanannekko', 'lizzie_mint1990', 'susanob0'],
#  ['sunset4me', 'marymil69985841', 'davenewworld_2', 'freschog'],
#  ['podcastati', 'sydvaughnfan2', 'missrballer', 'krystalcrystal7'],
#  ['sweety_eth', 'e', 'ridgegirlsclub', 'vitalik'],
#  ['delcrxpto', 'shibainuart', 'jesus__is__god', 'peleglewi'],
#  ['AlexFacis', 'Janelle_Int', 'thecompletejeff', 'TriplesX3'],
#  ['benweav06231174', 'natsechobbyist', 'daveweigel', 'Timodc'],
#  ['Tatted_Cat13x', 'McpeakRichie', 'tequila_coconut', 'Jambrady'],
#  ['Saucy_Sadie', 'realblueballs', 'HuffPostEnt', 'UsfFan2019'],
#  ['realdailywire', 'realDailyWire', 'realtjboris', 'windhoekson'],
#  ['JimmyTheWeirdo', 'jaclyn62372872', 'themanbehind200', 'durfeekris'],
#  ['wheeler', 'yuliankostov', 'stephenseanford', 'ch8i'],
#  ['whosfibbing', 'Mohyminul18', 'duchess_salty', 'issuesofmytime'],
#  ['_F_a_i_k_', 'k1482', 'zionistwit23', 'AZmess2'],
#  ['gman007bond', 'Wozrop', 'wozrop', 'Leah_Bordeaux'],
#  ['twd_lostie', 'MAT81456', 'tronnoc1', 'OpinionatedQue2'],
#  ['gato_parodia', 'truthor_lies', 'Gato_parodia', 'TabithaADraper'],
#  ['LilTia2013', 'WonderKing82', 'veronicasixsmi1', 'ColorMeRado'],
#  ['wabuutheraccoon', 'JBronson', 'johnjnorris', 'shaun_vids'],
#  ['usurperf', 'mrs_m_jones', 'wambsgussy', 'MissCassieWells'],
#  ['joeunseen', 'robertholzer', 'DougJBalloon', 'rrosenthal'],
#  ['johnny_joey', 'kilmeade', 'thefive', 'rfcats'],
#  ['shiznarz', 'cityshopgirl', 'fxnetworks', 'rhodyvoice'],
#  ['RandyHeyyyy', 'saintamourmi', 'Alowkin02', 'Reklein'],
#  ['cagranosalis', 'GerriisalsoGigi', 'aja1979', 'sallybell08'],
#  ['blobz2000', 'rotaru67138026', 'bob22247', 'TielaKegs'],
#  ['elaineatwell', 'onthemedia', 'ejdickson', 'roxitheatre'],
#  ['ryanard2011', 'BetteMidler', 'YharnamZilla', 'tamera_bigsby'],
#  ['punk_garden', 'Qnourrr', 'JoAnneGallop2', 'blackdr8gon'],
#  ['alley6669', 'phantomsdesire', 'TeeMar7727', 'purebredbootsy'],
#  ['mcvittie_laura', 'Canadian_What', 'project27262013', 'Snowballing2020'],
#  ['AfamDeluxo', '_spiriituaL', 'solubilityb', 'Wizarab10'],
#  ['jjtramp3', 'april_mordahl', 'ExpEx88', 'southeartlady'],
#  ['JonnnySpinster', 'NetflixUK', 'chloewd38', 'amjad_nabi'],
#  ['steven495', 'nicolelampert', 'ChrisWChrysalis', 'wrightonthenail'],
#  ['JessicaABC30', 'stanb99', 'ABC30', 'corinhoggard'],
#  ['4VLiveOfficial', 'LewdvigR', 'semitismandy', 'YunaSunaga'],
#  ['shuaibazhar', 'saaadmalikk', 'CherieDamour_', 'GenialMalik'],
#  ['shaunaghg', 'tompeck', '6thGUARDS_TNK', 'bungalow_town'],
#  ['stephenathome', 'shanekillingba1', 'davidleeroth', 'taikawaititi'],
#  ['newyorker', 'cspellot', 'just4bensimmons', 'kziwica'],
#  ['crypto__angel_', 'rhramholkar', 'mrnotsolucky078', 'abin0708'],
#  ['AmberKauur', 'kungfukeralite', 'cyasuzie', 'beachygal77'],
#  ['AgainstPRmedia', 'hearwegoghagain', 'nerdjpg', 'coryredding'],
#  ['Treetop32243990', 'Samantha2015x', 'cerebus79', 'FTWRUBINA22'],
#  ['chasingsprings', 'jumpbuttonsmom', 'ifonlyalabama', 'january6thcmte'],
#  ['ferg20213227', 'Pace1013', 'cathball', 'campbellclaret'],
#  ['PTSD_barnum', 'MattTheKing', 'picassoc', 'clangntang'],
#  ['benoliver_1', 'BobaTHEFett4', 'codexrex', 'loxyisme'],
#  ['NoSydGal2', 'Waltika', 'BrendaJ69492764', 'cholakrosanna'],
#  ['chicagokelley', 'TravelMartini1', 'daisy_cliff', 'LoveDoodlebug'],
#  ['christenczech', 'Robin1226', 'pulse_rifle', 'aroojtkhan'],
#  ['OnAirWithVBlair', 'EdricLeonson', 'FeltedAgain', 'elektraus'],
#  ['eesprite', 'carolecadwalla', 'ElzabethXtra', 'TomFetter2'],
#  ['edwina2018', 'LewisDineen', 'Gandhiyo2469', 'kirarlynne'],
#  ['alex_kraemer3', 'alisonmaloni', 'robfinnertyusa', 'dr_kkuhlman'],
#  ['awazebaramulla', 'zaira_nizaam', 'dr_avantika999', 'chinarcorpsia'],
#  ['GitchiGamiFan', 'conservatismDNA', 'LouDobbs', 'dudecrypto420'],
#  ['FiveHoleFire', 'elliottwindcat', 'Rainmaker1973', 'JuliusBernotas'],
#  ['anaisabelle', '_Talolie', 'Jbaffoh', 'Dalia42'],
#  ['springsteen', 'adultprotection', 'displacedinla', 'laco_dpss'],
#  ['kate_freedomer', 'LakeOswegomom', 'domleescott', 'stevemur'],
#  ['Cathylou34', 'Louise75997969', 'diannebdee', 'RkivedInMyHeart'],
#  ['amysmith9191', 'iflyCHS', 'Avis', 'robhuebel'],
#  ['alisonpower9', 'AlisonPower9', 'JoshMankiewicz', 'lucky32014128'],
#  ['amanitagiftshop', 'MorningEdition', 'johnlegend', 'jmsummers'],
#  ['traz_mac', 'alwaysanangel72', '_YorkshireLass_', 'David_Major'],
#  ['PhoenixVicki', 'filosofotasio', 'LDBlondePod', 'Jessikalb'],
#  ['hamiltonnolan', 'antifah_q', 'ashleyfeinberg', 'businessinsider'],
#  ['lifestream223', 'BrokenLobo', 'Marc_Daniels_ZA', 'ahyekubeyinje'],
#  ['BluestStocking', 'jack_phileas', 'bossert_l', 'HananDover1'],
#  ['jennie1966', 'rosemarwa97', 'SinclairDarleen', 'bnaeece'],
#  ['bodhisattvapgh', 'ThePriceSicard', 'BaconBacon1969', 'PapaleoKathleen'],
#  ['Fuuse', 'blauwelotus', 'eddy_terstall', 'Deeyah_Khan'],
#  ['JcGtrz', 'b3nl', 'lRosettaStoned', 'AregoodDrugs'],
#  ['bann1river', 'patiMax1948', 'Explorer_500', 'FarmgirlRebel'],
#  ['BillieRubenMake', 'Barnacules', 'atreides037', 'midnightsmith'],
#  ['gabrielmacht', 'halfadams', 'awaisbigmahmood', '__harveyspecter'],
#  ['deppdoge', 'kriptokral8', 'altcryptocom', 'benchewupamber'],
#  ['ThlsaSeaGoddess', 'rosiedoes', 'bernboomer', 'name_is_nessa'],
#  ['Louloukeets1', 'dulhunty', 'kris_carmelo_', 'jessica66079058'],
#  ['nra', 'sentedcruz', 'gregabbott_tx', 'kitwilliamson'],
#  ['leaveheardalone', 'Anthony_r_P', 'moulinswift', 'JaimePretellEsq'],
#  ['poniesnbourbon', 'JudgeFergusonTX', 'thewolflawyer', 'justice314lady'],
#  ['WaltGekko', 'DEFendFURiously', 'justiceisnext1', 'johnnynieves12'],
#  ['kids_safe_1st', 'AY64027641', 'JohnHag15101512', 'Lozv1'],
#  ['bazluhrmann', 'austinbutler', 'karenboulware2', 'tomhanks'],
#  ['katieh1975', 'elisestefanik', 'tuckercarlson', 'life_love_honey'],
#  ['mallorysiquiera', 'petterpaker8235', 'trulysmugfaced', 'Aaditya_Shukla2'],
#  ['thejusticedept', 'lyceumwc', 'jennycohn1', 'dojnatsec'],
#  ['haylesowen', 'jeanettearsenau', 'mandyconnell', 'thekiffness'],
#  ['marilynweaver13', 'Aberdare_ke', 'maryb1327', 'coylady70'],
#  ['mariannaspring', 'chrismasonbbc', 'walklate88', 'bbcferguswalsh'],
#  ['ZaBella13492540', 'lifeburn3', 'reid_indeed95', 'Abhishek_J_C'],
#  ['hairsniffer777', 'ProudLiberal340', 'emmylux1', 'invkoalabooks'],
#  ['flamingheaux', 'jack_obrien', 'milesofgray', 'dailyzeitgeist'],
#  ['BarrioFinito', 'FinanceLancelot', 'f4de2bl4ck', 'realJohnMappin'],
#  ['ftravellin', 'viris_2001', 'simply__logical', 'ondaonogrenci'],
#  ['shannonthedude', 'drewfranklinksr', 'jaymoore555', 'kysportsradio'],
#  ['showtimeboxing', 'jb_richter', 'i_amatunez', 'shosports'],
#  ['jakcyjack80', 'Vice0', 'Mladen43335029', 'big_smoke123'],
#  ['atdotcomma', 'SSEUPodcast', 'jasoncooper22', 'carmella_nicole'],
#  ['JuliaHB1', 'ianar47', 'paulwaugh', 'ArchRose90'],
#  ['Clementhillsong', 'JackieG4111', 'isabothe', 'csmcdncr99'],
#  ['faisorler', 'thebarcouncil', 'jeramiedreyfuss'],
#  ['sunnyzombie1', 'stirgussa', 'vanessa71389903'],
#  ['poopah73', 'colleenbaker4', 'AliciaMae_O'],
#  ['jennnnifer_22', 'cc_fiji', 'ameliajacko01'],
#  ['steviejraw', 'los', 'emmaleekelly5'],
#  ['mengmaanyaa', 'goblinqchesh', 'desigamerladki'],
#  ['AcklandVeronica', 'littlemissbants', 'Yiskah879'],
#  ['MelanieBridgen', 'shesfnspeaking', 'noland_misty'],
#  ['chrisel81457588', 'DailyMailCeleb', 'itsraining2'],
#  ['rad_sahar', 'CDeevia', 'Mochyatiff'],
#  ['snl825', 'moesfn1', 'trabulsyeh'],
#  ['MuskyBaby', 'katrinatatina', 'reillynjames'],
#  ['johnnydepp__ll', 'johnraf10618715', 'tqmeri01'],
#  ['xxjusttessxx', 'tartanbulletz', 'djtashy4624'],
#  ...]

# %%
print("Numero comunità identificate con l'algoritmo Label Propagation: ", len(labelp_coms.communities))
# Out:
# Numero comunità identificate con l'algoritmo Label Propagation:  4722

# %%
stampa_nodi_coms(labelp_coms, 'Label Propagation')
# Out:
# Nodi nelle communities identificate con l'algoritmo Label Propagation : 18266

# %% [markdown]
# Esporto le comunità identificate con **Label propagation**

# %%
df_comunities_lp = pd.DataFrame(labelp_coms.communities)
df_comunities_lp = df_comunities_lp.transpose()
string_names = ['community_'+ str(i) for i, c in enumerate(labelp_coms.communities)] 
df_comunities_lp.columns = string_names

# %%
df_comunities_lp
# Out:
#          community_0      community_1      community_2      community_3  \
# 0         kkatbat412    badgirl_drone            Iromg  mattjohnsonnews
# 1       davidterrace     newfypearl67       SchmoJosey    janna_bastone
# 2       snackbyteso1   12onefortyfour        javanoob2  gafamilylawyers
# 3          llivv0123       jentheriot   Butterflies949      janyegwynne
# 4     comteberenguer  keepcalmpersist  Tempora80335786         mghnn_jn
# ..               ...              ...              ...              ...
# 444    missvicious86             None             None             None
# 445          pmgsmbl             None             None             None
# 446         libhalps             None             None             None
# 447  daveforgiveness             None             None             None
# 448   the_mermaidian             None             None             None
#
#          community_4    community_5      community_6      community_7  \
# 0         ripdajuulz    DaaniMonday        ljh_3pups  marsbarwilliams
# 1    jordans92248235  AichaMarghadi  thissmallplanet       2facedpink
# 2      midas_forever     Diana__A93          guire89   kittycatlitter
# 3           texastoe    chuwareewap   amiablephantom    misannthropic
# 4    nepaligentleman        Protosz           l2049s        ajbartram
# ..               ...            ...              ...              ...
# 444             None           None             None             None
# 445             None           None             None             None
# 446             None           None             None             None
# 447             None           None             None             None
# 448             None           None             None             None
#
#         community_8     community_9  ... community_4712 community_4713  \
# 0             lorbe    jesskapizzle  ...  thetalentguru          z2htv
# 1       cheetah1961  diamondbabbyyy  ...           None           None
# 2    DavidSting1989  mrs_gonzalez05  ...           None           None
# 3          rlgriebe     elisadayj4j  ...           None           None
# 4       notascranky     farmama7983  ...           None           None
# ..              ...             ...  ...            ...            ...
# 444            None            None  ...           None           None
# 445            None            None  ...           None           None
# 446            None            None  ...           None           None
# 447            None            None  ...           None           None
# 448            None            None  ...           None           None
#
#     community_4714 community_4715  community_4716 community_4717  \
# 0    socialrobbers     stoptechy1  ex0t1c_markets  aylinaydindal
# 1             None           None            None           None
# 2             None           None            None           None
# 3             None           None            None           None
# 4             None           None            None           None
# ..             ...            ...             ...            ...
# 444           None           None            None           None
# 445           None           None            None           None
# 446           None           None            None           None
# 447           None           None            None           None
# 448           None           None            None           None
#
#      community_4718 community_4719  community_4720 community_4721
# 0    averagebeing99  lekucciglobal  faceswaponline        icmynft
# 1              None           None            None           None
# 2              None           None            None           None
# 3              None           None            None           None
# 4              None           None            None           None
# ..              ...            ...             ...            ...
# 444            None           None            None           None
# 445            None           None            None           None
# 446            None           None            None           None
# 447            None           None            None           None
# 448            None           None            None           None
#
# [449 rows x 4722 columns]

# %%
df_comunities_lp.to_csv("data/comunità/coms_lp.csv")

# %%
df_comunities_lp.shape
# Out:
# (449, 4722)

# %% [markdown]
# ----

# %% [markdown]
# ## K-CLIQUE <a id = 'kclique'> </a>

# %% [markdown]
# Parameter tuning (numero K)

# %%
k = ensemble.Parameter(name = "k", start = 2, end = 15, step = 1)

kclique_coms, scoring_k = ensemble.random_search(graph = g, method = algorithms.kclique,
                                              parameters = [k],
                                              quality_score = evaluation.erdos_renyi_modularity,
                                              instances = 3, aggregate=max)

print("Configuration: %s \nScoring: %s" %(kclique_coms.method_parameters, scoring_k))
# Out:
# Configuration: {'k': 4}
# Scoring: FitnessResult(min=None, max=None, score=0.0036402590732196463, std=None)

# %%
kclique_coms = algorithms.kclique(g, k=3)
kclique_coms

# %% [markdown]
# ### Valutazione interna

# %%
print('Sovrapposizione communities identificate con algoritmo Louvain (con pesi): ', kclique_coms.overlap)
#nel k-clique ci sono sovrapposizioni
# Out:
# Sovrapposizione communities identificate con algoritmo Louvain (con pesi):  True

# %%
coms_evaluation(kclique_coms, "K-Clique (k = 3)")
# Out:
# --------------------------------------------------------------
#  Valutazione comunità ottenute con algoritmo K-Clique (k = 3)
# -------------------------------------------------------------
#
# - Copertura nodi: 0.02989160188328041
# - Modularity: FitnessResult(min=None, max=None, score=0.01275063022637942, std=None)
# - Numero Nodi: FitnessResult(min=3, max=254, score=7.0, std=26.565641971037202)
# - Avg Distance: FitnessResult(min=1.0, max=2.9206685132737853, score=1.1242714804102472, std=0.2773980003122679)
# - Conductance: FitnessResult(min=0.0, max=0.9908675799086758, score=0.7619912677873699, std=0.28907527453167314)
# - Avarage Node Degree: FitnessResult(min=2.0, max=7.417322834645669, score=2.384450868280295, std=0.7613633339829603)
# - Internal Edge Density: FitnessResult(min=0.029317481559864307, max=1.6666666666666667, score=0.9068610082489726, std=0.2204938415078105)

# %%
kclique_coms.communities
# Out:
# [['postpunkbunny',
#   '007londongirl',
#   'mattjohnsonnews',
#   'duchess_neeka',
#   'janna_bastone',
#   'davidterrace',
#   'nytimes',
#   'gafamilylawyers',
#   'roslyn715',
#   'miamillerauthor',
#   'bonviebling',
#   'sretrodude',
#   'govchad',
#   'formerpr',
#   'apple121',
#   'fabz33',
#   'washingtonpost',
#   'faranbalanced',
#   'djliquiddrip',
#   'ThatBrianFella',
#   'nectarpeppervt',
#   'hnnbnn88',
#   'unabashedgator',
#   'IanRunkle',
#   'lorraine_hickey',
#   'deppheardtruth',
#   'anyaglows',
#   'jacxpearl',
#   'borghardtlaw',
#   'An_elf_pirate',
#   'FormerPr',
#   'mackette52',
#   '_Mz2u',
#   'popcornedplanet',
#   'j0hnnycdpp',
#   'texasmagnolia2',
#   'drproudman',
#   'kimwmoonchild',
#   'thelawkoala',
#   'sashacairesse',
#   'joonbug12345',
#   'jmmain21yahooc1',
#   'meganfoxwriter',
#   'robert__leonard',
#   'DrProudman',
#   'whatifanynani',
#   'channelclaireyt',
#   'life0fhigh707',
#   'rvanova01',
#   'lorenasalter1',
#   'leannen04',
#   'ffsnoidea',
#   'gemrosep',
#   'alison_diane',
#   'courttv',
#   'victori17400403',
#   'brelana88',
#   'donmc01195764',
#   'biosnap',
#   'esneet4113',
#   'shmuue',
#   'stern_angelica',
#   'erraticopinions',
#   'KyDUIGuy',
#   'zimmbiogal',
#   'natesaver',
#   'jamiediann003',
#   'vampire_fairy',
#   'lizbethne30',
#   'joycourttv',
#   'theemilydbaker',
#   'ellisgreg',
#   'adrferg',
#   'bluntbeyotchh',
#   'tedcourttv',
#   'lulatrixiebelle',
#   'kugraduate',
#   'danceinline',
#   'KevinRashidi',
#   'squidlord',
#   'redzesty11',
#   'scryndi',
#   'optistrong',
#   'davinajh',
#   'kumar_b1',
#   'mike_simmonds_',
#   'katarific2010',
#   'ashleycourttv',
#   'EllenBarkin',
#   'LuckyLo59037265',
#   'comedyfan1981',
#   'amberrosee422',
#   'norcrosslaw',
#   'aburkhartlaw',
#   'lumberlaw',
#   'TMZ',
#   'courttvuk',
#   'voguemagazine',
#   'rn_in_christ',
#   'wakeyourvintage',
#   'chanleycourttv',
#   'juliecourttv',
#   'ThatUmbrella',
#   'niermanjoe',
#   'hoeglaw',
#   'lola6307',
#   'dolly_faith2015',
#   'tahjwilson5',
#   'rebecca91921211',
#   'darrenimms',
#   'annsilvers',
#   'socialtheorycan',
#   'diealoguepod',
#   'realdavidgrace',
#   '0iivie',
#   'inspectorstocks',
#   'ElizabethMcGov',
#   'shortbusdave86',
#   'voxdotcom',
#   'lucybarbagallo',
#   'leahburke111',
#   'nurmiunchained',
#   'shellbell123r',
#   'Raven__Smith',
#   'integrityshines',
#   'newsome_dianne',
#   'zinniabees',
#   'forwomeninbiz',
#   'planetmonkie',
#   'vipvirtualsols',
#   'ChanleyCourtTV',
#   'charmgurl',
#   'ObserverUK',
#   'karima_bright',
#   'starwatch007',
#   'Independent',
#   'tatey61',
#   'moralecompass',
#   'sassyliltutus',
#   'jwl2nd',
#   'rohitkulk29',
#   'digbylaps',
#   'bootstinker',
#   'cookie_aunty',
#   'ChristinaPykles',
#   'lawyerschiff',
#   'lonestarmomcom',
#   'mderndarkwizard',
#   'thelizrusso',
#   'tmz',
#   'boydhelenanne',
#   'Truthse10335075',
#   'franklyme16',
#   'unmasked_kim',
#   'misschieffe',
#   'legalbytesmedia',
#   'source411',
#   'serpens1984',
#   'ganthew',
#   'thismisspenny',
#   'heather06898275',
#   'thirdgirlll',
#   'grinsli',
#   'courttvfans',
#   'thatumbrella',
#   'shanbamanana',
#   'kyduiguy',
#   'jamesfromcourt',
#   'dlordepp',
#   'pmt2387',
#   'stonedagainbro',
#   'magniloquensica',
#   'gnukman',
#   'Variety',
#   'ashleykristen64',
#   'shez1124',
#   'claudjaharis',
#   'majaseif',
#   'prince1antonio',
#   'colleenbaker4',
#   'GellertDepp',
#   'saifed99',
#   'annecarea',
#   'andysignore',
#   'catwoman_1111',
#   'factsoverbs',
#   'debsappy',
#   'thatbrianfella',
#   'rosiepilsbury',
#   'youtube',
#   'ailed_23',
#   'tgustincic',
#   'neneisme',
#   'bluerosegirl',
#   'devilsnight',
#   'steviejraw',
#   'LauraBockov',
#   'danblock4',
#   'TheNamesQ',
#   'AshleyCourtTV',
#   'heatherventures',
#   'ica_baby_la',
#   'kevinmuehleisen',
#   'laurennfarmerr',
#   'joleonard___x',
#   'marshmallow8753',
#   'mousears7',
#   'lorenkatie',
#   'teresalolvera',
#   'mskatiekate88',
#   'thevampirerose',
#   'MailOnline',
#   'blackfished2',
#   'toastymist',
#   'charisse_cantu',
#   'magesh_elumalai',
#   'grtamericanovel',
#   'marcoiaatty',
#   'rekietalaw',
#   'marsupial_gamer',
#   'kelly_updyke',
#   'mensurvivetoo',
#   'rupertmurdoch',
#   'minhaltaher',
#   'realamberheard',
#   'theonlyju1',
#   'tartanbulletz',
#   'bartonbella1',
#   'starrgh',
#   'bronk34',
#   'itsadriienne',
#   'tasteofsanity',
#   'notapopularop',
#   'channerz_maiden',
#   'ianrunkle',
#   'asl4nrawkz',
#   'sunflxwervolsix',
#   'JulieCourtTV',
#   'winkiesword',
#   'sub_boo',
#   'jackrice',
#   'stephxxmichelle',
#   'calley_criminal',
#   'ameliabee7721',
#   'laurabockov',
#   'miamay08979380',
#   'bondjane007',
#   'iamnenestwin',
#   'andreaelisii',
#   'daveforgiveness',
#   'abelci0',
#   'nypost',
#   'cinemamack',
#   'CourtTV'],
#  ['glorian62678817',
#   'joflohoosier',
#   'richschoenstein',
#   'watrundrbridge',
#   'florinalaw',
#   'hlntv',
#   'cathyrusson',
#   'tarterkrinsky',
#   'bretzelicious',
#   'nickjax222',
#   'pmasson_',
#   'deppheardtruth',
#   'janetlgallo',
#   'sasssassenach',
#   'LawCrimeNetwork',
#   '__towanda',
#   'askdinadoll1',
#   'allezupyourass',
#   'ginainala',
#   'angenette5',
#   'phxrisingamb',
#   'lawcrimenetwork',
#   'hey_johnathan',
#   'sierragillespie',
#   'jessiethebud',
#   'kenneybaden',
#   'la_julica',
#   'catwoman_1111',
#   'matthewtmangino',
#   'blueasthesky_1',
#   'finwinston',
#   'tiny_toff',
#   'wiseaudra',
#   'Angenette5',
#   'alargue4rfc',
#   'buckesq',
#   'rad_sahar',
#   'rossi4va',
#   'jessecordweber',
#   'lawfulrich',
#   'tracyexplains',
#   'scandalous_pod',
#   'castanzageorgie'],
#  ['sunny',
#   'luvwinsresist',
#   'justdoodirty3',
#   'JimmieMckinnon',
#   'Glamor14kt',
#   'MomOf3Pgh',
#   'brijh',
#   'iamprettypetty',
#   'ChrissysBlog',
#   'ABC',
#   'danabrams',
#   'farrisflagg',
#   'TClarkUSA',
#   'CLady62',
#   'LiveOnTheChat',
#   'TheSistahChick'],
#  ['elonmusk',
#   'tallie_anne',
#   'shellbell123r',
#   'warriorxqueeng',
#   'theemilydbaker',
#   'mariahamaya10',
#   'justagirl043',
#   'karate_kaninen',
#   'barbaraem77',
#   'nectarpeppervt',
#   'simplyslj'],
#  ['robert__leonard',
#   'peanatxo',
#   'malik_eva',
#   'anacbna',
#   'canada316',
#   'nan4bsb',
#   'realamberheard',
#   'DrProudman'],
#  ['BooBird65',
#   'b_sistah',
#   'voguemagazine',
#   'Raven__Smith',
#   'babetterthanmee',
#   'Cerebus79',
#   'truthfairyland'],
#  ['aburkhartlaw',
#   'colonelkurtz99',
#   'traceybaby',
#   'yuta89515664',
#   'laurieleannie',
#   'mh44461',
#   'tericarson'],
#  ['Ihaveadream0101',
#   'trotdarrow',
#   'nataliesonya',
#   'deppheardtrial',
#   'DeppHeardTrial',
#   'ihaveadream0101'],
#  ['haggisreflux',
#   'mandoq3r0',
#   'raccoonclubhous',
#   'Olhollywoodleft',
#   'ljsandahl',
#   'Lons'],
#  ['realamberheard',
#   'etbnetwork',
#   'nickwriteswords',
#   'nmorgasenradio',
#   'knackbags',
#   'beyondthebench1'],
#  ['maxvaldes', 'dohamadani', 'davidkli', 'saba_h', 'kalhanr', 'kattenbarge'],
#  ['atiebrahimi70', 'twyla411', 'madsonovich', 'depplyhaIIows', 'wbpictures'],
#  ['youtube',
#   'desigamerladki',
#   'washingtonpost',
#   'mengmaanyaa',
#   'goblinqchesh'],
#  ['emilyabell', 'jchodera', 'mifield', 'dasingleton', '_happyhappyist'],
#  ['baquelita', 'ian_gay_briel', 'DeppHeardTrial', 'RottenInDenmark'],
#  ['theemilydbaker', 'valskyco', 'texasmagnolia2', 'twitter'],
#  ['rekietalaw', 'thelegalvices', 'lawselfdefense', 'kittyb0bitty'],
#  ['robert__leonard', 'starjumper9', 'JulieCourtTV', 'CourtTV'],
#  ['kalhanr', 'tomnamako', 'nbcnews', 'calliope__m'],
#  ['ContraPoints', 'wozrop', 'Leah_Bordeaux', 'gman007bond'],
#  ['realamberheard', 'obsrvr4u', 'Eve_Barlow', 'watrundrbridge'],
#  ['sra_solicitors', 'wintermutexbt', 'btckershi', 'ONTIERLLP'],
#  ['exiled_Lover', 'MelanieBridgen', 'deppheardtruth', 'littlemissbants'],
#  ['jacques_hyzagi', 'kspowerwheels', 'maureendowd', 'jessicabennett'],
#  ['jrosengard', 'lumberlaw', 'sosofiefatale', 'ianrunkle'],
#  ['barnes_law', 'pjparkjd', 'thevivafrei', 'mean_vagine'],
#  ['grownded', 'TaraBull808', 'shane_holmberg', 'elonmusk'],
#  ['sweety_eth', 'ridgegirlsclub', 'vitalik', 'jesus__is__god'],
#  ['sidebarcns', 'ninapullano', 'courthousenews', 'bright_lamp'],
#  ['chrisablesfool', 'levy_sir', 'robbloodysaul', 'levylandshow'],
#  ['luciagranus', 'AmberRose_Bruh', 'realamberheard', 'debra_aquarius'],
#  ['courttv', 'bthequeen13', 'juliacourttv'],
#  ['GellertDepp', 'cynthiatweetsit', 'malik_eva'],
#  ['futuremair_', 'vulture', 'vicbekiempis'],
#  ['esneet4113', 'oldmenwguitars', 'thatumbrella'],
#  ['deppheardtruth', 'mrsw68_1', 'TheEmilyDBaker'],
#  ['deppheardtruth', 'thatsfunnymel', 'roaringrapids22'],
#  ['deppheardtruth', 'paul_smudga', 'RottenInDenmark'],
#  ['deppheardtruth', 'itsahashtaglife', 'laura_auerbach'],
#  ['barnardfox5dc', 'fox5dcjeannette', 'fox5dc'],
#  ['nbcnews', 'vivacityrules', 'jam_onlineradio'],
#  ['lobotechx', 'thingscloves', 'b_sistah'],
#  ['jamiediann003', 'asranomani', 'jamesfromcourt'],
#  ['queenvickyv', 'harriepw', 'indyvoices'],
#  ['sheecm81', 'audittheabsurd', 'tar_dojo'],
#  ['instagram', 'thirdgirlll', 'britbountree'],
#  ['ElaineAdu_Poku', 'mikekin73778218', 'thetwerkinggirl'],
#  ['juliecourttv', 'hlntv', 'jeancasarezcnn'],
#  ['eldiablo0786', 'solitarnesque', 'bordesleygreen'],
#  ['markgeragos', 'adamcarolla', 'gpatricksmith'],
#  ['newscomauhq', 'julie_sweet_', 'michaelglflood'],
#  ['esneet4113', 'kyduiguy', 'ssolorio77'],
#  ['toothfairylala', 'TheEmilyDBaker', 'keep_itt_movinn'],
#  ['amypolacko', 'sandra_radna', 'nbcnewsthink'],
#  ['madsonovich', 'Izze1122', 'solequeen2020'],
#  ['madsonovich', 'mariahh_elenaa', 'voguemagazine'],
#  ['theview', 'putneyswope9', 'danabrams'],
#  ['dailyblastlive', 'janinedriver', 'bubbysview'],
#  ['eve_barlow', 'jerusalem_post', 'emilykschrader'],
#  ['maniaandcoffee', 'queenofcodebass', 'eve_barlow'],
#  ['candywats', 'remoner4life', 'nypost'],
#  ['rekietalaw', 'awesomismmom', 'hunleyeric'],
#  ['thelastshow', 'aine_333', 'kyduiguy'],
#  ['mohitchuriwal', 'ani_digital', 'ani'],
#  ['realamberheard', 'finwinston', 'bradfordcohen'],
#  ['sailoryue', 'nityalakshmi108', 'elonmusk'],
#  ['DaniMet1', 'whosgunnadoit', 'realannaowens'],
#  ['nina7infinity', 'rekietalaw', 'lisan_al_mahdi'],
#  ['crimewatchdaily', 'askdinadoll1', 'joshuaritteresq'],
#  ['kyduiguy', '227thomas', 'j3lte'],
#  ['c_o_1991', 'dirtylovv', 'DrProudman'],
#  ['elonmusk', 'queenofcodebass', 'fearfully_madee'],
#  ['thatumbrella', 'sujujjh', 'queenofcodebass'],
#  ['vampmartinpgh', 'thesolarcoffee', 'fiendformojitos'],
#  ['25lrock', 'wheelerlydia', 'blaw'],
#  ['voicesoftruth', 'monchxriii', 'ThatUmbrella'],
#  ['azarilaw', 'teradatomoo', 'kaitlancollins'],
#  ['joflohoosier', 'claracluck33', 'DrProudman'],
#  ['luciagranus', 'llcosby', 'ThatUmbrella'],
#  ['sadittymommy', 'abc', 'ca_divorce'],
#  ['faranbalanced', 'aerwaves_', 'chanmasta'],
#  ['nakedvix', 'amandaknox', 'indyvoices'],
#  ['robert__leonard', 'aine_333', 'tghdecor'],
#  ['voguemagazine', 'mundo_esoteria', 'gaianyc'],
#  ['Sibilla08726941', 'martinsrosie', 'misstruthadare'],
#  ['bestebutter', 'Eve_Barlow', 'nonunnun'],
#  ['alinill123', 'hannerill', 'DrProudman'],
#  ['elizameryl', 'nonunnun', 'nypost'],
#  ['freyathais', 'GellertDepp', 'trishamott'],
#  ['ftravellin', 'its__me__x', 'DrProudman']]

# %%
print("Numero comunità identificate con l'algoritmo K-Clique: ", len(kclique_coms.communities))
# Out:
# Numero comunità identificate con l'algoritmo K-Clique:  90

# %%
stampa_nodi_coms(kclique_coms, 'K-Clique')
# Out:
# Nodi nelle communities identificate con l'algoritmo K-Clique : 546

# %%
kclique_coms = algorithms.kclique(g, k=3)
kclique_coms

# %% [markdown]
# Esporto le comunità identificate con **Kclique**

# %%
df_comunities_kc = pd.DataFrame(kclique_coms.communities) # modificare communities con kclique_coms.communities
df_comunities_kc = df_comunities_kc.transpose()
string_names = ['community_'+ str(i) for i, c in enumerate(kclique_coms.communities)] 
df_comunities_kc.columns = string_names

# %%
df_comunities_kc
# Out:
#          community_0      community_1     community_2     community_3  \
# 0      postpunkbunny  glorian62678817           sunny        elonmusk
# 1      007londongirl     joflohoosier   luvwinsresist     tallie_anne
# 2    mattjohnsonnews  richschoenstein   justdoodirty3   shellbell123r
# 3      duchess_neeka   watrundrbridge  JimmieMckinnon  warriorxqueeng
# 4      janna_bastone       florinalaw      Glamor14kt  theemilydbaker
# ..               ...              ...             ...             ...
# 249  daveforgiveness             None            None            None
# 250          abelci0             None            None            None
# 251           nypost             None            None            None
# 252       cinemamack             None            None            None
# 253          CourtTV             None            None            None
#
#          community_4      community_5     community_6      community_7  \
# 0    robert__leonard        BooBird65    aburkhartlaw  Ihaveadream0101
# 1           peanatxo         b_sistah  colonelkurtz99       trotdarrow
# 2          malik_eva    voguemagazine      traceybaby     nataliesonya
# 3            anacbna     Raven__Smith    yuta89515664   deppheardtrial
# 4          canada316  babetterthanmee   laurieleannie   DeppHeardTrial
# ..               ...              ...             ...              ...
# 249             None             None            None             None
# 250             None             None            None             None
# 251             None             None            None             None
# 252             None             None            None             None
# 253             None             None            None             None
#
#          community_8      community_9  ...   community_80 community_81  \
# 0       haggisreflux   realamberheard  ...  faranbalanced     nakedvix
# 1          mandoq3r0       etbnetwork  ...      aerwaves_   amandaknox
# 2    raccoonclubhous  nickwriteswords  ...      chanmasta   indyvoices
# 3    Olhollywoodleft   nmorgasenradio  ...           None         None
# 4          ljsandahl        knackbags  ...           None         None
# ..               ...              ...  ...            ...          ...
# 249             None             None  ...           None         None
# 250             None             None  ...           None         None
# 251             None             None  ...           None         None
# 252             None             None  ...           None         None
# 253             None             None  ...           None         None
#
#         community_82    community_83     community_84 community_85  \
# 0    robert__leonard   voguemagazine  Sibilla08726941  bestebutter
# 1           aine_333  mundo_esoteria     martinsrosie   Eve_Barlow
# 2           tghdecor         gaianyc   misstruthadare     nonunnun
# 3               None            None             None         None
# 4               None            None             None         None
# ..               ...             ...              ...          ...
# 249             None            None             None         None
# 250             None            None             None         None
# 251             None            None             None         None
# 252             None            None             None         None
# 253             None            None             None         None
#
#     community_86 community_87 community_88 community_89
# 0     alinill123   elizameryl   freyathais   ftravellin
# 1      hannerill     nonunnun  GellertDepp   its__me__x
# 2     DrProudman       nypost   trishamott   DrProudman
# 3           None         None         None         None
# 4           None         None         None         None
# ..           ...          ...          ...          ...
# 249         None         None         None         None
# 250         None         None         None         None
# 251         None         None         None         None
# 252         None         None         None         None
# 253         None         None         None         None
#
# [254 rows x 90 columns]

# %%
df_comunities_kc.to_csv("data/comunità/coms_kc.csv")

# %%
df_comunities_kc.shape
# Out:
# (254, 90)

# %% [markdown]
# -----

# %% [markdown]
# # EXTERNAL EVALUATION <a id = 'exval'></a>

# %% [markdown]
# - normalized mutual information
# - normalized f1 score

# %% [markdown]
# ###  Normalized Mutual Information (NMI)
# - louvain vs label prop

# %%
evaluation.normalized_mutual_information(labelp_coms, louvain_coms)
# Out:
# MatchingResult(score=0.8107437980173448, std=None)

# %%
#matrice nmi tra Louvain e label prop
# kclique non si può usare perché non copre lo stesso insieme di nodi degli altri due algoritmi
viz.plot_sim_matrix([labelp_coms, louvain_coms],evaluation.normalized_mutual_information)
plt.savefig('img/CD/matrix_louvain_labelp_nmi')

# %% [markdown]
# ### Normalized F1
# - louvain vs label propagation
# - k-clique vs Louvain
# - label propagation vs k-clique

# %%
labelp_coms

# %%
evaluation.f1(labelp_coms, louvain_coms)
# Out:
# MatchingResult(score=0.5332966334956595, std=0.47798326494793564)

# %%
evaluation.f1(kclique_coms, louvain_coms)
# Out:
# MatchingResult(score=0.08948453608247424, std=0.22923616388570156)

# %%
evaluation.f1(kclique_coms, labelp_coms)
# Out:
# MatchingResult(score=0.32606557377049183, std=0.2682901456584973)

# %%
#matrice nf1 tra tutti e tre gli algoritmi
clustermap = viz.plot_sim_matrix([kclique_coms, louvain_coms,labelp_coms ],evaluation.f1)
plt.savefig('img/CD/matrix_louvain_labelp_kclique_f1')

# %%
#matrice nf1 tra Louvain e label prop
clustermap = viz.plot_sim_matrix([labelp_coms,louvain_coms],evaluation.f1)
plt.savefig('img/CD/matrix_louvain_labelp_f1')

# %%
#matrice nf1 tra k-clique e label prop
clustermap = viz.plot_sim_matrix([kclique_coms, labelp_coms],evaluation.nf1)
plt.savefig('img/CD/matrix_louvain_kclique_f1')

# %% [markdown]
# ### Visualizzazione dei risultati ottenuti dalla valutazione esterna delle communities

# %%
# violin plot 
violinplot = viz.plot_com_stat([kclique_coms,louvain_coms],evaluation.size)

# %%
# relazione tra le proprietà 
viz.plot_com_properties_relation([labelp_coms,louvain_coms], evaluation.size, evaluation.internal_edge_density)
plt.savefig('img/CD/properties_relation_louvain_labelp')

# %% [markdown]
# #### Boxplot dei tre algoritmi

# %%
metodi = [('Label Propagation',labelp_coms.size(summary = False)), ('Louvain', louvain_coms.size(summary = False)), ('K-Clique', kclique_coms.size(summary = False))]

size = []
labels = []

for i in range(len(metodi)):
    labels.append(metodi[i][0])
    size.append(metodi[i][1])
fig = plt.figure(figsize=(16,8), dpi= 300)
ax = fig.add_subplot(111)
plt.boxplot(size,labels=labels)


plt.xlabel('Algoritmi di Community Discovery', fontsize = 16)
plt.ylabel("Dimensioni", fontsize = 16)
plt.grid(axis='both', alpha=.3)
#plt.title("Boxplot Algoritmi Community Discovery", fontsize = 18)
plt.yscale("log")
plt.xticks(fontsize = 14)
plt.savefig('img/CD/boxplot_CD')


plt.show()
